# %%
import os

import torch
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts

from going_modular.dataloader.magface import create_concat_magface_dataloader
from going_modular.model.MagFaceRecognition import MagFaceConcatRecognition
from going_modular.train_eval.train import fit
from going_modular.loss.MagLoss import MagLoss
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint

import albumentations as A

device = "cuda" if torch.cuda.is_available() else "cpu"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Đặt seed toàn cục
seed = 42
torch.manual_seed(seed)

CONFIGURATION = {
    # Thư mục
    'type': 'concat',
    'train_dir': './Dataset/Albedo/train',
    'test_dir': './Dataset/Albedo/test',
    'dataset_dir': './Dataset',
    'albedo_checkpoint': './checkpoint/magface/albedo/models/best_val_cosine_accuracy_270.pth',
    'depthmap_checkpoint': './checkpoint/magface/depthmap/models/best_val_cosine_accuracy_215.pth',
    'normalmap_checkpoint': './checkpoint/magface/normalmap/models/best_val_cosine_accuracy_195.pth',
    
    # Cấu hình train
    'backbone': 'iresnet18',
    'epochs': 2000,
    'num_workers': 4,
    'batch_size': 16,
    'image_size': 224,
    'num_class': len(os.listdir('./Dataset/Albedo/train')),
    'embedding_size': 512,
    'num_cpus': 10,
    
    'learning_rate': 0.1,
    'weight_decay': 5e-4,
    'momentum': 0.9,
    'alpha': 0.9,
    
    # Hàm m(ai) giúp thay đổi ai từ 0.25 đến 1.6
    'scale': 64,
    'lambda_g': 20,
    'l_margin': 0.45, 
    'u_margin': 0.8,
    'l_a': 10, 
    'u_a': 110,
}

train_transform = A.Compose([
    A.RandomCrop(CONFIGURATION['image_size'],CONFIGURATION['image_size'])
], additional_targets={
    'depthmap': 'image',
    'normalmap': 'image'   
})

test_transform = A.Compose([
    A.Resize(CONFIGURATION['image_size'], CONFIGURATION['image_size'], always_apply=True)
], additional_targets={
    'depthmap': 'image',
    'normalmap': 'image'
})

train_dataloader, val_dataloader = create_concat_magface_dataloader(CONFIGURATION, train_transform, test_transform)

# %%
model = MagFaceConcatRecognition(CONFIGURATION).to(device)
criterion = MagLoss(conf = CONFIGURATION)

optimizer = torch.optim.Adam(model.parameters(), lr=CONFIGURATION['learning_rate'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=1, eta_min=1e-6)
checkpoint_path = os.path.abspath('checkpoint/magface/'+ CONFIGURATION['type'] + '/models/checkpoint.pth')
modle_checkpoint = ModelCheckpoint(filepath=checkpoint_path, verbose=1)
earlystop_dir = os.path.abspath('checkpoint/magface/'+ CONFIGURATION['type'] + '/models')
early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['val_euclidean_accuracy', 'val_cosine_accuracy', 'val_auc_euclidean', 'val_auc_cosine'],
    patience=40,
    mode='max',
    verbose=1,
    save_dir=earlystop_dir,
    start_from_epoch=0
)

# %% [markdown]
# 29s: Generate finish

# %%
fit(CONFIGURATION, 0, model, device, train_dataloader, val_dataloader, criterion, optimizer, scheduler, early_stopping, modle_checkpoint)
# Out:
# Epoch 1:
# 	train: loss 3.022 | loss id   3.00 | top_1_acc 0.4454 | top_5_acc 0.5747 | acc_eu: 0.967 | acc_cos: 0.968 | auc_eu: 0.994 | auc_cos: 0.997
# 	val: acc_eu: 0.806 | acc_cos: 0.769 | auc_eu: 0.821 | auc_cos: 0.876
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 2:
# 	train: loss 1.836 | loss id   1.81 | top_1_acc 0.8759 | top_5_acc 0.9537 | acc_eu: 0.983 | acc_cos: 0.993 | auc_eu: 0.998 | auc_cos: 1.000
# 	val: acc_eu: 0.798 | acc_cos: 0.835 | auc_eu: 0.832 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 3:
# 	train: loss 1.287 | loss id   1.26 | top_1_acc 0.9671 | top_5_acc 0.9880 | acc_eu: 0.985 | acc_cos: 0.995 | auc_eu: 0.998 | auc_cos: 1.000
# 	val: acc_eu: 0.804 | acc_cos: 0.804 | auc_eu: 0.833 | auc_cos: 0.918
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 4:
# 	train: loss 1.072 | loss id   1.05 | top_1_acc 0.9873 | top_5_acc 0.9963 | acc_eu: 0.989 | acc_cos: 0.996 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.715 | acc_cos: 0.856 | auc_eu: 0.829 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 5:
# 	train: loss 0.912 | loss id   0.89 | top_1_acc 0.9948 | top_5_acc 1.0000 | acc_eu: 0.992 | acc_cos: 0.998 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.748 | acc_cos: 0.908 | auc_eu: 0.823 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 6:
# 	train: loss 0.834 | loss id   0.81 | top_1_acc 0.9948 | top_5_acc 1.0000 | acc_eu: 0.989 | acc_cos: 0.998 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.748 | acc_cos: 0.913 | auc_eu: 0.825 | auc_cos: 0.903
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 7:
# 	train: loss 0.748 | loss id   0.72 | top_1_acc 0.9970 | top_5_acc 1.0000 | acc_eu: 0.990 | acc_cos: 0.999 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.758 | acc_cos: 0.925 | auc_eu: 0.825 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 8:
# 	train: loss 0.692 | loss id   0.67 | top_1_acc 0.9970 | top_5_acc 1.0000 | acc_eu: 0.993 | acc_cos: 0.999 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.755 | acc_cos: 0.887 | auc_eu: 0.828 | auc_cos: 0.910
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 9:
# 	train: loss 0.650 | loss id   0.63 | top_1_acc 0.9985 | top_5_acc 1.0000 | acc_eu: 0.991 | acc_cos: 0.999 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.841 | acc_cos: 0.930 | auc_eu: 0.827 | auc_cos: 0.910
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 10:
# 	train: loss 0.633 | loss id   0.61 | top_1_acc 0.9978 | top_5_acc 1.0000 | acc_eu: 0.993 | acc_cos: 0.998 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.771 | acc_cos: 0.938 | auc_eu: 0.826 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 11:
# 	train: loss 0.874 | loss id   0.85 | top_1_acc 0.9978 | top_5_acc 1.0000 | acc_eu: 0.984 | acc_cos: 0.998 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.831 | acc_cos: 0.950 | auc_eu: 0.830 | auc_cos: 0.910
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 12:
# 	train: loss 0.884 | loss id   0.86 | top_1_acc 0.9978 | top_5_acc 0.9993 | acc_eu: 0.994 | acc_cos: 0.997 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.866 | acc_cos: 0.948 | auc_eu: 0.834 | auc_cos: 0.916
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 13:
# 	train: loss 0.830 | loss id   0.81 | top_1_acc 0.9978 | top_5_acc 1.0000 | acc_eu: 0.994 | acc_cos: 0.998 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.836 | acc_cos: 0.915 | auc_eu: 0.831 | auc_cos: 0.912
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 14:
# 	train: loss 0.738 | loss id   0.71 | top_1_acc 0.9993 | top_5_acc 1.0000 | acc_eu: 0.993 | acc_cos: 0.999 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.813 | acc_cos: 0.938 | auc_eu: 0.836 | auc_cos: 0.911
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 15:
# 	train: loss 0.665 | loss id   0.64 | top_1_acc 0.9993 | top_5_acc 1.0000 | acc_eu: 0.996 | acc_cos: 0.999 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.852 | acc_cos: 0.938 | auc_eu: 0.831 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 16:
# 	train: loss 0.623 | loss id   0.60 | top_1_acc 0.9978 | top_5_acc 1.0000 | acc_eu: 0.993 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.830 | acc_cos: 0.885 | auc_eu: 0.831 | auc_cos: 0.915
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 17:
# 	train: loss 0.553 | loss id   0.53 | top_1_acc 0.9993 | top_5_acc 1.0000 | acc_eu: 0.993 | acc_cos: 0.999 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.814 | acc_cos: 0.898 | auc_eu: 0.828 | auc_cos: 0.911
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 18:
# 	train: loss 0.519 | loss id   0.50 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.995 | acc_cos: 0.999 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.799 | acc_cos: 0.917 | auc_eu: 0.835 | auc_cos: 0.914
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 19:
# 	train: loss 0.478 | loss id   0.46 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.995 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.851 | acc_cos: 0.901 | auc_eu: 0.831 | auc_cos: 0.913
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 20:
# 	train: loss 0.469 | loss id   0.45 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.995 | acc_cos: 0.999 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.854 | acc_cos: 0.912 | auc_eu: 0.829 | auc_cos: 0.912
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 21:
# 	train: loss 0.634 | loss id   0.61 | top_1_acc 0.9985 | top_5_acc 1.0000 | acc_eu: 0.996 | acc_cos: 0.999 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.766 | acc_cos: 0.911 | auc_eu: 0.831 | auc_cos: 0.908
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 22:
# 	train: loss 0.684 | loss id   0.66 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.995 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.835 | acc_cos: 0.936 | auc_eu: 0.833 | auc_cos: 0.914
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 23:
# 	train: loss 0.622 | loss id   0.60 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.994 | acc_cos: 0.999 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.840 | acc_cos: 0.926 | auc_eu: 0.834 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 24:
# 	train: loss 0.601 | loss id   0.58 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.825 | acc_cos: 0.900 | auc_eu: 0.830 | auc_cos: 0.912
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 25:
# 	train: loss 0.533 | loss id   0.51 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.995 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.855 | acc_cos: 0.922 | auc_eu: 0.821 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 26:
# 	train: loss 0.464 | loss id   0.44 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.800 | acc_cos: 0.925 | auc_eu: 0.825 | auc_cos: 0.910
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 27:
# 	train: loss 0.422 | loss id   0.40 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.820 | acc_cos: 0.907 | auc_eu: 0.825 | auc_cos: 0.913
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 28:
# 	train: loss 0.400 | loss id   0.38 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.806 | acc_cos: 0.908 | auc_eu: 0.829 | auc_cos: 0.915
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 29:
# 	train: loss 0.383 | loss id   0.36 | top_1_acc 0.9993 | top_5_acc 1.0000 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.774 | acc_cos: 0.901 | auc_eu: 0.827 | auc_cos: 0.913
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 30:
# 	train: loss 0.346 | loss id   0.32 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.874 | acc_cos: 0.916 | auc_eu: 0.829 | auc_cos: 0.914
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 31:
# 	train: loss 0.495 | loss id   0.47 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.996 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.741 | acc_cos: 0.868 | auc_eu: 0.824 | auc_cos: 0.908
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 32:
# 	train: loss 0.540 | loss id   0.52 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.755 | acc_cos: 0.946 | auc_eu: 0.814 | auc_cos: 0.899
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 33:
# 	train: loss 0.490 | loss id   0.47 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.909 | acc_cos: 0.912 | auc_eu: 0.826 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 34:
# 	train: loss 0.451 | loss id   0.43 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.866 | acc_cos: 0.908 | auc_eu: 0.821 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 35:
# 	train: loss 0.434 | loss id   0.41 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.876 | acc_cos: 0.900 | auc_eu: 0.820 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 36:
# 	train: loss 0.383 | loss id   0.36 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.860 | acc_cos: 0.931 | auc_eu: 0.815 | auc_cos: 0.908
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 37:
# 	train: loss 0.345 | loss id   0.32 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.865 | acc_cos: 0.926 | auc_eu: 0.817 | auc_cos: 0.903
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 38:
# 	train: loss 0.299 | loss id   0.28 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.846 | acc_cos: 0.917 | auc_eu: 0.824 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 39:
# 	train: loss 0.292 | loss id   0.27 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.879 | acc_cos: 0.913 | auc_eu: 0.823 | auc_cos: 0.914
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 40:
# 	train: loss 0.271 | loss id   0.25 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.793 | acc_cos: 0.916 | auc_eu: 0.815 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 41:
# 	train: loss 0.427 | loss id   0.40 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.995 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.810 | acc_cos: 0.926 | auc_eu: 0.824 | auc_cos: 0.912
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 42:
# 	train: loss 0.436 | loss id   0.41 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.817 | acc_cos: 0.936 | auc_eu: 0.816 | auc_cos: 0.902
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 43:
# 	train: loss 0.406 | loss id   0.38 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.844 | acc_cos: 0.906 | auc_eu: 0.823 | auc_cos: 0.917
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 44:
# 	train: loss 0.382 | loss id   0.36 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.845 | acc_cos: 0.928 | auc_eu: 0.825 | auc_cos: 0.912
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 45:
# 	train: loss 0.347 | loss id   0.32 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.874 | acc_cos: 0.922 | auc_eu: 0.821 | auc_cos: 0.908
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 46:
# 	train: loss 0.298 | loss id   0.28 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.856 | acc_cos: 0.931 | auc_eu: 0.819 | auc_cos: 0.906
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 47:
# 	train: loss 0.269 | loss id   0.25 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.845 | acc_cos: 0.947 | auc_eu: 0.823 | auc_cos: 0.906
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 48:
# 	train: loss 0.250 | loss id   0.23 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.829 | acc_cos: 0.903 | auc_eu: 0.823 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 49:
# 	train: loss 0.235 | loss id   0.21 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.866 | acc_cos: 0.916 | auc_eu: 0.825 | auc_cos: 0.908
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# Epoch 50:
# 	train: loss 0.215 | loss id   0.19 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.882 | acc_cos: 0.918 | auc_eu: 0.826 | auc_cos: 0.913
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 50 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_euclidean_accuracy_50.pth'
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 50 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_cosine_accuracy_50.pth'
# 	Saved best model weights for 'val_auc_euclidean' at epoch 50 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_auc_euclidean_50.pth'
# 	Saved best model weights for 'val_auc_cosine' at epoch 50 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_auc_cosine_50.pth'
# Epoch 51:
# 	train: loss 0.336 | loss id   0.31 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.832 | acc_cos: 0.886 | auc_eu: 0.830 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 51: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 51: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Saved best model weights for 'val_auc_euclidean' at epoch 51 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_auc_euclidean_51.pth'
# 	Epoch 51: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 52:
# 	train: loss 0.381 | loss id   0.36 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.867 | acc_cos: 0.920 | auc_eu: 0.832 | auc_cos: 0.916
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 52: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 52 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_cosine_accuracy_52.pth'
# 	Saved best model weights for 'val_auc_euclidean' at epoch 52 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_auc_euclidean_52.pth'
# 	Saved best model weights for 'val_auc_cosine' at epoch 52 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_auc_cosine_52.pth'
# Epoch 53:
# 	train: loss 0.334 | loss id   0.31 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.831 | acc_cos: 0.931 | auc_eu: 0.826 | auc_cos: 0.908
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 53: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 53 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_cosine_accuracy_53.pth'
# 	Epoch 53: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 53: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 54:
# 	train: loss 0.308 | loss id   0.28 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.856 | acc_cos: 0.875 | auc_eu: 0.836 | auc_cos: 0.916
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 54: EarlyStopping counter for 'val_euclidean_accuracy': 4/40
# 	Epoch 54: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Saved best model weights for 'val_auc_euclidean' at epoch 54 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_auc_euclidean_54.pth'
# 	Saved best model weights for 'val_auc_cosine' at epoch 54 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_auc_cosine_54.pth'
# Epoch 55:
# 	train: loss 0.287 | loss id   0.26 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.887 | acc_cos: 0.895 | auc_eu: 0.835 | auc_cos: 0.910
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 55 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_euclidean_accuracy_55.pth'
# 	Epoch 55: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 55: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 55: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 56:
# 	train: loss 0.233 | loss id   0.21 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.856 | acc_cos: 0.868 | auc_eu: 0.838 | auc_cos: 0.914
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 56: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 56: EarlyStopping counter for 'val_cosine_accuracy': 3/40
# 	Saved best model weights for 'val_auc_euclidean' at epoch 56 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_auc_euclidean_56.pth'
# 	Epoch 56: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 57:
# 	train: loss 0.211 | loss id   0.19 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.829 | acc_cos: 0.910 | auc_eu: 0.832 | auc_cos: 0.910
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 57: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Epoch 57: EarlyStopping counter for 'val_cosine_accuracy': 4/40
# 	Epoch 57: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 57: EarlyStopping counter for 'val_auc_cosine': 3/40
# Epoch 58:
# 	train: loss 0.208 | loss id   0.19 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.851 | acc_cos: 0.926 | auc_eu: 0.830 | auc_cos: 0.912
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 58: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Epoch 58: EarlyStopping counter for 'val_cosine_accuracy': 5/40
# 	Epoch 58: EarlyStopping counter for 'val_auc_euclidean': 2/40
# 	Epoch 58: EarlyStopping counter for 'val_auc_cosine': 4/40
# Epoch 59:
# 	train: loss 0.194 | loss id   0.17 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.885 | acc_cos: 0.884 | auc_eu: 0.830 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 59: EarlyStopping counter for 'val_euclidean_accuracy': 4/40
# 	Epoch 59: EarlyStopping counter for 'val_cosine_accuracy': 6/40
# 	Epoch 59: EarlyStopping counter for 'val_auc_euclidean': 3/40
# 	Epoch 59: EarlyStopping counter for 'val_auc_cosine': 5/40
# Epoch 60:
# 	train: loss 0.174 | loss id   0.15 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.861 | acc_cos: 0.885 | auc_eu: 0.831 | auc_cos: 0.913
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 60: EarlyStopping counter for 'val_euclidean_accuracy': 5/40
# 	Epoch 60: EarlyStopping counter for 'val_cosine_accuracy': 7/40
# 	Epoch 60: EarlyStopping counter for 'val_auc_euclidean': 4/40
# 	Epoch 60: EarlyStopping counter for 'val_auc_cosine': 6/40
# Epoch 61:
# 	train: loss 0.275 | loss id   0.25 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.838 | acc_cos: 0.893 | auc_eu: 0.821 | auc_cos: 0.897
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 61: EarlyStopping counter for 'val_euclidean_accuracy': 6/40
# 	Epoch 61: EarlyStopping counter for 'val_cosine_accuracy': 8/40
# 	Epoch 61: EarlyStopping counter for 'val_auc_euclidean': 5/40
# 	Epoch 61: EarlyStopping counter for 'val_auc_cosine': 7/40
# Epoch 62:
# 	train: loss 0.345 | loss id   0.32 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.820 | acc_cos: 0.880 | auc_eu: 0.826 | auc_cos: 0.906
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 62: EarlyStopping counter for 'val_euclidean_accuracy': 7/40
# 	Epoch 62: EarlyStopping counter for 'val_cosine_accuracy': 9/40
# 	Epoch 62: EarlyStopping counter for 'val_auc_euclidean': 6/40
# 	Epoch 62: EarlyStopping counter for 'val_auc_cosine': 8/40
# Epoch 63:
# 	train: loss 0.312 | loss id   0.29 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.902 | acc_cos: 0.808 | auc_eu: 0.822 | auc_cos: 0.903
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 63 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_euclidean_accuracy_63.pth'
# 	Epoch 63: EarlyStopping counter for 'val_cosine_accuracy': 10/40
# 	Epoch 63: EarlyStopping counter for 'val_auc_euclidean': 7/40
# 	Epoch 63: EarlyStopping counter for 'val_auc_cosine': 9/40
# Epoch 64:
# 	train: loss 0.262 | loss id   0.24 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.873 | acc_cos: 0.887 | auc_eu: 0.837 | auc_cos: 0.913
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 64: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 64: EarlyStopping counter for 'val_cosine_accuracy': 11/40
# 	Epoch 64: EarlyStopping counter for 'val_auc_euclidean': 8/40
# 	Epoch 64: EarlyStopping counter for 'val_auc_cosine': 10/40
# Epoch 65:
# 	train: loss 0.224 | loss id   0.20 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.850 | acc_cos: 0.900 | auc_eu: 0.821 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 65: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Epoch 65: EarlyStopping counter for 'val_cosine_accuracy': 12/40
# 	Epoch 65: EarlyStopping counter for 'val_auc_euclidean': 9/40
# 	Epoch 65: EarlyStopping counter for 'val_auc_cosine': 11/40
# Epoch 66:
# 	train: loss 0.207 | loss id   0.18 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.879 | acc_cos: 0.841 | auc_eu: 0.822 | auc_cos: 0.906
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 66: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Epoch 66: EarlyStopping counter for 'val_cosine_accuracy': 13/40
# 	Epoch 66: EarlyStopping counter for 'val_auc_euclidean': 10/40
# 	Epoch 66: EarlyStopping counter for 'val_auc_cosine': 12/40
# Epoch 67:
# 	train: loss 0.186 | loss id   0.16 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.870 | acc_cos: 0.859 | auc_eu: 0.832 | auc_cos: 0.908
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 67: EarlyStopping counter for 'val_euclidean_accuracy': 4/40
# 	Epoch 67: EarlyStopping counter for 'val_cosine_accuracy': 14/40
# 	Epoch 67: EarlyStopping counter for 'val_auc_euclidean': 11/40
# 	Epoch 67: EarlyStopping counter for 'val_auc_cosine': 13/40
# Epoch 68:
# 	train: loss 0.157 | loss id   0.13 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.853 | acc_cos: 0.901 | auc_eu: 0.824 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 68: EarlyStopping counter for 'val_euclidean_accuracy': 5/40
# 	Epoch 68: EarlyStopping counter for 'val_cosine_accuracy': 15/40
# 	Epoch 68: EarlyStopping counter for 'val_auc_euclidean': 12/40
# 	Epoch 68: EarlyStopping counter for 'val_auc_cosine': 14/40
# Epoch 69:
# 	train: loss 0.152 | loss id   0.13 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.858 | acc_cos: 0.921 | auc_eu: 0.823 | auc_cos: 0.903
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 69: EarlyStopping counter for 'val_euclidean_accuracy': 6/40
# 	Epoch 69: EarlyStopping counter for 'val_cosine_accuracy': 16/40
# 	Epoch 69: EarlyStopping counter for 'val_auc_euclidean': 13/40
# 	Epoch 69: EarlyStopping counter for 'val_auc_cosine': 15/40
# Epoch 70:
# 	train: loss 0.148 | loss id   0.13 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.867 | acc_cos: 0.881 | auc_eu: 0.824 | auc_cos: 0.906
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 70: EarlyStopping counter for 'val_euclidean_accuracy': 7/40
# 	Epoch 70: EarlyStopping counter for 'val_cosine_accuracy': 17/40
# 	Epoch 70: EarlyStopping counter for 'val_auc_euclidean': 14/40
# 	Epoch 70: EarlyStopping counter for 'val_auc_cosine': 16/40
# Epoch 71:
# 	train: loss 0.222 | loss id   0.20 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.853 | acc_cos: 0.881 | auc_eu: 0.823 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 71: EarlyStopping counter for 'val_euclidean_accuracy': 8/40
# 	Epoch 71: EarlyStopping counter for 'val_cosine_accuracy': 18/40
# 	Epoch 71: EarlyStopping counter for 'val_auc_euclidean': 15/40
# 	Epoch 71: EarlyStopping counter for 'val_auc_cosine': 17/40
# Epoch 72:
# 	train: loss 0.265 | loss id   0.24 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.835 | acc_cos: 0.868 | auc_eu: 0.826 | auc_cos: 0.901
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 72: EarlyStopping counter for 'val_euclidean_accuracy': 9/40
# 	Epoch 72: EarlyStopping counter for 'val_cosine_accuracy': 19/40
# 	Epoch 72: EarlyStopping counter for 'val_auc_euclidean': 16/40
# 	Epoch 72: EarlyStopping counter for 'val_auc_cosine': 18/40
# Epoch 73:
# 	train: loss 0.268 | loss id   0.25 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.854 | acc_cos: 0.916 | auc_eu: 0.836 | auc_cos: 0.911
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 73: EarlyStopping counter for 'val_euclidean_accuracy': 10/40
# 	Epoch 73: EarlyStopping counter for 'val_cosine_accuracy': 20/40
# 	Epoch 73: EarlyStopping counter for 'val_auc_euclidean': 17/40
# 	Epoch 73: EarlyStopping counter for 'val_auc_cosine': 19/40
# Epoch 74:
# 	train: loss 0.227 | loss id   0.20 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.852 | acc_cos: 0.852 | auc_eu: 0.829 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 74: EarlyStopping counter for 'val_euclidean_accuracy': 11/40
# 	Epoch 74: EarlyStopping counter for 'val_cosine_accuracy': 21/40
# 	Epoch 74: EarlyStopping counter for 'val_auc_euclidean': 18/40
# 	Epoch 74: EarlyStopping counter for 'val_auc_cosine': 20/40
# Epoch 75:
# 	train: loss 0.211 | loss id   0.19 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.876 | acc_cos: 0.948 | auc_eu: 0.823 | auc_cos: 0.903
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 75: EarlyStopping counter for 'val_euclidean_accuracy': 12/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 75 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_cosine_accuracy_75.pth'
# 	Epoch 75: EarlyStopping counter for 'val_auc_euclidean': 19/40
# 	Epoch 75: EarlyStopping counter for 'val_auc_cosine': 21/40
# Epoch 76:
# 	train: loss 0.166 | loss id   0.14 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.884 | acc_cos: 0.802 | auc_eu: 0.831 | auc_cos: 0.910
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 76: EarlyStopping counter for 'val_euclidean_accuracy': 13/40
# 	Epoch 76: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 76: EarlyStopping counter for 'val_auc_euclidean': 20/40
# 	Epoch 76: EarlyStopping counter for 'val_auc_cosine': 22/40
# Epoch 77:
# 	train: loss 0.152 | loss id   0.13 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.875 | acc_cos: 0.789 | auc_eu: 0.828 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 77: EarlyStopping counter for 'val_euclidean_accuracy': 14/40
# 	Epoch 77: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 77: EarlyStopping counter for 'val_auc_euclidean': 21/40
# 	Epoch 77: EarlyStopping counter for 'val_auc_cosine': 23/40
# Epoch 78:
# 	train: loss 0.135 | loss id   0.11 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.871 | acc_cos: 0.862 | auc_eu: 0.827 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 78: EarlyStopping counter for 'val_euclidean_accuracy': 15/40
# 	Epoch 78: EarlyStopping counter for 'val_cosine_accuracy': 3/40
# 	Epoch 78: EarlyStopping counter for 'val_auc_euclidean': 22/40
# 	Epoch 78: EarlyStopping counter for 'val_auc_cosine': 24/40
# Epoch 79:
# 	train: loss 0.120 | loss id   0.10 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.793 | acc_cos: 0.851 | auc_eu: 0.826 | auc_cos: 0.906
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 79: EarlyStopping counter for 'val_euclidean_accuracy': 16/40
# 	Epoch 79: EarlyStopping counter for 'val_cosine_accuracy': 4/40
# 	Epoch 79: EarlyStopping counter for 'val_auc_euclidean': 23/40
# 	Epoch 79: EarlyStopping counter for 'val_auc_cosine': 25/40
# Epoch 80:
# 	train: loss 0.122 | loss id   0.10 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.867 | acc_cos: 0.963 | auc_eu: 0.826 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 80: EarlyStopping counter for 'val_euclidean_accuracy': 17/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 80 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_cosine_accuracy_80.pth'
# 	Epoch 80: EarlyStopping counter for 'val_auc_euclidean': 24/40
# 	Epoch 80: EarlyStopping counter for 'val_auc_cosine': 26/40
# Epoch 81:
# 	train: loss 0.215 | loss id   0.19 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.844 | acc_cos: 0.809 | auc_eu: 0.822 | auc_cos: 0.901
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 81: EarlyStopping counter for 'val_euclidean_accuracy': 18/40
# 	Epoch 81: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 81: EarlyStopping counter for 'val_auc_euclidean': 25/40
# 	Epoch 81: EarlyStopping counter for 'val_auc_cosine': 27/40
# Epoch 82:
# 	train: loss 0.240 | loss id   0.22 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.792 | acc_cos: 0.937 | auc_eu: 0.836 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 82: EarlyStopping counter for 'val_euclidean_accuracy': 19/40
# 	Epoch 82: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 82: EarlyStopping counter for 'val_auc_euclidean': 26/40
# 	Epoch 82: EarlyStopping counter for 'val_auc_cosine': 28/40
# Epoch 83:
# 	train: loss 0.213 | loss id   0.19 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.811 | acc_cos: 0.813 | auc_eu: 0.819 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 83: EarlyStopping counter for 'val_euclidean_accuracy': 20/40
# 	Epoch 83: EarlyStopping counter for 'val_cosine_accuracy': 3/40
# 	Epoch 83: EarlyStopping counter for 'val_auc_euclidean': 27/40
# 	Epoch 83: EarlyStopping counter for 'val_auc_cosine': 29/40
# Epoch 84:
# 	train: loss 0.196 | loss id   0.17 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.853 | acc_cos: 0.878 | auc_eu: 0.825 | auc_cos: 0.912
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 84: EarlyStopping counter for 'val_euclidean_accuracy': 21/40
# 	Epoch 84: EarlyStopping counter for 'val_cosine_accuracy': 4/40
# 	Epoch 84: EarlyStopping counter for 'val_auc_euclidean': 28/40
# 	Epoch 84: EarlyStopping counter for 'val_auc_cosine': 30/40
# Epoch 85:
# 	train: loss 0.170 | loss id   0.15 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.838 | acc_cos: 0.856 | auc_eu: 0.828 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 85: EarlyStopping counter for 'val_euclidean_accuracy': 22/40
# 	Epoch 85: EarlyStopping counter for 'val_cosine_accuracy': 5/40
# 	Epoch 85: EarlyStopping counter for 'val_auc_euclidean': 29/40
# 	Epoch 85: EarlyStopping counter for 'val_auc_cosine': 31/40
# Epoch 86:
# 	train: loss 0.145 | loss id   0.12 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.857 | acc_cos: 0.801 | auc_eu: 0.821 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 86: EarlyStopping counter for 'val_euclidean_accuracy': 23/40
# 	Epoch 86: EarlyStopping counter for 'val_cosine_accuracy': 6/40
# 	Epoch 86: EarlyStopping counter for 'val_auc_euclidean': 30/40
# 	Epoch 86: EarlyStopping counter for 'val_auc_cosine': 32/40
# Epoch 87:
# 	train: loss 0.126 | loss id   0.10 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.736 | acc_cos: 0.800 | auc_eu: 0.827 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 87: EarlyStopping counter for 'val_euclidean_accuracy': 24/40
# 	Epoch 87: EarlyStopping counter for 'val_cosine_accuracy': 7/40
# 	Epoch 87: EarlyStopping counter for 'val_auc_euclidean': 31/40
# 	Epoch 87: EarlyStopping counter for 'val_auc_cosine': 33/40
# Epoch 88:
# 	train: loss 0.117 | loss id   0.09 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.888 | acc_cos: 0.848 | auc_eu: 0.824 | auc_cos: 0.908
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 88: EarlyStopping counter for 'val_euclidean_accuracy': 25/40
# 	Epoch 88: EarlyStopping counter for 'val_cosine_accuracy': 8/40
# 	Epoch 88: EarlyStopping counter for 'val_auc_euclidean': 32/40
# 	Epoch 88: EarlyStopping counter for 'val_auc_cosine': 34/40
# Epoch 89:
# 	train: loss 0.105 | loss id   0.08 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.865 | acc_cos: 0.880 | auc_eu: 0.825 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 89: EarlyStopping counter for 'val_euclidean_accuracy': 26/40
# 	Epoch 89: EarlyStopping counter for 'val_cosine_accuracy': 9/40
# 	Epoch 89: EarlyStopping counter for 'val_auc_euclidean': 33/40
# 	Epoch 89: EarlyStopping counter for 'val_auc_cosine': 35/40
# Epoch 90:
# 	train: loss 0.101 | loss id   0.08 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.736 | acc_cos: 0.926 | auc_eu: 0.821 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 90: EarlyStopping counter for 'val_euclidean_accuracy': 27/40
# 	Epoch 90: EarlyStopping counter for 'val_cosine_accuracy': 10/40
# 	Epoch 90: EarlyStopping counter for 'val_auc_euclidean': 34/40
# 	Epoch 90: EarlyStopping counter for 'val_auc_cosine': 36/40
# Epoch 91:
# 	train: loss 0.155 | loss id   0.13 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.786 | acc_cos: 0.823 | auc_eu: 0.829 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 91: EarlyStopping counter for 'val_euclidean_accuracy': 28/40
# 	Epoch 91: EarlyStopping counter for 'val_cosine_accuracy': 11/40
# 	Epoch 91: EarlyStopping counter for 'val_auc_euclidean': 35/40
# 	Epoch 91: EarlyStopping counter for 'val_auc_cosine': 37/40
# Epoch 92:
# 	train: loss 0.211 | loss id   0.19 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.912 | acc_cos: 0.831 | auc_eu: 0.834 | auc_cos: 0.910
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 92 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/best_val_euclidean_accuracy_92.pth'
# 	Epoch 92: EarlyStopping counter for 'val_cosine_accuracy': 12/40
# 	Epoch 92: EarlyStopping counter for 'val_auc_euclidean': 36/40
# 	Epoch 92: EarlyStopping counter for 'val_auc_cosine': 38/40
# Epoch 93:
# 	train: loss 0.199 | loss id   0.18 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.824 | acc_cos: 0.896 | auc_eu: 0.827 | auc_cos: 0.902
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 93: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 93: EarlyStopping counter for 'val_cosine_accuracy': 13/40
# 	Epoch 93: EarlyStopping counter for 'val_auc_euclidean': 37/40
# 	Epoch 93: EarlyStopping counter for 'val_auc_cosine': 39/40
# Epoch 94:
# 	train: loss 0.164 | loss id   0.14 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.854 | acc_cos: 0.887 | auc_eu: 0.820 | auc_cos: 0.900
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 94: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Epoch 94: EarlyStopping counter for 'val_cosine_accuracy': 14/40
# 	Epoch 94: EarlyStopping counter for 'val_auc_euclidean': 38/40
# 	Epoch 94: EarlyStopping counter for 'val_auc_cosine': 40/40
# Epoch 95:
# 	train: loss 0.142 | loss id   0.12 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.864 | acc_cos: 0.835 | auc_eu: 0.822 | auc_cos: 0.906
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 95: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Epoch 95: EarlyStopping counter for 'val_cosine_accuracy': 15/40
# 	Epoch 95: EarlyStopping counter for 'val_auc_euclidean': 39/40
# 	Epoch 95: EarlyStopping counter for 'val_auc_cosine': 41/40
# Epoch 96:
# 	train: loss 0.116 | loss id   0.09 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.853 | acc_cos: 0.836 | auc_eu: 0.829 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 96: EarlyStopping counter for 'val_euclidean_accuracy': 4/40
# 	Epoch 96: EarlyStopping counter for 'val_cosine_accuracy': 16/40
# 	Epoch 96: EarlyStopping counter for 'val_auc_euclidean': 40/40
# 	Epoch 96: EarlyStopping counter for 'val_auc_cosine': 42/40
# Epoch 97:
# 	train: loss 0.112 | loss id   0.09 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.833 | acc_cos: 0.867 | auc_eu: 0.820 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 97: EarlyStopping counter for 'val_euclidean_accuracy': 5/40
# 	Epoch 97: EarlyStopping counter for 'val_cosine_accuracy': 17/40
# 	Epoch 97: EarlyStopping counter for 'val_auc_euclidean': 41/40
# 	Epoch 97: EarlyStopping counter for 'val_auc_cosine': 43/40
# Epoch 98:
# 	train: loss 0.087 | loss id   0.06 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.851 | acc_cos: 0.922 | auc_eu: 0.820 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 98: EarlyStopping counter for 'val_euclidean_accuracy': 6/40
# 	Epoch 98: EarlyStopping counter for 'val_cosine_accuracy': 18/40
# 	Epoch 98: EarlyStopping counter for 'val_auc_euclidean': 42/40
# 	Epoch 98: EarlyStopping counter for 'val_auc_cosine': 44/40
# Epoch 99:
# 	train: loss 0.090 | loss id   0.07 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.835 | acc_cos: 0.932 | auc_eu: 0.826 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 99: EarlyStopping counter for 'val_euclidean_accuracy': 7/40
# 	Epoch 99: EarlyStopping counter for 'val_cosine_accuracy': 19/40
# 	Epoch 99: EarlyStopping counter for 'val_auc_euclidean': 43/40
# 	Epoch 99: EarlyStopping counter for 'val_auc_cosine': 45/40
# Epoch 100:
# 	train: loss 0.078 | loss id   0.06 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.849 | acc_cos: 0.785 | auc_eu: 0.820 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 100: EarlyStopping counter for 'val_euclidean_accuracy': 8/40
# 	Epoch 100: EarlyStopping counter for 'val_cosine_accuracy': 20/40
# 	Epoch 100: EarlyStopping counter for 'val_auc_euclidean': 44/40
# 	Epoch 100: EarlyStopping counter for 'val_auc_cosine': 46/40
# Epoch 101:
# 	train: loss 0.133 | loss id   0.11 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.868 | acc_cos: 0.894 | auc_eu: 0.821 | auc_cos: 0.897
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 101: EarlyStopping counter for 'val_euclidean_accuracy': 9/40
# 	Epoch 101: EarlyStopping counter for 'val_cosine_accuracy': 21/40
# 	Epoch 101: EarlyStopping counter for 'val_auc_euclidean': 45/40
# 	Epoch 101: EarlyStopping counter for 'val_auc_cosine': 47/40
# Epoch 102:
# 	train: loss 0.172 | loss id   0.15 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.762 | acc_cos: 0.862 | auc_eu: 0.810 | auc_cos: 0.893
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/concat/models/checkpoint.pth
# 	Epoch 102: EarlyStopping counter for 'val_euclidean_accuracy': 10/40
# 	Epoch 102: EarlyStopping counter for 'val_cosine_accuracy': 22/40
# 	Epoch 102: EarlyStopping counter for 'val_auc_euclidean': 46/40
# 	Epoch 102: EarlyStopping counter for 'val_auc_cosine': 48/40
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fit(CONFIGURATION, 0, model, device, train_dataloader, val_dataloader, criterion, optimizer, scheduler, early_stopping, modle_checkpoint)
#
# File /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/going_modular/train_eval/train.py:69, in fit(conf, start_epoch, model, device, train_dataloader, val_dataloader, criterion, optimizer, scheduler, early_stopping, model_checkpoint)
#      66 train_acc_top1.compute()
#      67 train_acc_top5.compute()
# ---> 69 train_euclidean_accuracy, train_cosine_accuracy, train_auc_euclidean, train_auc_cosine = compute_roc_auc(train_dataloader, model, device)
#      71 val_euclidean_accuracy, val_cosine_accuracy, val_auc_euclidean, val_auc_cosine = compute_roc_auc(val_dataloader, model, device)
#      73 # Ghi các giá trị vào TensorBoard
#
# File /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/going_modular/train_eval/roc_auc.py:45, in compute_roc_auc(dataloader, model, device)
#      43 euclidean_score = F.pairwise_distance(embedding1, embedding2).item()
#      44 # Cosine similarity
# ---> 45 cosine_score = F.cosine_similarity(embedding1.unsqueeze(0), embedding2.unsqueeze(0)).item()
#      47 # Store similarity scores and labels
#      48 euclidean_scores.append(euclidean_score)
#
# KeyboardInterrupt:
