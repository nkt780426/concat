# %%
import os

import torch
from torchinfo import summary
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts

from going_modular.dataloader.magface import create_magface_dataloader
from going_modular.model.MagFaceRecognition import MagFaceRecognition
from going_modular.train_eval.train import fit
from going_modular.loss.MagLoss import MagLoss
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint

device = "cuda" if torch.cuda.is_available() else "cpu"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
CONFIGURATION = {
    # Thư mục
    'type': 'albedo',
    'train_dir': './Dataset/Albedo/train',
    'test_dir': './Dataset/Albedo/test',
    
    # Cấu hình train
    'backbone': 'iresnet34',
    'epochs': 2000,
    'num_workers': 4,
    'batch_size': 16,
    'image_size': 224,
    'num_class': len(os.listdir('./Dataset/Albedo/train')),
    'embedding_size': 512,
    
    'learning_rate': 0.1,
    'weight_decay': 5e-4,
    'momentum': 0.9,
    'alpha': 0.9,
    
    # Hàm m(ai) giúp thay đổi ai từ 0.25 đến 1.6
    'scale': 64,
    'lambda_g': 20,
    'l_margin': 0.45, 
    'u_margin': 0.8,
    'l_a': 10, 
    'u_a': 110,
}

# %%
# Đặt seed toàn cục
seed = 42
torch.manual_seed(seed)

# %%
train_dataloader, val_dataloader = create_magface_dataloader(CONFIGURATION, None, None)

# %%
dataiter = iter(train_dataloader)
images, labels = next(dataiter)
print(f"Labels: {images.shape}")
# Out:
# Labels: torch.Size([16, 3, 224, 224])

# %%
# summary(
#     model=MagFaceRecognition(CONFIGURATION), 
#     verbose=0, 
#     col_width=20, 
#     row_settings=["var_names"],
#     col_names=["input_size", 'output_size', "num_params", "trainable"],
#     input_size=(1,3,224,224)
# )

# %%
model = MagFaceRecognition(CONFIGURATION).to(device)
criterion = MagLoss(conf = CONFIGURATION)

optimizer = torch.optim.Adam(model.parameters(), lr=CONFIGURATION['learning_rate'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=40, T_mult=1, eta_min=1e-6)
checkpoint_path = os.path.abspath('checkpoint/magface/albedo/' + CONFIGURATION['backbone'] + '/models/checkpoint.pth')
modle_checkpoint = ModelCheckpoint(filepath=checkpoint_path, verbose=1)
earlystop_dir = os.path.abspath('checkpoint/magface/albedo/' + CONFIGURATION['backbone'] + '/models')
early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['val_euclidean_accuracy', 'val_cosine_accuracy', 'val_auc_euclidean', 'val_auc_cosine'],
    patience=40,
    mode='max',
    verbose=1,
    save_dir=earlystop_dir,
    start_from_epoch=60
)

# %%
fit(CONFIGURATION, 0, model, device, train_dataloader, val_dataloader, criterion, optimizer, scheduler, early_stopping, modle_checkpoint)
# Out:
# Epoch 1:
# 	train: loss 3.796 | loss id   3.77 | top_1_acc 0.0015 | top_5_acc 0.0247 | acc_eu: 0.705 | acc_cos: 0.348 | auc_eu: 0.581 | auc_cos: 0.553
# 	val: acc_eu: 0.708 | acc_cos: 0.302 | auc_eu: 0.592 | auc_cos: 0.558
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 2:
# 	train: loss 3.096 | loss id   3.07 | top_1_acc 0.0097 | top_5_acc 0.0381 | acc_eu: 0.636 | acc_cos: 0.152 | auc_eu: 0.585 | auc_cos: 0.517
# 	val: acc_eu: 0.787 | acc_cos: 0.142 | auc_eu: 0.621 | auc_cos: 0.510
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 3:
# 	train: loss 0.661 | loss id   0.64 | top_1_acc 0.0052 | top_5_acc 0.0277 | acc_eu: 0.615 | acc_cos: 0.333 | auc_eu: 0.581 | auc_cos: 0.547
# 	val: acc_eu: 0.791 | acc_cos: 0.414 | auc_eu: 0.603 | auc_cos: 0.537
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 4:
# 	train: loss 0.538 | loss id   0.51 | top_1_acc 0.0052 | top_5_acc 0.0314 | acc_eu: 0.528 | acc_cos: 0.302 | auc_eu: 0.582 | auc_cos: 0.585
# 	val: acc_eu: 0.737 | acc_cos: 0.280 | auc_eu: 0.600 | auc_cos: 0.611
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 5:
# 	train: loss 0.506 | loss id   0.48 | top_1_acc 0.0127 | top_5_acc 0.0433 | acc_eu: 0.457 | acc_cos: 0.432 | auc_eu: 0.608 | auc_cos: 0.630
# 	val: acc_eu: 0.579 | acc_cos: 0.591 | auc_eu: 0.660 | auc_cos: 0.675
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 6:
# 	train: loss 0.517 | loss id   0.49 | top_1_acc 0.0075 | top_5_acc 0.0359 | acc_eu: 0.408 | acc_cos: 0.363 | auc_eu: 0.619 | auc_cos: 0.645
# 	val: acc_eu: 0.617 | acc_cos: 0.546 | auc_eu: 0.657 | auc_cos: 0.690
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 7:
# 	train: loss 0.455 | loss id   0.43 | top_1_acc 0.0142 | top_5_acc 0.0531 | acc_eu: 0.394 | acc_cos: 0.435 | auc_eu: 0.640 | auc_cos: 0.663
# 	val: acc_eu: 0.515 | acc_cos: 0.648 | auc_eu: 0.690 | auc_cos: 0.714
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 8:
# 	train: loss 0.480 | loss id   0.46 | top_1_acc 0.0090 | top_5_acc 0.0501 | acc_eu: 0.515 | acc_cos: 0.448 | auc_eu: 0.655 | auc_cos: 0.670
# 	val: acc_eu: 0.679 | acc_cos: 0.690 | auc_eu: 0.716 | auc_cos: 0.728
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 9:
# 	train: loss 0.445 | loss id   0.42 | top_1_acc 0.0112 | top_5_acc 0.0486 | acc_eu: 0.485 | acc_cos: 0.456 | auc_eu: 0.650 | auc_cos: 0.676
# 	val: acc_eu: 0.628 | acc_cos: 0.596 | auc_eu: 0.701 | auc_cos: 0.734
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 10:
# 	train: loss 0.455 | loss id   0.43 | top_1_acc 0.0142 | top_5_acc 0.0441 | acc_eu: 0.452 | acc_cos: 0.436 | auc_eu: 0.658 | auc_cos: 0.689
# 	val: acc_eu: 0.614 | acc_cos: 0.638 | auc_eu: 0.704 | auc_cos: 0.735
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 11:
# 	train: loss 0.489 | loss id   0.47 | top_1_acc 0.0082 | top_5_acc 0.0605 | acc_eu: 0.662 | acc_cos: 0.651 | auc_eu: 0.669 | auc_cos: 0.675
# 	val: acc_eu: 0.604 | acc_cos: 0.597 | auc_eu: 0.732 | auc_cos: 0.740
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 12:
# 	train: loss 0.478 | loss id   0.45 | top_1_acc 0.0142 | top_5_acc 0.0605 | acc_eu: 0.459 | acc_cos: 0.495 | auc_eu: 0.658 | auc_cos: 0.703
# 	val: acc_eu: 0.643 | acc_cos: 0.630 | auc_eu: 0.705 | auc_cos: 0.764
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 13:
# 	train: loss 0.509 | loss id   0.49 | top_1_acc 0.0179 | top_5_acc 0.0695 | acc_eu: 0.395 | acc_cos: 0.570 | auc_eu: 0.665 | auc_cos: 0.712
# 	val: acc_eu: 0.771 | acc_cos: 0.748 | auc_eu: 0.709 | auc_cos: 0.773
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 14:
# 	train: loss 0.446 | loss id   0.42 | top_1_acc 0.0135 | top_5_acc 0.0613 | acc_eu: 0.481 | acc_cos: 0.457 | auc_eu: 0.663 | auc_cos: 0.662
# 	val: acc_eu: 0.564 | acc_cos: 0.713 | auc_eu: 0.714 | auc_cos: 0.696
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 15:
# 	train: loss 0.477 | loss id   0.45 | top_1_acc 0.0194 | top_5_acc 0.0703 | acc_eu: 0.581 | acc_cos: 0.596 | auc_eu: 0.695 | auc_cos: 0.718
# 	val: acc_eu: 0.722 | acc_cos: 0.673 | auc_eu: 0.748 | auc_cos: 0.758
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 16:
# 	train: loss 0.533 | loss id   0.51 | top_1_acc 0.0277 | top_5_acc 0.0942 | acc_eu: 0.506 | acc_cos: 0.620 | auc_eu: 0.702 | auc_cos: 0.725
# 	val: acc_eu: 0.708 | acc_cos: 0.594 | auc_eu: 0.765 | auc_cos: 0.790
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 17:
# 	train: loss 0.478 | loss id   0.45 | top_1_acc 0.0172 | top_5_acc 0.0964 | acc_eu: 0.497 | acc_cos: 0.581 | auc_eu: 0.691 | auc_cos: 0.728
# 	val: acc_eu: 0.796 | acc_cos: 0.591 | auc_eu: 0.741 | auc_cos: 0.770
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 18:
# 	train: loss 0.510 | loss id   0.49 | top_1_acc 0.0284 | top_5_acc 0.1158 | acc_eu: 0.641 | acc_cos: 0.639 | auc_eu: 0.718 | auc_cos: 0.746
# 	val: acc_eu: 0.841 | acc_cos: 0.819 | auc_eu: 0.774 | auc_cos: 0.783
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 19:
# 	train: loss 0.520 | loss id   0.50 | top_1_acc 0.0254 | top_5_acc 0.1076 | acc_eu: 0.606 | acc_cos: 0.648 | auc_eu: 0.708 | auc_cos: 0.751
# 	val: acc_eu: 0.849 | acc_cos: 0.694 | auc_eu: 0.752 | auc_cos: 0.801
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 20:
# 	train: loss 0.566 | loss id   0.54 | top_1_acc 0.0374 | top_5_acc 0.1495 | acc_eu: 0.701 | acc_cos: 0.705 | auc_eu: 0.742 | auc_cos: 0.791
# 	val: acc_eu: 0.733 | acc_cos: 0.802 | auc_eu: 0.771 | auc_cos: 0.807
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 21:
# 	train: loss 0.514 | loss id   0.49 | top_1_acc 0.0501 | top_5_acc 0.1622 | acc_eu: 0.677 | acc_cos: 0.642 | auc_eu: 0.775 | auc_cos: 0.794
# 	val: acc_eu: 0.769 | acc_cos: 0.546 | auc_eu: 0.828 | auc_cos: 0.825
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 22:
# 	train: loss 0.573 | loss id   0.55 | top_1_acc 0.0381 | top_5_acc 0.1689 | acc_eu: 0.688 | acc_cos: 0.657 | auc_eu: 0.795 | auc_cos: 0.809
# 	val: acc_eu: 0.857 | acc_cos: 0.810 | auc_eu: 0.813 | auc_cos: 0.823
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 23:
# 	train: loss 0.573 | loss id   0.55 | top_1_acc 0.0553 | top_5_acc 0.1943 | acc_eu: 0.716 | acc_cos: 0.715 | auc_eu: 0.783 | auc_cos: 0.794
# 	val: acc_eu: 0.886 | acc_cos: 0.817 | auc_eu: 0.805 | auc_cos: 0.826
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 24:
# 	train: loss 0.570 | loss id   0.55 | top_1_acc 0.0568 | top_5_acc 0.2048 | acc_eu: 0.744 | acc_cos: 0.720 | auc_eu: 0.776 | auc_cos: 0.786
# 	val: acc_eu: 0.912 | acc_cos: 0.861 | auc_eu: 0.801 | auc_cos: 0.811
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 25:
# 	train: loss 0.530 | loss id   0.51 | top_1_acc 0.0665 | top_5_acc 0.2369 | acc_eu: 0.770 | acc_cos: 0.759 | auc_eu: 0.765 | auc_cos: 0.811
# 	val: acc_eu: 0.898 | acc_cos: 0.837 | auc_eu: 0.797 | auc_cos: 0.829
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 26:
# 	train: loss 0.566 | loss id   0.54 | top_1_acc 0.0822 | top_5_acc 0.2564 | acc_eu: 0.709 | acc_cos: 0.711 | auc_eu: 0.804 | auc_cos: 0.803
# 	val: acc_eu: 0.806 | acc_cos: 0.777 | auc_eu: 0.837 | auc_cos: 0.826
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 27:
# 	train: loss 0.527 | loss id   0.50 | top_1_acc 0.0792 | top_5_acc 0.2466 | acc_eu: 0.729 | acc_cos: 0.697 | auc_eu: 0.800 | auc_cos: 0.826
# 	val: acc_eu: 0.850 | acc_cos: 0.790 | auc_eu: 0.837 | auc_cos: 0.843
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 28:
# 	train: loss 0.532 | loss id   0.51 | top_1_acc 0.0874 | top_5_acc 0.2623 | acc_eu: 0.765 | acc_cos: 0.733 | auc_eu: 0.827 | auc_cos: 0.846
# 	val: acc_eu: 0.870 | acc_cos: 0.859 | auc_eu: 0.848 | auc_cos: 0.857
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 29:
# 	train: loss 0.524 | loss id   0.50 | top_1_acc 0.0800 | top_5_acc 0.2810 | acc_eu: 0.753 | acc_cos: 0.712 | auc_eu: 0.828 | auc_cos: 0.851
# 	val: acc_eu: 0.849 | acc_cos: 0.895 | auc_eu: 0.840 | auc_cos: 0.849
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 30:
# 	train: loss 0.542 | loss id   0.52 | top_1_acc 0.0777 | top_5_acc 0.2870 | acc_eu: 0.804 | acc_cos: 0.757 | auc_eu: 0.848 | auc_cos: 0.862
# 	val: acc_eu: 0.888 | acc_cos: 0.817 | auc_eu: 0.860 | auc_cos: 0.864
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 31:
# 	train: loss 0.548 | loss id   0.53 | top_1_acc 0.1061 | top_5_acc 0.3109 | acc_eu: 0.755 | acc_cos: 0.776 | auc_eu: 0.830 | auc_cos: 0.852
# 	val: acc_eu: 0.906 | acc_cos: 0.805 | auc_eu: 0.855 | auc_cos: 0.861
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 32:
# 	train: loss 0.530 | loss id   0.51 | top_1_acc 0.1069 | top_5_acc 0.3378 | acc_eu: 0.788 | acc_cos: 0.731 | auc_eu: 0.745 | auc_cos: 0.805
# 	val: acc_eu: 0.811 | acc_cos: 0.711 | auc_eu: 0.800 | auc_cos: 0.849
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 33:
# 	train: loss 0.513 | loss id   0.49 | top_1_acc 0.1158 | top_5_acc 0.3303 | acc_eu: 0.771 | acc_cos: 0.770 | auc_eu: 0.821 | auc_cos: 0.863
# 	val: acc_eu: 0.826 | acc_cos: 0.891 | auc_eu: 0.828 | auc_cos: 0.856
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 34:
# 	train: loss 0.562 | loss id   0.54 | top_1_acc 0.1338 | top_5_acc 0.3789 | acc_eu: 0.751 | acc_cos: 0.747 | auc_eu: 0.845 | auc_cos: 0.858
# 	val: acc_eu: 0.790 | acc_cos: 0.857 | auc_eu: 0.880 | auc_cos: 0.865
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 35:
# 	train: loss 0.469 | loss id   0.45 | top_1_acc 0.1248 | top_5_acc 0.3602 | acc_eu: 0.772 | acc_cos: 0.790 | auc_eu: 0.866 | auc_cos: 0.882
# 	val: acc_eu: 0.855 | acc_cos: 0.755 | auc_eu: 0.873 | auc_cos: 0.870
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 36:
# 	train: loss 0.511 | loss id   0.49 | top_1_acc 0.1465 | top_5_acc 0.4133 | acc_eu: 0.745 | acc_cos: 0.788 | auc_eu: 0.850 | auc_cos: 0.884
# 	val: acc_eu: 0.783 | acc_cos: 0.773 | auc_eu: 0.849 | auc_cos: 0.867
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 37:
# 	train: loss 0.544 | loss id   0.52 | top_1_acc 0.1764 | top_5_acc 0.4148 | acc_eu: 0.781 | acc_cos: 0.798 | auc_eu: 0.864 | auc_cos: 0.899
# 	val: acc_eu: 0.865 | acc_cos: 0.838 | auc_eu: 0.860 | auc_cos: 0.886
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 38:
# 	train: loss 0.509 | loss id   0.49 | top_1_acc 0.1584 | top_5_acc 0.4275 | acc_eu: 0.820 | acc_cos: 0.812 | auc_eu: 0.880 | auc_cos: 0.905
# 	val: acc_eu: 0.896 | acc_cos: 0.825 | auc_eu: 0.847 | auc_cos: 0.881
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 39:
# 	train: loss 0.513 | loss id   0.49 | top_1_acc 0.1846 | top_5_acc 0.4581 | acc_eu: 0.788 | acc_cos: 0.825 | auc_eu: 0.873 | auc_cos: 0.911
# 	val: acc_eu: 0.862 | acc_cos: 0.932 | auc_eu: 0.857 | auc_cos: 0.898
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 40:
# 	train: loss 0.485 | loss id   0.46 | top_1_acc 0.1966 | top_5_acc 0.4963 | acc_eu: 0.786 | acc_cos: 0.820 | auc_eu: 0.854 | auc_cos: 0.910
# 	val: acc_eu: 0.932 | acc_cos: 0.766 | auc_eu: 0.842 | auc_cos: 0.897
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 41:
# 	train: loss 0.549 | loss id   0.53 | top_1_acc 0.2392 | top_5_acc 0.5389 | acc_eu: 0.780 | acc_cos: 0.810 | auc_eu: 0.830 | auc_cos: 0.887
# 	val: acc_eu: 0.921 | acc_cos: 0.876 | auc_eu: 0.814 | auc_cos: 0.886
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 42:
# 	train: loss 0.452 | loss id   0.43 | top_1_acc 0.2257 | top_5_acc 0.5703 | acc_eu: 0.810 | acc_cos: 0.811 | auc_eu: 0.868 | auc_cos: 0.893
# 	val: acc_eu: 0.869 | acc_cos: 0.855 | auc_eu: 0.870 | auc_cos: 0.890
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 43:
# 	train: loss 0.511 | loss id   0.49 | top_1_acc 0.2638 | top_5_acc 0.6099 | acc_eu: 0.798 | acc_cos: 0.808 | auc_eu: 0.837 | auc_cos: 0.871
# 	val: acc_eu: 0.831 | acc_cos: 0.864 | auc_eu: 0.850 | auc_cos: 0.891
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 44:
# 	train: loss 0.476 | loss id   0.45 | top_1_acc 0.2608 | top_5_acc 0.5912 | acc_eu: 0.815 | acc_cos: 0.795 | auc_eu: 0.887 | auc_cos: 0.913
# 	val: acc_eu: 0.957 | acc_cos: 0.911 | auc_eu: 0.867 | auc_cos: 0.893
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 45:
# 	train: loss 0.562 | loss id   0.54 | top_1_acc 0.3019 | top_5_acc 0.6315 | acc_eu: 0.826 | acc_cos: 0.834 | auc_eu: 0.871 | auc_cos: 0.915
# 	val: acc_eu: 0.834 | acc_cos: 0.844 | auc_eu: 0.869 | auc_cos: 0.911
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 46:
# 	train: loss 0.461 | loss id   0.44 | top_1_acc 0.3445 | top_5_acc 0.6659 | acc_eu: 0.823 | acc_cos: 0.841 | auc_eu: 0.868 | auc_cos: 0.911
# 	val: acc_eu: 0.889 | acc_cos: 0.813 | auc_eu: 0.844 | auc_cos: 0.884
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 47:
# 	train: loss 0.477 | loss id   0.45 | top_1_acc 0.3587 | top_5_acc 0.7033 | acc_eu: 0.856 | acc_cos: 0.856 | auc_eu: 0.899 | auc_cos: 0.929
# 	val: acc_eu: 0.812 | acc_cos: 0.869 | auc_eu: 0.872 | auc_cos: 0.907
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 48:
# 	train: loss 0.487 | loss id   0.46 | top_1_acc 0.3483 | top_5_acc 0.7048 | acc_eu: 0.859 | acc_cos: 0.842 | auc_eu: 0.914 | auc_cos: 0.939
# 	val: acc_eu: 0.881 | acc_cos: 0.848 | auc_eu: 0.888 | auc_cos: 0.911
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 49:
# 	train: loss 0.498 | loss id   0.47 | top_1_acc 0.3969 | top_5_acc 0.7496 | acc_eu: 0.860 | acc_cos: 0.859 | auc_eu: 0.933 | auc_cos: 0.946
# 	val: acc_eu: 0.904 | acc_cos: 0.927 | auc_eu: 0.896 | auc_cos: 0.915
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 50:
# 	train: loss 0.479 | loss id   0.46 | top_1_acc 0.4297 | top_5_acc 0.7773 | acc_eu: 0.843 | acc_cos: 0.867 | auc_eu: 0.936 | auc_cos: 0.947
# 	val: acc_eu: 0.912 | acc_cos: 0.861 | auc_eu: 0.902 | auc_cos: 0.922
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 51:
# 	train: loss 0.514 | loss id   0.49 | top_1_acc 0.4066 | top_5_acc 0.7504 | acc_eu: 0.844 | acc_cos: 0.832 | auc_eu: 0.889 | auc_cos: 0.922
# 	val: acc_eu: 0.806 | acc_cos: 0.930 | auc_eu: 0.860 | auc_cos: 0.888
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 52:
# 	train: loss 0.439 | loss id   0.42 | top_1_acc 0.4753 | top_5_acc 0.7982 | acc_eu: 0.826 | acc_cos: 0.816 | auc_eu: 0.908 | auc_cos: 0.921
# 	val: acc_eu: 0.795 | acc_cos: 0.875 | auc_eu: 0.882 | auc_cos: 0.906
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 53:
# 	train: loss 0.440 | loss id   0.42 | top_1_acc 0.4626 | top_5_acc 0.8094 | acc_eu: 0.835 | acc_cos: 0.790 | auc_eu: 0.891 | auc_cos: 0.903
# 	val: acc_eu: 0.839 | acc_cos: 0.886 | auc_eu: 0.884 | auc_cos: 0.885
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 54:
# 	train: loss 0.491 | loss id   0.47 | top_1_acc 0.4880 | top_5_acc 0.8176 | acc_eu: 0.867 | acc_cos: 0.846 | auc_eu: 0.928 | auc_cos: 0.941
# 	val: acc_eu: 0.788 | acc_cos: 0.842 | auc_eu: 0.876 | auc_cos: 0.898
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 55:
# 	train: loss 0.430 | loss id   0.41 | top_1_acc 0.4791 | top_5_acc 0.8019 | acc_eu: 0.837 | acc_cos: 0.837 | auc_eu: 0.923 | auc_cos: 0.928
# 	val: acc_eu: 0.822 | acc_cos: 0.917 | auc_eu: 0.891 | auc_cos: 0.891
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 56:
# 	train: loss 0.431 | loss id   0.41 | top_1_acc 0.4933 | top_5_acc 0.8191 | acc_eu: 0.862 | acc_cos: 0.859 | auc_eu: 0.934 | auc_cos: 0.944
# 	val: acc_eu: 0.893 | acc_cos: 0.876 | auc_eu: 0.878 | auc_cos: 0.896
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 57:
# 	train: loss 0.470 | loss id   0.45 | top_1_acc 0.4940 | top_5_acc 0.8326 | acc_eu: 0.858 | acc_cos: 0.863 | auc_eu: 0.935 | auc_cos: 0.943
# 	val: acc_eu: 0.873 | acc_cos: 0.847 | auc_eu: 0.880 | auc_cos: 0.903
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 58:
# 	train: loss 0.450 | loss id   0.43 | top_1_acc 0.5433 | top_5_acc 0.8700 | acc_eu: 0.875 | acc_cos: 0.871 | auc_eu: 0.941 | auc_cos: 0.958
# 	val: acc_eu: 0.892 | acc_cos: 0.876 | auc_eu: 0.884 | auc_cos: 0.907
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 59:
# 	train: loss 0.527 | loss id   0.50 | top_1_acc 0.5254 | top_5_acc 0.8520 | acc_eu: 0.882 | acc_cos: 0.884 | auc_eu: 0.942 | auc_cos: 0.956
# 	val: acc_eu: 0.845 | acc_cos: 0.903 | auc_eu: 0.892 | auc_cos: 0.917
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# Epoch 60:
# 	train: loss 0.512 | loss id   0.49 | top_1_acc 0.5329 | top_5_acc 0.8475 | acc_eu: 0.880 | acc_cos: 0.865 | auc_eu: 0.943 | auc_cos: 0.950
# 	val: acc_eu: 0.859 | acc_cos: 0.864 | auc_eu: 0.894 | auc_cos: 0.920
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 60 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_euclidean_accuracy_60.pth'
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 60 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_cosine_accuracy_60.pth'
# 	Saved best model weights for 'val_auc_euclidean' at epoch 60 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_auc_euclidean_60.pth'
# 	Saved best model weights for 'val_auc_cosine' at epoch 60 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_auc_cosine_60.pth'
# Epoch 61:
# 	train: loss 0.459 | loss id   0.44 | top_1_acc 0.5501 | top_5_acc 0.8580 | acc_eu: 0.853 | acc_cos: 0.860 | auc_eu: 0.916 | auc_cos: 0.936
# 	val: acc_eu: 0.857 | acc_cos: 0.891 | auc_eu: 0.874 | auc_cos: 0.901
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 61: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 61 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_cosine_accuracy_61.pth'
# 	Epoch 61: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 61: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 62:
# 	train: loss 0.541 | loss id   0.52 | top_1_acc 0.5957 | top_5_acc 0.8849 | acc_eu: 0.831 | acc_cos: 0.834 | auc_eu: 0.908 | auc_cos: 0.912
# 	val: acc_eu: 0.884 | acc_cos: 0.858 | auc_eu: 0.854 | auc_cos: 0.863
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 62 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_euclidean_accuracy_62.pth'
# 	Epoch 62: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 62: EarlyStopping counter for 'val_auc_euclidean': 2/40
# 	Epoch 62: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 63:
# 	train: loss 0.530 | loss id   0.51 | top_1_acc 0.6039 | top_5_acc 0.9051 | acc_eu: 0.867 | acc_cos: 0.872 | auc_eu: 0.942 | auc_cos: 0.948
# 	val: acc_eu: 0.753 | acc_cos: 0.805 | auc_eu: 0.878 | auc_cos: 0.884
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 63: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 63: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 63: EarlyStopping counter for 'val_auc_euclidean': 3/40
# 	Epoch 63: EarlyStopping counter for 'val_auc_cosine': 3/40
# Epoch 64:
# 	train: loss 0.614 | loss id   0.59 | top_1_acc 0.5800 | top_5_acc 0.8737 | acc_eu: 0.841 | acc_cos: 0.858 | auc_eu: 0.897 | auc_cos: 0.924
# 	val: acc_eu: 0.831 | acc_cos: 0.910 | auc_eu: 0.852 | auc_cos: 0.883
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 64: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 64 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_cosine_accuracy_64.pth'
# 	Epoch 64: EarlyStopping counter for 'val_auc_euclidean': 4/40
# 	Epoch 64: EarlyStopping counter for 'val_auc_cosine': 4/40
# Epoch 65:
# 	train: loss 0.600 | loss id   0.58 | top_1_acc 0.5874 | top_5_acc 0.8871 | acc_eu: 0.887 | acc_cos: 0.874 | auc_eu: 0.934 | auc_cos: 0.935
# 	val: acc_eu: 0.812 | acc_cos: 0.828 | auc_eu: 0.860 | auc_cos: 0.876
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 65: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Epoch 65: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 65: EarlyStopping counter for 'val_auc_euclidean': 5/40
# 	Epoch 65: EarlyStopping counter for 'val_auc_cosine': 5/40
# Epoch 66:
# 	train: loss 0.753 | loss id   0.73 | top_1_acc 0.5815 | top_5_acc 0.8842 | acc_eu: 0.888 | acc_cos: 0.860 | auc_eu: 0.914 | auc_cos: 0.924
# 	val: acc_eu: 0.938 | acc_cos: 0.849 | auc_eu: 0.859 | auc_cos: 0.878
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 66 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_euclidean_accuracy_66.pth'
# 	Epoch 66: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 66: EarlyStopping counter for 'val_auc_euclidean': 6/40
# 	Epoch 66: EarlyStopping counter for 'val_auc_cosine': 6/40
# Epoch 67:
# 	train: loss 0.668 | loss id   0.64 | top_1_acc 0.6278 | top_5_acc 0.9028 | acc_eu: 0.879 | acc_cos: 0.868 | auc_eu: 0.952 | auc_cos: 0.952
# 	val: acc_eu: 0.905 | acc_cos: 0.844 | auc_eu: 0.885 | auc_cos: 0.906
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 67: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 67: EarlyStopping counter for 'val_cosine_accuracy': 3/40
# 	Epoch 67: EarlyStopping counter for 'val_auc_euclidean': 7/40
# 	Epoch 67: EarlyStopping counter for 'val_auc_cosine': 7/40
# Epoch 68:
# 	train: loss 0.769 | loss id   0.75 | top_1_acc 0.6413 | top_5_acc 0.9051 | acc_eu: 0.875 | acc_cos: 0.874 | auc_eu: 0.951 | auc_cos: 0.949
# 	val: acc_eu: 0.834 | acc_cos: 0.867 | auc_eu: 0.880 | auc_cos: 0.883
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 68: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Epoch 68: EarlyStopping counter for 'val_cosine_accuracy': 4/40
# 	Epoch 68: EarlyStopping counter for 'val_auc_euclidean': 8/40
# 	Epoch 68: EarlyStopping counter for 'val_auc_cosine': 8/40
# Epoch 69:
# 	train: loss 0.939 | loss id   0.92 | top_1_acc 0.6076 | top_5_acc 0.8894 | acc_eu: 0.883 | acc_cos: 0.878 | auc_eu: 0.937 | auc_cos: 0.939
# 	val: acc_eu: 0.830 | acc_cos: 0.798 | auc_eu: 0.849 | auc_cos: 0.881
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 69: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Epoch 69: EarlyStopping counter for 'val_cosine_accuracy': 5/40
# 	Epoch 69: EarlyStopping counter for 'val_auc_euclidean': 9/40
# 	Epoch 69: EarlyStopping counter for 'val_auc_cosine': 9/40
# Epoch 70:
# 	train: loss 1.182 | loss id   1.16 | top_1_acc 0.6286 | top_5_acc 0.8782 | acc_eu: 0.894 | acc_cos: 0.869 | auc_eu: 0.937 | auc_cos: 0.916
# 	val: acc_eu: 0.917 | acc_cos: 0.906 | auc_eu: 0.851 | auc_cos: 0.844
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 70: EarlyStopping counter for 'val_euclidean_accuracy': 4/40
# 	Epoch 70: EarlyStopping counter for 'val_cosine_accuracy': 6/40
# 	Epoch 70: EarlyStopping counter for 'val_auc_euclidean': 10/40
# 	Epoch 70: EarlyStopping counter for 'val_auc_cosine': 10/40
# Epoch 71:
# 	train: loss 0.968 | loss id   0.95 | top_1_acc 0.6166 | top_5_acc 0.8931 | acc_eu: 0.874 | acc_cos: 0.866 | auc_eu: 0.934 | auc_cos: 0.902
# 	val: acc_eu: 0.873 | acc_cos: 0.927 | auc_eu: 0.836 | auc_cos: 0.862
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 71: EarlyStopping counter for 'val_euclidean_accuracy': 5/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 71 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_cosine_accuracy_71.pth'
# 	Epoch 71: EarlyStopping counter for 'val_auc_euclidean': 11/40
# 	Epoch 71: EarlyStopping counter for 'val_auc_cosine': 11/40
# Epoch 72:
# 	train: loss 1.080 | loss id   1.06 | top_1_acc 0.6450 | top_5_acc 0.8999 | acc_eu: 0.865 | acc_cos: 0.832 | auc_eu: 0.919 | auc_cos: 0.881
# 	val: acc_eu: 0.880 | acc_cos: 0.770 | auc_eu: 0.841 | auc_cos: 0.841
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 72: EarlyStopping counter for 'val_euclidean_accuracy': 6/40
# 	Epoch 72: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 72: EarlyStopping counter for 'val_auc_euclidean': 12/40
# 	Epoch 72: EarlyStopping counter for 'val_auc_cosine': 12/40
# Epoch 73:
# 	train: loss 1.190 | loss id   1.17 | top_1_acc 0.6741 | top_5_acc 0.9133 | acc_eu: 0.891 | acc_cos: 0.868 | auc_eu: 0.930 | auc_cos: 0.922
# 	val: acc_eu: 0.870 | acc_cos: 0.848 | auc_eu: 0.856 | auc_cos: 0.843
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 73: EarlyStopping counter for 'val_euclidean_accuracy': 7/40
# 	Epoch 73: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 73: EarlyStopping counter for 'val_auc_euclidean': 13/40
# 	Epoch 73: EarlyStopping counter for 'val_auc_cosine': 13/40
# Epoch 74:
# 	train: loss 1.180 | loss id   1.16 | top_1_acc 0.6816 | top_5_acc 0.9103 | acc_eu: 0.886 | acc_cos: 0.848 | auc_eu: 0.931 | auc_cos: 0.885
# 	val: acc_eu: 0.904 | acc_cos: 0.836 | auc_eu: 0.834 | auc_cos: 0.821
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 74: EarlyStopping counter for 'val_euclidean_accuracy': 8/40
# 	Epoch 74: EarlyStopping counter for 'val_cosine_accuracy': 3/40
# 	Epoch 74: EarlyStopping counter for 'val_auc_euclidean': 14/40
# 	Epoch 74: EarlyStopping counter for 'val_auc_cosine': 14/40
# Epoch 75:
# 	train: loss 1.278 | loss id   1.25 | top_1_acc 0.6734 | top_5_acc 0.9268 | acc_eu: 0.877 | acc_cos: 0.841 | auc_eu: 0.929 | auc_cos: 0.913
# 	val: acc_eu: 0.846 | acc_cos: 0.747 | auc_eu: 0.852 | auc_cos: 0.814
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 75: EarlyStopping counter for 'val_euclidean_accuracy': 9/40
# 	Epoch 75: EarlyStopping counter for 'val_cosine_accuracy': 4/40
# 	Epoch 75: EarlyStopping counter for 'val_auc_euclidean': 15/40
# 	Epoch 75: EarlyStopping counter for 'val_auc_cosine': 15/40
# Epoch 76:
# 	train: loss 1.279 | loss id   1.26 | top_1_acc 0.7130 | top_5_acc 0.9283 | acc_eu: 0.882 | acc_cos: 0.847 | auc_eu: 0.944 | auc_cos: 0.930
# 	val: acc_eu: 0.851 | acc_cos: 0.672 | auc_eu: 0.859 | auc_cos: 0.843
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 76: EarlyStopping counter for 'val_euclidean_accuracy': 10/40
# 	Epoch 76: EarlyStopping counter for 'val_cosine_accuracy': 5/40
# 	Epoch 76: EarlyStopping counter for 'val_auc_euclidean': 16/40
# 	Epoch 76: EarlyStopping counter for 'val_auc_cosine': 16/40
# Epoch 77:
# 	train: loss 1.385 | loss id   1.36 | top_1_acc 0.7100 | top_5_acc 0.9230 | acc_eu: 0.873 | acc_cos: 0.844 | auc_eu: 0.939 | auc_cos: 0.936
# 	val: acc_eu: 0.893 | acc_cos: 0.880 | auc_eu: 0.848 | auc_cos: 0.861
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 77: EarlyStopping counter for 'val_euclidean_accuracy': 11/40
# 	Epoch 77: EarlyStopping counter for 'val_cosine_accuracy': 6/40
# 	Epoch 77: EarlyStopping counter for 'val_auc_euclidean': 17/40
# 	Epoch 77: EarlyStopping counter for 'val_auc_cosine': 17/40
# Epoch 78:
# 	train: loss 1.613 | loss id   1.59 | top_1_acc 0.7287 | top_5_acc 0.9297 | acc_eu: 0.909 | acc_cos: 0.829 | auc_eu: 0.920 | auc_cos: 0.923
# 	val: acc_eu: 0.897 | acc_cos: 0.830 | auc_eu: 0.863 | auc_cos: 0.857
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 78: EarlyStopping counter for 'val_euclidean_accuracy': 12/40
# 	Epoch 78: EarlyStopping counter for 'val_cosine_accuracy': 7/40
# 	Epoch 78: EarlyStopping counter for 'val_auc_euclidean': 18/40
# 	Epoch 78: EarlyStopping counter for 'val_auc_cosine': 18/40
# Epoch 79:
# 	train: loss 1.874 | loss id   1.85 | top_1_acc 0.7362 | top_5_acc 0.9260 | acc_eu: 0.919 | acc_cos: 0.809 | auc_eu: 0.929 | auc_cos: 0.937
# 	val: acc_eu: 0.883 | acc_cos: 0.746 | auc_eu: 0.881 | auc_cos: 0.856
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 79: EarlyStopping counter for 'val_euclidean_accuracy': 13/40
# 	Epoch 79: EarlyStopping counter for 'val_cosine_accuracy': 8/40
# 	Epoch 79: EarlyStopping counter for 'val_auc_euclidean': 19/40
# 	Epoch 79: EarlyStopping counter for 'val_auc_cosine': 19/40
# Epoch 80:
# 	train: loss 2.152 | loss id   2.13 | top_1_acc 0.7892 | top_5_acc 0.9432 | acc_eu: 0.939 | acc_cos: 0.945 | auc_eu: 0.964 | auc_cos: 0.980
# 	val: acc_eu: 0.904 | acc_cos: 0.952 | auc_eu: 0.886 | auc_cos: 0.927
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 80: EarlyStopping counter for 'val_euclidean_accuracy': 14/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 80 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_cosine_accuracy_80.pth'
# 	Epoch 80: EarlyStopping counter for 'val_auc_euclidean': 20/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 80 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_auc_cosine_80.pth'
# Epoch 81:
# 	train: loss 2.002 | loss id   1.98 | top_1_acc 0.8169 | top_5_acc 0.9522 | acc_eu: 0.942 | acc_cos: 0.938 | auc_eu: 0.985 | auc_cos: 0.988
# 	val: acc_eu: 0.887 | acc_cos: 0.916 | auc_eu: 0.910 | auc_cos: 0.926
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 81: EarlyStopping counter for 'val_euclidean_accuracy': 15/40
# 	Epoch 81: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Saved best model weights for 'val_auc_euclidean' at epoch 81 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_auc_euclidean_81.pth'
# 	Epoch 81: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 82:
# 	train: loss 1.793 | loss id   1.77 | top_1_acc 0.8969 | top_5_acc 0.9813 | acc_eu: 0.934 | acc_cos: 0.946 | auc_eu: 0.984 | auc_cos: 0.990
# 	val: acc_eu: 0.871 | acc_cos: 0.846 | auc_eu: 0.883 | auc_cos: 0.930
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 82: EarlyStopping counter for 'val_euclidean_accuracy': 16/40
# 	Epoch 82: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 82: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 82 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_auc_cosine_82.pth'
# Epoch 83:
# 	train: loss 1.695 | loss id   1.67 | top_1_acc 0.9081 | top_5_acc 0.9783 | acc_eu: 0.952 | acc_cos: 0.959 | auc_eu: 0.986 | auc_cos: 0.994
# 	val: acc_eu: 0.794 | acc_cos: 0.879 | auc_eu: 0.885 | auc_cos: 0.927
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 83: EarlyStopping counter for 'val_euclidean_accuracy': 17/40
# 	Epoch 83: EarlyStopping counter for 'val_cosine_accuracy': 3/40
# 	Epoch 83: EarlyStopping counter for 'val_auc_euclidean': 2/40
# 	Epoch 83: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 84:
# 	train: loss 1.604 | loss id   1.58 | top_1_acc 0.9200 | top_5_acc 0.9843 | acc_eu: 0.946 | acc_cos: 0.963 | auc_eu: 0.991 | auc_cos: 0.996
# 	val: acc_eu: 0.894 | acc_cos: 0.876 | auc_eu: 0.904 | auc_cos: 0.930
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 84: EarlyStopping counter for 'val_euclidean_accuracy': 18/40
# 	Epoch 84: EarlyStopping counter for 'val_cosine_accuracy': 4/40
# 	Epoch 84: EarlyStopping counter for 'val_auc_euclidean': 3/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 84 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_auc_cosine_84.pth'
# Epoch 85:
# 	train: loss 1.500 | loss id   1.48 | top_1_acc 0.9469 | top_5_acc 0.9925 | acc_eu: 0.966 | acc_cos: 0.979 | auc_eu: 0.994 | auc_cos: 0.998
# 	val: acc_eu: 0.831 | acc_cos: 0.831 | auc_eu: 0.888 | auc_cos: 0.935
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 85: EarlyStopping counter for 'val_euclidean_accuracy': 19/40
# 	Epoch 85: EarlyStopping counter for 'val_cosine_accuracy': 5/40
# 	Epoch 85: EarlyStopping counter for 'val_auc_euclidean': 4/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 85 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_auc_cosine_85.pth'
# Epoch 86:
# 	train: loss 1.446 | loss id   1.42 | top_1_acc 0.9507 | top_5_acc 0.9895 | acc_eu: 0.976 | acc_cos: 0.980 | auc_eu: 0.996 | auc_cos: 0.999
# 	val: acc_eu: 0.757 | acc_cos: 0.899 | auc_eu: 0.895 | auc_cos: 0.915
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 86: EarlyStopping counter for 'val_euclidean_accuracy': 20/40
# 	Epoch 86: EarlyStopping counter for 'val_cosine_accuracy': 6/40
# 	Epoch 86: EarlyStopping counter for 'val_auc_euclidean': 5/40
# 	Epoch 86: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 87:
# 	train: loss 1.335 | loss id   1.31 | top_1_acc 0.9656 | top_5_acc 0.9963 | acc_eu: 0.976 | acc_cos: 0.989 | auc_eu: 0.998 | auc_cos: 0.999
# 	val: acc_eu: 0.919 | acc_cos: 0.891 | auc_eu: 0.895 | auc_cos: 0.930
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 87: EarlyStopping counter for 'val_euclidean_accuracy': 21/40
# 	Epoch 87: EarlyStopping counter for 'val_cosine_accuracy': 7/40
# 	Epoch 87: EarlyStopping counter for 'val_auc_euclidean': 6/40
# 	Epoch 87: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 88:
# 	train: loss 1.256 | loss id   1.23 | top_1_acc 0.9723 | top_5_acc 0.9963 | acc_eu: 0.984 | acc_cos: 0.995 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.871 | acc_cos: 0.883 | auc_eu: 0.885 | auc_cos: 0.942
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 88: EarlyStopping counter for 'val_euclidean_accuracy': 22/40
# 	Epoch 88: EarlyStopping counter for 'val_cosine_accuracy': 8/40
# 	Epoch 88: EarlyStopping counter for 'val_auc_euclidean': 7/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 88 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/best_val_auc_cosine_88.pth'
# Epoch 89:
# 	train: loss 1.179 | loss id   1.16 | top_1_acc 0.9813 | top_5_acc 0.9963 | acc_eu: 0.988 | acc_cos: 0.996 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.814 | acc_cos: 0.848 | auc_eu: 0.877 | auc_cos: 0.928
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 89: EarlyStopping counter for 'val_euclidean_accuracy': 23/40
# 	Epoch 89: EarlyStopping counter for 'val_cosine_accuracy': 9/40
# 	Epoch 89: EarlyStopping counter for 'val_auc_euclidean': 8/40
# 	Epoch 89: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 90:
# 	train: loss 1.107 | loss id   1.08 | top_1_acc 0.9873 | top_5_acc 0.9993 | acc_eu: 0.992 | acc_cos: 0.995 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.917 | acc_cos: 0.934 | auc_eu: 0.890 | auc_cos: 0.940
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 90: EarlyStopping counter for 'val_euclidean_accuracy': 24/40
# 	Epoch 90: EarlyStopping counter for 'val_cosine_accuracy': 10/40
# 	Epoch 90: EarlyStopping counter for 'val_auc_euclidean': 9/40
# 	Epoch 90: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 91:
# 	train: loss 1.030 | loss id   1.01 | top_1_acc 0.9918 | top_5_acc 0.9985 | acc_eu: 0.986 | acc_cos: 0.991 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.804 | acc_cos: 0.891 | auc_eu: 0.872 | auc_cos: 0.909
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 91: EarlyStopping counter for 'val_euclidean_accuracy': 25/40
# 	Epoch 91: EarlyStopping counter for 'val_cosine_accuracy': 11/40
# 	Epoch 91: EarlyStopping counter for 'val_auc_euclidean': 10/40
# 	Epoch 91: EarlyStopping counter for 'val_auc_cosine': 3/40
# Epoch 92:
# 	train: loss 0.977 | loss id   0.95 | top_1_acc 0.9888 | top_5_acc 0.9993 | acc_eu: 0.981 | acc_cos: 0.994 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.802 | acc_cos: 0.861 | auc_eu: 0.842 | auc_cos: 0.931
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 92: EarlyStopping counter for 'val_euclidean_accuracy': 26/40
# 	Epoch 92: EarlyStopping counter for 'val_cosine_accuracy': 12/40
# 	Epoch 92: EarlyStopping counter for 'val_auc_euclidean': 11/40
# 	Epoch 92: EarlyStopping counter for 'val_auc_cosine': 4/40
# Epoch 93:
# 	train: loss 0.898 | loss id   0.88 | top_1_acc 0.9948 | top_5_acc 0.9993 | acc_eu: 0.987 | acc_cos: 0.997 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.866 | acc_cos: 0.885 | auc_eu: 0.847 | auc_cos: 0.920
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 93: EarlyStopping counter for 'val_euclidean_accuracy': 27/40
# 	Epoch 93: EarlyStopping counter for 'val_cosine_accuracy': 13/40
# 	Epoch 93: EarlyStopping counter for 'val_auc_euclidean': 12/40
# 	Epoch 93: EarlyStopping counter for 'val_auc_cosine': 5/40
# Epoch 94:
# 	train: loss 0.839 | loss id   0.82 | top_1_acc 0.9903 | top_5_acc 0.9993 | acc_eu: 0.993 | acc_cos: 0.998 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.881 | acc_cos: 0.887 | auc_eu: 0.872 | auc_cos: 0.942
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 94: EarlyStopping counter for 'val_euclidean_accuracy': 28/40
# 	Epoch 94: EarlyStopping counter for 'val_cosine_accuracy': 14/40
# 	Epoch 94: EarlyStopping counter for 'val_auc_euclidean': 13/40
# 	Epoch 94: EarlyStopping counter for 'val_auc_cosine': 6/40
# Epoch 95:
# 	train: loss 0.779 | loss id   0.76 | top_1_acc 0.9948 | top_5_acc 1.0000 | acc_eu: 0.996 | acc_cos: 0.999 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.828 | acc_cos: 0.898 | auc_eu: 0.874 | auc_cos: 0.934
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 95: EarlyStopping counter for 'val_euclidean_accuracy': 29/40
# 	Epoch 95: EarlyStopping counter for 'val_cosine_accuracy': 15/40
# 	Epoch 95: EarlyStopping counter for 'val_auc_euclidean': 14/40
# 	Epoch 95: EarlyStopping counter for 'val_auc_cosine': 7/40
# Epoch 96:
# 	train: loss 0.709 | loss id   0.69 | top_1_acc 0.9978 | top_5_acc 1.0000 | acc_eu: 0.996 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.784 | acc_cos: 0.884 | auc_eu: 0.869 | auc_cos: 0.942
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 96: EarlyStopping counter for 'val_euclidean_accuracy': 30/40
# 	Epoch 96: EarlyStopping counter for 'val_cosine_accuracy': 16/40
# 	Epoch 96: EarlyStopping counter for 'val_auc_euclidean': 15/40
# 	Epoch 96: EarlyStopping counter for 'val_auc_cosine': 8/40
# Epoch 97:
# 	train: loss 0.687 | loss id   0.66 | top_1_acc 0.9970 | top_5_acc 1.0000 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.832 | acc_cos: 0.922 | auc_eu: 0.857 | auc_cos: 0.931
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 97: EarlyStopping counter for 'val_euclidean_accuracy': 31/40
# 	Epoch 97: EarlyStopping counter for 'val_cosine_accuracy': 17/40
# 	Epoch 97: EarlyStopping counter for 'val_auc_euclidean': 16/40
# 	Epoch 97: EarlyStopping counter for 'val_auc_cosine': 9/40
# Epoch 98:
# 	train: loss 0.638 | loss id   0.61 | top_1_acc 0.9993 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.884 | acc_cos: 0.852 | auc_eu: 0.853 | auc_cos: 0.925
# ...
# 	Epoch 103: EarlyStopping counter for 'val_auc_euclidean': 22/40
# 	Epoch 103: EarlyStopping counter for 'val_auc_cosine': 15/40
# Epoch 104:
# 	train: loss 0.427 | loss id   0.40 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.867 | acc_cos: 0.798 | auc_eu: 0.858 | auc_cos: 0.918
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 104: EarlyStopping counter for 'val_euclidean_accuracy': 38/40
# 	Epoch 104: EarlyStopping counter for 'val_cosine_accuracy': 24/40
# 	Epoch 104: EarlyStopping counter for 'val_auc_euclidean': 23/40
# 	Epoch 104: EarlyStopping counter for 'val_auc_cosine': 16/40
# Epoch 105:
# 	train: loss 0.359 | loss id   0.34 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.839 | acc_cos: 0.861 | auc_eu: 0.873 | auc_cos: 0.939
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 105: EarlyStopping counter for 'val_euclidean_accuracy': 39/40
# 	Epoch 105: EarlyStopping counter for 'val_cosine_accuracy': 25/40
# 	Epoch 105: EarlyStopping counter for 'val_auc_euclidean': 24/40
# 	Epoch 105: EarlyStopping counter for 'val_auc_cosine': 17/40
# Epoch 106:
# 	train: loss 0.333 | loss id   0.31 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.884 | acc_cos: 0.860 | auc_eu: 0.859 | auc_cos: 0.931
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 106: EarlyStopping counter for 'val_euclidean_accuracy': 40/40
# 	Epoch 106: EarlyStopping counter for 'val_cosine_accuracy': 26/40
# 	Epoch 106: EarlyStopping counter for 'val_auc_euclidean': 25/40
# 	Epoch 106: EarlyStopping counter for 'val_auc_cosine': 18/40
# Epoch 107:
# 	train: loss 0.318 | loss id   0.30 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.854 | acc_cos: 0.827 | auc_eu: 0.870 | auc_cos: 0.938
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 107: EarlyStopping counter for 'val_euclidean_accuracy': 41/40
# 	Epoch 107: EarlyStopping counter for 'val_cosine_accuracy': 27/40
# 	Epoch 107: EarlyStopping counter for 'val_auc_euclidean': 26/40
# 	Epoch 107: EarlyStopping counter for 'val_auc_cosine': 19/40
# Epoch 108:
# 	train: loss 0.266 | loss id   0.24 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.888 | acc_cos: 0.840 | auc_eu: 0.872 | auc_cos: 0.940
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 108: EarlyStopping counter for 'val_euclidean_accuracy': 42/40
# 	Epoch 108: EarlyStopping counter for 'val_cosine_accuracy': 28/40
# 	Epoch 108: EarlyStopping counter for 'val_auc_euclidean': 27/40
# 	Epoch 108: EarlyStopping counter for 'val_auc_cosine': 20/40
# Epoch 109:
# 	train: loss 0.264 | loss id   0.24 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.849 | acc_cos: 0.937 | auc_eu: 0.868 | auc_cos: 0.931
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 109: EarlyStopping counter for 'val_euclidean_accuracy': 43/40
# 	Epoch 109: EarlyStopping counter for 'val_cosine_accuracy': 29/40
# 	Epoch 109: EarlyStopping counter for 'val_auc_euclidean': 28/40
# 	Epoch 109: EarlyStopping counter for 'val_auc_cosine': 21/40
# Epoch 110:
# 	train: loss 0.237 | loss id   0.21 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.756 | acc_cos: 0.886 | auc_eu: 0.865 | auc_cos: 0.931
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 110: EarlyStopping counter for 'val_euclidean_accuracy': 44/40
# 	Epoch 110: EarlyStopping counter for 'val_cosine_accuracy': 30/40
# 	Epoch 110: EarlyStopping counter for 'val_auc_euclidean': 29/40
# 	Epoch 110: EarlyStopping counter for 'val_auc_cosine': 22/40
# Epoch 111:
# 	train: loss 0.209 | loss id   0.19 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.804 | acc_cos: 0.884 | auc_eu: 0.859 | auc_cos: 0.926
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 111: EarlyStopping counter for 'val_euclidean_accuracy': 45/40
# 	Epoch 111: EarlyStopping counter for 'val_cosine_accuracy': 31/40
# 	Epoch 111: EarlyStopping counter for 'val_auc_euclidean': 30/40
# 	Epoch 111: EarlyStopping counter for 'val_auc_cosine': 23/40
# Epoch 112:
# 	train: loss 0.212 | loss id   0.19 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.893 | acc_cos: 0.873 | auc_eu: 0.863 | auc_cos: 0.939
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 112: EarlyStopping counter for 'val_euclidean_accuracy': 46/40
# 	Epoch 112: EarlyStopping counter for 'val_cosine_accuracy': 32/40
# 	Epoch 112: EarlyStopping counter for 'val_auc_euclidean': 31/40
# 	Epoch 112: EarlyStopping counter for 'val_auc_cosine': 24/40
# Epoch 113:
# 	train: loss 0.231 | loss id   0.21 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.826 | acc_cos: 0.899 | auc_eu: 0.846 | auc_cos: 0.932
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 113: EarlyStopping counter for 'val_euclidean_accuracy': 47/40
# 	Epoch 113: EarlyStopping counter for 'val_cosine_accuracy': 33/40
# 	Epoch 113: EarlyStopping counter for 'val_auc_euclidean': 32/40
# 	Epoch 113: EarlyStopping counter for 'val_auc_cosine': 25/40
# Epoch 114:
# 	train: loss 0.206 | loss id   0.18 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.827 | acc_cos: 0.947 | auc_eu: 0.859 | auc_cos: 0.923
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 114: EarlyStopping counter for 'val_euclidean_accuracy': 48/40
# 	Epoch 114: EarlyStopping counter for 'val_cosine_accuracy': 34/40
# 	Epoch 114: EarlyStopping counter for 'val_auc_euclidean': 33/40
# 	Epoch 114: EarlyStopping counter for 'val_auc_cosine': 26/40
# Epoch 115:
# 	train: loss 0.184 | loss id   0.16 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.868 | acc_cos: 0.894 | auc_eu: 0.863 | auc_cos: 0.932
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 115: EarlyStopping counter for 'val_euclidean_accuracy': 49/40
# 	Epoch 115: EarlyStopping counter for 'val_cosine_accuracy': 35/40
# 	Epoch 115: EarlyStopping counter for 'val_auc_euclidean': 34/40
# 	Epoch 115: EarlyStopping counter for 'val_auc_cosine': 27/40
# Epoch 116:
# 	train: loss 0.189 | loss id   0.17 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.735 | acc_cos: 0.877 | auc_eu: 0.855 | auc_cos: 0.932
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 116: EarlyStopping counter for 'val_euclidean_accuracy': 50/40
# 	Epoch 116: EarlyStopping counter for 'val_cosine_accuracy': 36/40
# 	Epoch 116: EarlyStopping counter for 'val_auc_euclidean': 35/40
# 	Epoch 116: EarlyStopping counter for 'val_auc_cosine': 28/40
# Epoch 117:
# 	train: loss 0.154 | loss id   0.13 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.816 | acc_cos: 0.806 | auc_eu: 0.851 | auc_cos: 0.928
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 117: EarlyStopping counter for 'val_euclidean_accuracy': 51/40
# 	Epoch 117: EarlyStopping counter for 'val_cosine_accuracy': 37/40
# 	Epoch 117: EarlyStopping counter for 'val_auc_euclidean': 36/40
# 	Epoch 117: EarlyStopping counter for 'val_auc_cosine': 29/40
# Epoch 118:
# 	train: loss 0.151 | loss id   0.13 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.903 | acc_cos: 0.863 | auc_eu: 0.854 | auc_cos: 0.926
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 118: EarlyStopping counter for 'val_euclidean_accuracy': 52/40
# 	Epoch 118: EarlyStopping counter for 'val_cosine_accuracy': 38/40
# 	Epoch 118: EarlyStopping counter for 'val_auc_euclidean': 37/40
# 	Epoch 118: EarlyStopping counter for 'val_auc_cosine': 30/40
# Epoch 119:
# 	train: loss 0.133 | loss id   0.11 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.865 | acc_cos: 0.907 | auc_eu: 0.853 | auc_cos: 0.928
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 119: EarlyStopping counter for 'val_euclidean_accuracy': 53/40
# 	Epoch 119: EarlyStopping counter for 'val_cosine_accuracy': 39/40
# 	Epoch 119: EarlyStopping counter for 'val_auc_euclidean': 38/40
# 	Epoch 119: EarlyStopping counter for 'val_auc_cosine': 31/40
# Epoch 120:
# 	train: loss 0.116 | loss id   0.09 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.865 | acc_cos: 0.873 | auc_eu: 0.862 | auc_cos: 0.935
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 120: EarlyStopping counter for 'val_euclidean_accuracy': 54/40
# 	Epoch 120: EarlyStopping counter for 'val_cosine_accuracy': 40/40
# 	Epoch 120: EarlyStopping counter for 'val_auc_euclidean': 39/40
# 	Epoch 120: EarlyStopping counter for 'val_auc_cosine': 32/40
# Epoch 121:
# 	train: loss 0.118 | loss id   0.09 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.810 | acc_cos: 0.904 | auc_eu: 0.856 | auc_cos: 0.933
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 121: EarlyStopping counter for 'val_euclidean_accuracy': 55/40
# 	Epoch 121: EarlyStopping counter for 'val_cosine_accuracy': 41/40
# 	Epoch 121: EarlyStopping counter for 'val_auc_euclidean': 40/40
# 	Epoch 121: EarlyStopping counter for 'val_auc_cosine': 33/40
# Epoch 122:
# 	train: loss 0.112 | loss id   0.09 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.826 | acc_cos: 0.858 | auc_eu: 0.853 | auc_cos: 0.936
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 122: EarlyStopping counter for 'val_euclidean_accuracy': 56/40
# 	Epoch 122: EarlyStopping counter for 'val_cosine_accuracy': 42/40
# 	Epoch 122: EarlyStopping counter for 'val_auc_euclidean': 41/40
# 	Epoch 122: EarlyStopping counter for 'val_auc_cosine': 34/40
# Epoch 123:
# 	train: loss 0.122 | loss id   0.10 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.906 | acc_cos: 0.889 | auc_eu: 0.876 | auc_cos: 0.924
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 123: EarlyStopping counter for 'val_euclidean_accuracy': 57/40
# 	Epoch 123: EarlyStopping counter for 'val_cosine_accuracy': 43/40
# 	Epoch 123: EarlyStopping counter for 'val_auc_euclidean': 42/40
# 	Epoch 123: EarlyStopping counter for 'val_auc_cosine': 35/40
# Epoch 124:
# 	train: loss 0.118 | loss id   0.10 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.877 | acc_cos: 0.892 | auc_eu: 0.857 | auc_cos: 0.933
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 124: EarlyStopping counter for 'val_euclidean_accuracy': 58/40
# 	Epoch 124: EarlyStopping counter for 'val_cosine_accuracy': 44/40
# 	Epoch 124: EarlyStopping counter for 'val_auc_euclidean': 43/40
# 	Epoch 124: EarlyStopping counter for 'val_auc_cosine': 36/40
# Epoch 125:
# 	train: loss 0.137 | loss id   0.11 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.786 | acc_cos: 0.818 | auc_eu: 0.861 | auc_cos: 0.927
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 125: EarlyStopping counter for 'val_euclidean_accuracy': 59/40
# 	Epoch 125: EarlyStopping counter for 'val_cosine_accuracy': 45/40
# 	Epoch 125: EarlyStopping counter for 'val_auc_euclidean': 44/40
# 	Epoch 125: EarlyStopping counter for 'val_auc_cosine': 37/40
# Epoch 126:
# 	train: loss 0.114 | loss id   0.09 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.932 | acc_cos: 0.881 | auc_eu: 0.863 | auc_cos: 0.938
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 126: EarlyStopping counter for 'val_euclidean_accuracy': 60/40
# 	Epoch 126: EarlyStopping counter for 'val_cosine_accuracy': 46/40
# 	Epoch 126: EarlyStopping counter for 'val_auc_euclidean': 45/40
# 	Epoch 126: EarlyStopping counter for 'val_auc_cosine': 38/40
# Epoch 127:
# 	train: loss 0.092 | loss id   0.07 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.906 | acc_cos: 0.905 | auc_eu: 0.855 | auc_cos: 0.925
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 127: EarlyStopping counter for 'val_euclidean_accuracy': 61/40
# 	Epoch 127: EarlyStopping counter for 'val_cosine_accuracy': 47/40
# 	Epoch 127: EarlyStopping counter for 'val_auc_euclidean': 46/40
# 	Epoch 127: EarlyStopping counter for 'val_auc_cosine': 39/40
# Epoch 128:
# 	train: loss 0.096 | loss id   0.07 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.917 | acc_cos: 0.842 | auc_eu: 0.845 | auc_cos: 0.916
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet34/models/checkpoint.pth
# 	Epoch 128: EarlyStopping counter for 'val_euclidean_accuracy': 62/40
# 	Epoch 128: EarlyStopping counter for 'val_cosine_accuracy': 48/40
# 	Epoch 128: EarlyStopping counter for 'val_auc_euclidean': 47/40
# 	Epoch 128: EarlyStopping counter for 'val_auc_cosine': 40/40
# 	Early stopping triggered at epoch 128 as all metrics exceeded patience.

# %%
# %load_ext tensorboard
# %tensorboard --logdir checkpoint/magface/albedo/iresnet34/logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 83960), started 0:00:05 ago. (Use '!kill 83960' to kill it.)
#       <iframe id="tensorboard-frame-d5aebc3b7bd59bc4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d5aebc3b7bd59bc4");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
print('TB: 0.87703125p/epoch')
# Out:
# TB: 0.87703125p/epoch
