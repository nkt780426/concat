# %%
# !git clone https://github.com/nkt780426/concat.git
# Out:
# Cloning into 'concat'...
# remote: Enumerating objects: 454, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 454 (delta 0), reused 4 (delta 0), pack-reused 445 (from 1)
# Receiving objects: 100% (454/454), 76.05 MiB | 46.33 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
# !gdown --quiet --folder "https://drive.google.com/drive/folders/18xo7lymNGJ-1oq63nKPlVKV_apTUeEF3?usp=drive_link"

# %%
# !mv concat/going_modular .

# %%
# !ls -la
# Out:
# total 44
# drwxr-xr-x 5 root root  4096 Dec 21 11:03 .
# drwxr-xr-x 6 root root  4096 Dec 21 11:03 ..
# drwxr-xr-x 3 root root  4096 Dec 21 11:03 checkpoint
# drwxr-xr-x 6 root root  4096 Dec 21 11:03 concat
# drwxr-xr-x 8 root root  4096 Dec 21 11:03 going_modular
# ---------- 1 root root 22826 Dec 21 11:03 __notebook__.ipynb

# %%
import warnings
warnings.filterwarnings("ignore")
import torch
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import albumentations as A


from going_modular.model.TripletFaceRecognition import EmbeddingNet_Concat, TripletNet_Concat
from going_modular.dataloader.triplet import TripletDatasetConcat
from going_modular.loss.TripletLoss import TripletLoss
from going_modular.dataloader.triplet import CustomExrDatasetConcat
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.train_eval.triplet.train import fit

import os

import warnings
warnings.filterwarnings("ignore")

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Đặt seed toàn cục
seed = 42
torch.manual_seed(seed)

CONFIGURATION = {
    'type': 'concat',
    # Thư mục
    'data_dir': '/kaggle/input/hoangvn-3dfacerecognition',
    'checkpoint_dir': './checkpoint/triplet/',
    'normalmap_checkpoint': './checkpoint/samenetwork/triplet/normalmap/models/checkpoint.pth',
    'albedo_checkpoint': './checkpoint/samenetwork/triplet/albedo/models/checkpoint.pth',

    # Cấu hình train
    'epochs': 119,
    'num_workers': 4,
    'batch_size': 16,
    'image_size': 256,
    'embedding_size': 512,
    
    'start_lr': 1e-4,
    'weight_decay': 5e-4,
    'momentum': 0.9,
    'alpha': 0.9,
    
    # triplet
    'margin': 1.,
}


train_transform = A.Compose([
    RandomResizedCropRect(256),
    GaussianNoise(),
])

test_transform = A.Compose([
    A.Resize(height=CONFIGURATION['image_size'], width=CONFIGURATION['image_size'])
])

triplet_concat_train_dataset = TripletDatasetConcat(data_dir=CONFIGURATION['data_dir'], transform=train_transform, train=True)
triplet_concat_test_dataset = TripletDatasetConcat(data_dir=CONFIGURATION['data_dir'], transform=test_transform, train=False)


triplet_concat_train_loader = DataLoader(
    triplet_concat_train_dataset, 
    batch_size=CONFIGURATION['batch_size'], 
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True
)


triplet_concat_test_loader = DataLoader(
    triplet_concat_test_dataset, 
    batch_size=CONFIGURATION['batch_size'], 
    shuffle=False,
    num_workers=4,
    pin_memory=True,
    drop_last=True
)


roc_concat_train_dataset = CustomExrDatasetConcat(data_dir=CONFIGURATION['data_dir'], transform=train_transform, train=True)
roc_concat_train_loader = DataLoader(
    roc_concat_train_dataset,
    num_workers=4,
    batch_size=CONFIGURATION['batch_size'],
)

roc_concat_test_dataset = CustomExrDatasetConcat(data_dir=CONFIGURATION['data_dir'], transform=test_transform, train=False)
roc_test_loader = DataLoader(
    roc_concat_test_dataset,
    num_workers=4,
    batch_size=CONFIGURATION['batch_size'],
)


# Load pre-trained state_dict
normal_checkpoint = torch.load(CONFIGURATION['normalmap_checkpoint'])
# Loại bỏ 14 ký tự đầu tiên từ các khóa trong state_dict
new_normalmap_state_dict = {}
for key, value in normal_checkpoint['model_state_dict'].items():
    new_key = key[14:]  # Cắt bỏ 14 ký tự đầu tiên
    new_normalmap_state_dict[new_key] = value

albedo_checkpoint = torch.load(CONFIGURATION['albedo_checkpoint'])
# Loại bỏ 14 ký tự đầu tiên từ các khóa trong state_dict
new_albedo_state_dict = {}
for key, value in normal_checkpoint['model_state_dict'].items():
    new_key = key[14:]  # Cắt bỏ 14 ký tự đầu tiên
    new_albedo_state_dict[new_key] = value
    
embedding_net = EmbeddingNet_Concat(conf=CONFIGURATION)

embedding_net.resnet1.load_state_dict(new_normalmap_state_dict, strict=False)

embedding_net.resnet2.load_state_dict(new_albedo_state_dict)

model = TripletNet_Concat(embedding_net).to(device)

# Freeze 2 mạng lại
for param in model.embedding_net.resnet1.parameters():
    param.requires_grad = False
    
for param in model.embedding_net.resnet2.parameters():
    param.requires_grad = False
    
criterion = TripletLoss(CONFIGURATION['margin'])
optimizer = Adam(model.parameters(), lr=CONFIGURATION['start_lr'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=30, T_mult=1, eta_min=1e-6)

earlystop_dir = os.path.abspath(CONFIGURATION['checkpoint_dir'] + CONFIGURATION['type'] + '/models')

early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['cosine_auc', 'euclidean_auc'],
    patience=50,
    mode='max',
    verbose=0,
    save_dir=earlystop_dir,
    start_from_epoch=80
)      

checkpoint_path = os.path.abspath(CONFIGURATION['checkpoint_dir'] + CONFIGURATION['type'] + '/models/checkpoint.pth')
modle_checkpoint = ModelCheckpoint(filepath=checkpoint_path, verbose=1)
# Out:
# cuda

# %%
fit(
    conf=CONFIGURATION,
    start_epoch=0,
    model=model,
    triplet_train_loader=triplet_concat_train_loader, 
    triplet_test_loader=triplet_concat_test_loader, 
    criterion=criterion,
    optimizer=optimizer, 
    scheduler=scheduler, 
    epochs=CONFIGURATION['epochs'], 
    device=device, 
    roc_train_loader=roc_concat_train_loader, 
    roc_test_loader=roc_test_loader,
    early_max_stopping=early_stopping,
    model_checkpoint=modle_checkpoint
)
# Out:
# Epoch 1:
# 	train: loss: 3.5137 | auc_cos: 0.9421 | auc_eu: 0.9478
# 	test: loss: 0.4236 | auc_cos: 0.9187 | auc_eu: 0.9269
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 2:
# 	train: loss: 1.6672 | auc_cos: 0.9408 | auc_eu: 0.9519
# 	test: loss: 0.2503 | auc_cos: 0.9154 | auc_eu: 0.9311
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 3:
# 	train: loss: 2.1720 | auc_cos: 0.9477 | auc_eu: 0.9602
# 	test: loss: 0.2757 | auc_cos: 0.9178 | auc_eu: 0.9248
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 4:
# 	train: loss: 1.6087 | auc_cos: 0.9493 | auc_eu: 0.9621
# 	test: loss: 0.3054 | auc_cos: 0.9245 | auc_eu: 0.9261
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 5:
# 	train: loss: 1.4349 | auc_cos: 0.9494 | auc_eu: 0.9594
# 	test: loss: 0.4957 | auc_cos: 0.9206 | auc_eu: 0.9247
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 6:
# 	train: loss: 1.6321 | auc_cos: 0.9489 | auc_eu: 0.9612
# 	test: loss: 0.4334 | auc_cos: 0.9164 | auc_eu: 0.9191
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 7:
# 	train: loss: 1.4015 | auc_cos: 0.9505 | auc_eu: 0.9625
# 	test: loss: 0.3454 | auc_cos: 0.9212 | auc_eu: 0.9244
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 8:
# 	train: loss: 1.2054 | auc_cos: 0.9525 | auc_eu: 0.9631
# 	test: loss: 0.5930 | auc_cos: 0.9168 | auc_eu: 0.9214
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 9:
# 	train: loss: 1.5909 | auc_cos: 0.9522 | auc_eu: 0.9645
# 	test: loss: 0.3153 | auc_cos: 0.9196 | auc_eu: 0.9249
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 10:
# 	train: loss: 1.6998 | auc_cos: 0.9547 | auc_eu: 0.9655
# 	test: loss: 0.2368 | auc_cos: 0.9185 | auc_eu: 0.9255
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 11:
# 	train: loss: 1.6563 | auc_cos: 0.9514 | auc_eu: 0.9643
# 	test: loss: 0.2684 | auc_cos: 0.9173 | auc_eu: 0.9257
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 12:
# 	train: loss: 1.1491 | auc_cos: 0.9528 | auc_eu: 0.9635
# 	test: loss: 0.3961 | auc_cos: 0.9179 | auc_eu: 0.9241
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 13:
# 	train: loss: 1.0958 | auc_cos: 0.9531 | auc_eu: 0.9653
# 	test: loss: 0.4167 | auc_cos: 0.9200 | auc_eu: 0.9252
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 14:
# 	train: loss: 1.1480 | auc_cos: 0.9503 | auc_eu: 0.9644
# 	test: loss: 0.4185 | auc_cos: 0.9157 | auc_eu: 0.9306
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 15:
# 	train: loss: 1.1813 | auc_cos: 0.9542 | auc_eu: 0.9637
# 	test: loss: 0.2926 | auc_cos: 0.9233 | auc_eu: 0.9277
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 16:
# 	train: loss: 1.5698 | auc_cos: 0.9553 | auc_eu: 0.9630
# 	test: loss: 0.2638 | auc_cos: 0.9241 | auc_eu: 0.9261
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 17:
# 	train: loss: 1.2080 | auc_cos: 0.9546 | auc_eu: 0.9652
# 	test: loss: 0.2808 | auc_cos: 0.9209 | auc_eu: 0.9257
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 18:
# 	train: loss: 1.1112 | auc_cos: 0.9519 | auc_eu: 0.9651
# 	test: loss: 0.5833 | auc_cos: 0.9161 | auc_eu: 0.9233
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 19:
# 	train: loss: 1.1108 | auc_cos: 0.9562 | auc_eu: 0.9679
# 	test: loss: 0.4783 | auc_cos: 0.9184 | auc_eu: 0.9240
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 20:
# 	train: loss: 1.4660 | auc_cos: 0.9547 | auc_eu: 0.9663
# 	test: loss: 0.4246 | auc_cos: 0.9214 | auc_eu: 0.9241
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 21:
# 	train: loss: 1.0487 | auc_cos: 0.9566 | auc_eu: 0.9694
# 	test: loss: 0.4601 | auc_cos: 0.9177 | auc_eu: 0.9270
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 22:
# 	train: loss: 0.9741 | auc_cos: 0.9555 | auc_eu: 0.9672
# 	test: loss: 0.5557 | auc_cos: 0.9165 | auc_eu: 0.9240
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 23:
# 	train: loss: 1.1481 | auc_cos: 0.9559 | auc_eu: 0.9682
# 	test: loss: 0.6028 | auc_cos: 0.9189 | auc_eu: 0.9252
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 24:
# 	train: loss: 1.3793 | auc_cos: 0.9539 | auc_eu: 0.9688
# 	test: loss: 0.3525 | auc_cos: 0.9196 | auc_eu: 0.9288
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 25:
# 	train: loss: 1.1941 | auc_cos: 0.9586 | auc_eu: 0.9677
# 	test: loss: 0.3054 | auc_cos: 0.9250 | auc_eu: 0.9285
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 26:
# 	train: loss: 1.3522 | auc_cos: 0.9569 | auc_eu: 0.9692
# 	test: loss: 0.4032 | auc_cos: 0.9192 | auc_eu: 0.9267
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 27:
# 	train: loss: 1.1195 | auc_cos: 0.9571 | auc_eu: 0.9680
# 	test: loss: 0.2998 | auc_cos: 0.9221 | auc_eu: 0.9261
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 28:
# 	train: loss: 1.1803 | auc_cos: 0.9574 | auc_eu: 0.9683
# 	test: loss: 0.3748 | auc_cos: 0.9212 | auc_eu: 0.9261
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 29:
# 	train: loss: 1.2774 | auc_cos: 0.9535 | auc_eu: 0.9668
# 	test: loss: 0.5037 | auc_cos: 0.9220 | auc_eu: 0.9260
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 30:
# 	train: loss: 1.0757 | auc_cos: 0.9511 | auc_eu: 0.9654
# 	test: loss: 0.2856 | auc_cos: 0.9191 | auc_eu: 0.9284
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 31:
# 	train: loss: 1.3534 | auc_cos: 0.9512 | auc_eu: 0.9648
# 	test: loss: 0.3765 | auc_cos: 0.9157 | auc_eu: 0.9278
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 32:
# 	train: loss: 1.2858 | auc_cos: 0.9480 | auc_eu: 0.9644
# 	test: loss: 0.4922 | auc_cos: 0.9149 | auc_eu: 0.9277
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 33:
# 	train: loss: 1.1638 | auc_cos: 0.9510 | auc_eu: 0.9647
# 	test: loss: 0.8171 | auc_cos: 0.9131 | auc_eu: 0.9281
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 34:
# 	train: loss: 1.2938 | auc_cos: 0.9503 | auc_eu: 0.9661
# 	test: loss: 0.7473 | auc_cos: 0.9117 | auc_eu: 0.9286
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 35:
# 	train: loss: 1.3012 | auc_cos: 0.9496 | auc_eu: 0.9626
# 	test: loss: 0.4950 | auc_cos: 0.9190 | auc_eu: 0.9262
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 36:
# 	train: loss: 1.1962 | auc_cos: 0.9522 | auc_eu: 0.9646
# 	test: loss: 0.4047 | auc_cos: 0.9166 | auc_eu: 0.9287
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 37:
# 	train: loss: 1.0275 | auc_cos: 0.9539 | auc_eu: 0.9674
# 	test: loss: 0.3903 | auc_cos: 0.9198 | auc_eu: 0.9299
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 38:
# 	train: loss: 1.2229 | auc_cos: 0.9494 | auc_eu: 0.9643
# 	test: loss: 0.7175 | auc_cos: 0.9174 | auc_eu: 0.9273
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 39:
# 	train: loss: 1.1427 | auc_cos: 0.9538 | auc_eu: 0.9661
# 	test: loss: 0.2617 | auc_cos: 0.9180 | auc_eu: 0.9296
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 40:
# 	train: loss: 1.2636 | auc_cos: 0.9515 | auc_eu: 0.9646
# 	test: loss: 0.3388 | auc_cos: 0.9173 | auc_eu: 0.9264
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 41:
# 	train: loss: 1.4720 | auc_cos: 0.9545 | auc_eu: 0.9653
# 	test: loss: 0.4761 | auc_cos: 0.9179 | auc_eu: 0.9227
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 42:
# 	train: loss: 0.9583 | auc_cos: 0.9567 | auc_eu: 0.9680
# 	test: loss: 0.3186 | auc_cos: 0.9183 | auc_eu: 0.9257
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 43:
# 	train: loss: 0.9528 | auc_cos: 0.9546 | auc_eu: 0.9665
# 	test: loss: 0.7041 | auc_cos: 0.9156 | auc_eu: 0.9243
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 44:
# 	train: loss: 1.5098 | auc_cos: 0.9505 | auc_eu: 0.9651
# 	test: loss: 0.5040 | auc_cos: 0.9124 | auc_eu: 0.9241
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 45:
# 	train: loss: 1.5453 | auc_cos: 0.9561 | auc_eu: 0.9689
# 	test: loss: 0.3947 | auc_cos: 0.9199 | auc_eu: 0.9282
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 46:
# 	train: loss: 1.1186 | auc_cos: 0.9563 | auc_eu: 0.9683
# 	test: loss: 0.3865 | auc_cos: 0.9214 | auc_eu: 0.9252
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 47:
# 	train: loss: 1.3270 | auc_cos: 0.9537 | auc_eu: 0.9670
# 	test: loss: 0.5225 | auc_cos: 0.9188 | auc_eu: 0.9236
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 48:
# 	train: loss: 1.1432 | auc_cos: 0.9570 | auc_eu: 0.9693
# 	test: loss: 0.6304 | auc_cos: 0.9188 | auc_eu: 0.9223
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 49:
# 	train: loss: 1.1991 | auc_cos: 0.9560 | auc_eu: 0.9688
# 	test: loss: 0.4672 | auc_cos: 0.9184 | auc_eu: 0.9279
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 50:
# 	train: loss: 1.0622 | auc_cos: 0.9530 | auc_eu: 0.9686
# 	test: loss: 0.5091 | auc_cos: 0.9180 | auc_eu: 0.9276
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 51:
# 	train: loss: 1.0040 | auc_cos: 0.9511 | auc_eu: 0.9688
# 	test: loss: 0.4936 | auc_cos: 0.9178 | auc_eu: 0.9298
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 52:
# 	train: loss: 1.1235 | auc_cos: 0.9553 | auc_eu: 0.9699
# 	test: loss: 0.5078 | auc_cos: 0.9181 | auc_eu: 0.9281
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 53:
# 	train: loss: 0.9985 | auc_cos: 0.9546 | auc_eu: 0.9705
# 	test: loss: 0.5424 | auc_cos: 0.9169 | auc_eu: 0.9278
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 54:
# 	train: loss: 0.8133 | auc_cos: 0.9550 | auc_eu: 0.9697
# 	test: loss: 0.4748 | auc_cos: 0.9164 | auc_eu: 0.9267
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 55:
# 	train: loss: 1.4185 | auc_cos: 0.9552 | auc_eu: 0.9672
# 	test: loss: 0.5450 | auc_cos: 0.9186 | auc_eu: 0.9239
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 56:
# 	train: loss: 1.1929 | auc_cos: 0.9561 | auc_eu: 0.9686
# 	test: loss: 0.6125 | auc_cos: 0.9174 | auc_eu: 0.9256
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 57:
# 	train: loss: 1.6093 | auc_cos: 0.9534 | auc_eu: 0.9681
# 	test: loss: 0.6309 | auc_cos: 0.9169 | auc_eu: 0.9235
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 58:
# 	train: loss: 1.0555 | auc_cos: 0.9562 | auc_eu: 0.9691
# 	test: loss: 0.5152 | auc_cos: 0.9182 | auc_eu: 0.9245
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 59:
# 	train: loss: 0.7919 | auc_cos: 0.9577 | auc_eu: 0.9705
# 	test: loss: 0.5157 | auc_cos: 0.9167 | auc_eu: 0.9256
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 60:
# 	train: loss: 0.6595 | auc_cos: 0.9543 | auc_eu: 0.9685
# 	test: loss: 0.6425 | auc_cos: 0.9129 | auc_eu: 0.9232
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 61:
# 	train: loss: 0.9853 | auc_cos: 0.9531 | auc_eu: 0.9662
# 	test: loss: 0.4544 | auc_cos: 0.9152 | auc_eu: 0.9227
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 62:
# 	train: loss: 1.5862 | auc_cos: 0.9492 | auc_eu: 0.9631
# 	test: loss: 0.8416 | auc_cos: 0.9144 | auc_eu: 0.9208
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 63:
# 	train: loss: 1.0169 | auc_cos: 0.9528 | auc_eu: 0.9645
# 	test: loss: 0.4499 | auc_cos: 0.9199 | auc_eu: 0.9211
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 64:
# 	train: loss: 0.8956 | auc_cos: 0.9516 | auc_eu: 0.9641
# 	test: loss: 0.6456 | auc_cos: 0.9181 | auc_eu: 0.9207
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 65:
# 	train: loss: 1.5666 | auc_cos: 0.9522 | auc_eu: 0.9654
# 	test: loss: 0.4995 | auc_cos: 0.9183 | auc_eu: 0.9239
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 66:
# 	train: loss: 1.3802 | auc_cos: 0.9446 | auc_eu: 0.9629
# 	test: loss: 0.2226 | auc_cos: 0.9149 | auc_eu: 0.9257
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 67:
# 	train: loss: 1.3435 | auc_cos: 0.9489 | auc_eu: 0.9637
# 	test: loss: 0.4430 | auc_cos: 0.9158 | auc_eu: 0.9232
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 68:
# 	train: loss: 1.1570 | auc_cos: 0.9527 | auc_eu: 0.9662
# 	test: loss: 0.4324 | auc_cos: 0.9155 | auc_eu: 0.9261
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 69:
# 	train: loss: 1.4895 | auc_cos: 0.9518 | auc_eu: 0.9631
# 	test: loss: 0.2303 | auc_cos: 0.9159 | auc_eu: 0.9248
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 70:
# 	train: loss: 1.5372 | auc_cos: 0.9520 | auc_eu: 0.9644
# 	test: loss: 0.2040 | auc_cos: 0.9165 | auc_eu: 0.9263
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 71:
# 	train: loss: 1.1172 | auc_cos: 0.9554 | auc_eu: 0.9699
# 	test: loss: 0.3669 | auc_cos: 0.9164 | auc_eu: 0.9247
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 72:
# 	train: loss: 1.1509 | auc_cos: 0.9534 | auc_eu: 0.9682
# 	test: loss: 0.3694 | auc_cos: 0.9181 | auc_eu: 0.9274
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 73:
# 	train: loss: 1.2762 | auc_cos: 0.9568 | auc_eu: 0.9688
# 	test: loss: 0.3397 | auc_cos: 0.9221 | auc_eu: 0.9253
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 74:
# 	train: loss: 1.1400 | auc_cos: 0.9544 | auc_eu: 0.9655
# 	test: loss: 0.4907 | auc_cos: 0.9207 | auc_eu: 0.9276
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 75:
# 	train: loss: 0.9179 | auc_cos: 0.9572 | auc_eu: 0.9671
# 	test: loss: 0.4152 | auc_cos: 0.9201 | auc_eu: 0.9255
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 76:
# 	train: loss: 1.4842 | auc_cos: 0.9556 | auc_eu: 0.9689
# 	test: loss: 0.2806 | auc_cos: 0.9173 | auc_eu: 0.9300
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 77:
# 	train: loss: 1.1870 | auc_cos: 0.9604 | auc_eu: 0.9697
# 	test: loss: 0.2094 | auc_cos: 0.9220 | auc_eu: 0.9252
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 78:
# 	train: loss: 1.0731 | auc_cos: 0.9578 | auc_eu: 0.9679
# 	test: loss: 0.2940 | auc_cos: 0.9222 | auc_eu: 0.9265
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 79:
# 	train: loss: 0.9763 | auc_cos: 0.9586 | auc_eu: 0.9687
# 	test: loss: 0.2827 | auc_cos: 0.9170 | auc_eu: 0.9251
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 80:
# 	train: loss: 0.9706 | auc_cos: 0.9570 | auc_eu: 0.9691
# 	test: loss: 0.2373 | auc_cos: 0.9188 | auc_eu: 0.9243
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 81:
# 	train: loss: 1.0182 | auc_cos: 0.9604 | auc_eu: 0.9703
# 	test: loss: 0.2566 | auc_cos: 0.9227 | auc_eu: 0.9268
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 82:
# 	train: loss: 0.8696 | auc_cos: 0.9594 | auc_eu: 0.9717
# 	test: loss: 0.3407 | auc_cos: 0.9194 | auc_eu: 0.9248
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 83:
# 	train: loss: 1.0515 | auc_cos: 0.9578 | auc_eu: 0.9713
# 	test: loss: 0.4416 | auc_cos: 0.9161 | auc_eu: 0.9242
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 84:
# 	train: loss: 1.2293 | auc_cos: 0.9576 | auc_eu: 0.9695
# 	test: loss: 0.2567 | auc_cos: 0.9147 | auc_eu: 0.9238
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 85:
# 	train: loss: 0.9139 | auc_cos: 0.9606 | auc_eu: 0.9698
# 	test: loss: 0.3638 | auc_cos: 0.9200 | auc_eu: 0.9207
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 86:
# 	train: loss: 1.0815 | auc_cos: 0.9593 | auc_eu: 0.9703
# 	test: loss: 0.3293 | auc_cos: 0.9222 | auc_eu: 0.9273
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 87:
# 	train: loss: 1.0697 | auc_cos: 0.9612 | auc_eu: 0.9705
# 	test: loss: 0.4130 | auc_cos: 0.9210 | auc_eu: 0.9239
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 88:
# 	train: loss: 1.0574 | auc_cos: 0.9579 | auc_eu: 0.9710
# 	test: loss: 0.4089 | auc_cos: 0.9192 | auc_eu: 0.9247
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 89:
# 	train: loss: 1.2429 | auc_cos: 0.9617 | auc_eu: 0.9723
# 	test: loss: 0.4263 | auc_cos: 0.9151 | auc_eu: 0.9225
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 90:
# 	train: loss: 1.1810 | auc_cos: 0.9520 | auc_eu: 0.9667
# 	test: loss: 0.5053 | auc_cos: 0.9148 | auc_eu: 0.9289
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 91:
# 	train: loss: 1.1528 | auc_cos: 0.9524 | auc_eu: 0.9674
# 	test: loss: 0.3108 | auc_cos: 0.9131 | auc_eu: 0.9300
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 92:
# 	train: loss: 1.8247 | auc_cos: 0.9511 | auc_eu: 0.9659
# 	test: loss: 0.8046 | auc_cos: 0.9061 | auc_eu: 0.9253
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 93:
# 	train: loss: 0.7045 | auc_cos: 0.9488 | auc_eu: 0.9644
# 	test: loss: 0.4320 | auc_cos: 0.9102 | auc_eu: 0.9249
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 94:
# 	train: loss: 1.0079 | auc_cos: 0.9517 | auc_eu: 0.9655
# 	test: loss: 0.8600 | auc_cos: 0.9093 | auc_eu: 0.9177
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 95:
# 	train: loss: 1.2438 | auc_cos: 0.9519 | auc_eu: 0.9653
# 	test: loss: 0.8651 | auc_cos: 0.9119 | auc_eu: 0.9209
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 96:
# 	train: loss: 1.6996 | auc_cos: 0.9467 | auc_eu: 0.9624
# 	test: loss: 0.4340 | auc_cos: 0.9147 | auc_eu: 0.9247
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 97:
# 	train: loss: 1.6645 | auc_cos: 0.9451 | auc_eu: 0.9647
# 	test: loss: 0.5285 | auc_cos: 0.9092 | auc_eu: 0.9263
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 98:
# 	train: loss: 1.1748 | auc_cos: 0.9517 | auc_eu: 0.9627
# 	test: loss: 0.7222 | auc_cos: 0.9195 | auc_eu: 0.9228
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 99:
# 	train: loss: 1.3503 | auc_cos: 0.9507 | auc_eu: 0.9643
# 	test: loss: 0.4334 | auc_cos: 0.9126 | auc_eu: 0.9169
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 100:
# 	train: loss: 1.0559 | auc_cos: 0.9534 | auc_eu: 0.9648
# 	test: loss: 0.7369 | auc_cos: 0.9178 | auc_eu: 0.9169
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 101:
# 	train: loss: 1.1287 | auc_cos: 0.9558 | auc_eu: 0.9678
# 	test: loss: 0.7158 | auc_cos: 0.9176 | auc_eu: 0.9200
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 102:
# 	train: loss: 1.2217 | auc_cos: 0.9540 | auc_eu: 0.9677
# 	test: loss: 0.4635 | auc_cos: 0.9135 | auc_eu: 0.9255
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 103:
# 	train: loss: 1.2690 | auc_cos: 0.9560 | auc_eu: 0.9686
# 	test: loss: 0.5031 | auc_cos: 0.9183 | auc_eu: 0.9252
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 104:
# 	train: loss: 0.9585 | auc_cos: 0.9547 | auc_eu: 0.9682
# 	test: loss: 0.5730 | auc_cos: 0.9209 | auc_eu: 0.9275
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 105:
# 	train: loss: 0.8287 | auc_cos: 0.9545 | auc_eu: 0.9673
# 	test: loss: 0.3870 | auc_cos: 0.9193 | auc_eu: 0.9257
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 106:
# 	train: loss: 1.5172 | auc_cos: 0.9528 | auc_eu: 0.9669
# 	test: loss: 0.4498 | auc_cos: 0.9195 | auc_eu: 0.9288
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 107:
# 	train: loss: 1.2198 | auc_cos: 0.9547 | auc_eu: 0.9680
# 	test: loss: 0.3346 | auc_cos: 0.9186 | auc_eu: 0.9293
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 108:
# 	train: loss: 1.4177 | auc_cos: 0.9549 | auc_eu: 0.9664
# 	test: loss: 0.3443 | auc_cos: 0.9178 | auc_eu: 0.9254
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 109:
# 	train: loss: 0.9449 | auc_cos: 0.9571 | auc_eu: 0.9695
# 	test: loss: 0.5021 | auc_cos: 0.9163 | auc_eu: 0.9269
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 110:
# 	train: loss: 1.2511 | auc_cos: 0.9568 | auc_eu: 0.9681
# 	test: loss: 0.4267 | auc_cos: 0.9201 | auc_eu: 0.9270
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 111:
# 	train: loss: 1.0043 | auc_cos: 0.9512 | auc_eu: 0.9667
# 	test: loss: 0.6003 | auc_cos: 0.9189 | auc_eu: 0.9270
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 112:
# 	train: loss: 1.1028 | auc_cos: 0.9545 | auc_eu: 0.9677
# 	test: loss: 0.4782 | auc_cos: 0.9141 | auc_eu: 0.9262
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 113:
# 	train: loss: 0.7681 | auc_cos: 0.9553 | auc_eu: 0.9687
# 	test: loss: 0.5095 | auc_cos: 0.9208 | auc_eu: 0.9279
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 114:
# 	train: loss: 1.2564 | auc_cos: 0.9558 | auc_eu: 0.9688
# 	test: loss: 0.5812 | auc_cos: 0.9187 | auc_eu: 0.9266
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 115:
# 	train: loss: 1.1538 | auc_cos: 0.9580 | auc_eu: 0.9680
# 	test: loss: 0.5531 | auc_cos: 0.9190 | auc_eu: 0.9231
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 116:
# 	train: loss: 1.4068 | auc_cos: 0.9573 | auc_eu: 0.9702
# 	test: loss: 0.5896 | auc_cos: 0.9189 | auc_eu: 0.9258
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 117:
# 	train: loss: 1.2349 | auc_cos: 0.9578 | auc_eu: 0.9684
# 	test: loss: 0.4282 | auc_cos: 0.9227 | auc_eu: 0.9259
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 118:
# 	train: loss: 1.0818 | auc_cos: 0.9565 | auc_eu: 0.9709
# 	test: loss: 0.3599 | auc_cos: 0.9206 | auc_eu: 0.9305
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 119:
# 	train: loss: 0.9162 | auc_cos: 0.9606 | auc_eu: 0.9697
# 	test: loss: 0.5379 | auc_cos: 0.9226 | auc_eu: 0.9271
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth

# %%
# !zip -r output.zip checkpoint/triplet/concat
