# %%
# !git clone https://github.com/nkt780426/concat.git
# Out:
# Cloning into 'concat'...
# remote: Enumerating objects: 519, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 519 (delta 20), reused 64 (delta 16), pack-reused 445 (from 1)
# Receiving objects: 100% (519/519), 77.81 MiB | 42.16 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# !gdown --quiet --folder "https://drive.google.com/drive/folders/111XLjyrsaLIAu4BsW8ZhLa68vnWLDLnH?usp=sharing"

# %%
# !mv concat/going_modular .

# %%
# !ls -la
# Out:
# total 52
# drwxr-xr-x 5 root root  4096 Dec 21 18:03 .
# drwxr-xr-x 6 root root  4096 Dec 21 18:02 ..
# drwxr-xr-x 3 root root  4096 Dec 21 18:02 checkpoint
# drwxr-xr-x 6 root root  4096 Dec 21 18:03 concat
# drwxr-xr-x 8 root root  4096 Dec 21 18:02 going_modular
# ---------- 1 root root 32036 Dec 21 18:03 __notebook__.ipynb

# %%
import warnings
warnings.filterwarnings("ignore")
import torch
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import albumentations as A


from going_modular.model.TripletFaceRecognition import EmbeddingNet_Concat_V2, TripletNet_Concat_V2
from going_modular.dataloader.triplet import TripletDatasetConcatV2
from going_modular.loss.TripletLoss import TripletLoss
from going_modular.dataloader.triplet import CustomExrDatasetConCatV2
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.train_eval.triplet.train import fit

import os

import warnings
warnings.filterwarnings("ignore")

device = "cuda" if torch.cuda.is_available() else "cpu"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Đặt seed toàn cục
seed = 42
torch.manual_seed(seed)

CONFIGURATION = {
    'type': 'concat',
    # Thư mục
    'data_dir': '/kaggle/input/hoangvn-3dfacerecognition',
    'checkpoint_dir': './checkpoint/new/',
    'normalmap_checkpoint': './checkpoint/new/normalmap/models/checkpoint.pth',
    'albedo_checkpoint': './checkpoint/new/albedo/iresnet18/models/checkpoint.pth',
    'depthmap_checkpoint': './checkpoint/new/depthmap/iresnet34/models/checkpoint.pth',

    # Cấu hình train
    'epochs': 387,
    'num_workers': 4,
    'batch_size': 16,
    'image_size': 256,
    'embedding_size': 512,
    
    'start_lr': 1e-4,
    'weight_decay': 5e-4,
    'momentum': 0.9,
    'alpha': 0.9,
    
    # triplet
    'margin': 1.,
}


train_transform = A.Compose([
    RandomResizedCropRect(256),
    GaussianNoise(),
], additional_targets={
    'albedo': 'image',
    'depthmap': 'image'
})


test_transform = A.Compose([
    A.Resize(height=CONFIGURATION['image_size'], width=CONFIGURATION['image_size'])
], additional_targets={
    'albedo': 'image',
    'depthmap': 'image'
})

triplet_concat_train_dataset = TripletDatasetConcatV2(data_dir=CONFIGURATION['data_dir'], transform=train_transform, train=True)
triplet_concat_test_dataset = TripletDatasetConcatV2(data_dir=CONFIGURATION['data_dir'], transform=test_transform, train=False)


triplet_concat_train_loader = DataLoader(
    triplet_concat_train_dataset, 
    batch_size=CONFIGURATION['batch_size'], 
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    drop_last=True
)


triplet_concat_test_loader = DataLoader(
    triplet_concat_test_dataset, 
    batch_size=CONFIGURATION['batch_size'], 
    shuffle=False,
    num_workers=4,
    pin_memory=True,
    drop_last=True
)


roc_concat_train_dataset = CustomExrDatasetConCatV2(data_dir=CONFIGURATION['data_dir'], transform=train_transform, train=True)
roc_concat_train_loader = DataLoader(
    roc_concat_train_dataset,
    num_workers=4,
    batch_size=CONFIGURATION['batch_size'],
)

roc_concat_test_dataset = CustomExrDatasetConCatV2(data_dir=CONFIGURATION['data_dir'], transform=test_transform, train=False)
roc_test_loader = DataLoader(
    roc_concat_test_dataset,
    num_workers=4,
    batch_size=CONFIGURATION['batch_size'],
)

normal_checkpoint = torch.load(CONFIGURATION['normalmap_checkpoint'])
new_normalmap_state_dict = {}
for key, value in normal_checkpoint.items():
    new_key = key[14:]  # Cắt bỏ 14 ký tự đầu tiên
    new_normalmap_state_dict[new_key] = value
    
albedo_checkpoint = torch.load(CONFIGURATION['albedo_checkpoint'])
new_albedo_state_dict = {}
for key, value in albedo_checkpoint.items():
    new_key = key[14:]  # Cắt bỏ 14 ký tự đầu tiên
    new_albedo_state_dict[new_key] = value
    
depthmap_checkpoint = torch.load(CONFIGURATION['depthmap_checkpoint'])
new_depthmap_state_dict = {}
for key, value in depthmap_checkpoint.items():
    new_key = key[14:]  # Cắt bỏ 14 ký tự đầu tiên
    new_depthmap_state_dict[new_key] = value

embedding_net = EmbeddingNet_Concat_V2(conf=CONFIGURATION)

embedding_net.resnet1.load_state_dict(new_normalmap_state_dict)

embedding_net.resnet2.load_state_dict(new_albedo_state_dict)

embedding_net.resnet3.load_state_dict(new_depthmap_state_dict)

model = TripletNet_Concat_V2(embedding_net)

# Freeze 3 mạng lại
for param in model.embedding_net.resnet1.parameters():
    param.requires_grad = False
    
for param in model.embedding_net.resnet2.parameters():
    param.requires_grad = False

for param in model.embedding_net.resnet3.parameters():
    param.requires_grad = False
    
criterion = TripletLoss(CONFIGURATION['margin'])
optimizer = Adam(model.parameters(), lr=CONFIGURATION['start_lr'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=30, T_mult=1, eta_min=1e-6)

earlystop_dir = os.path.abspath(CONFIGURATION['checkpoint_dir'] + CONFIGURATION['type'] + '/models')

early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['cosine_auc', 'euclidean_auc'],
    patience=1000,
    mode='max',
    verbose=0,
    save_dir=earlystop_dir,
    start_from_epoch=0
)      

checkpoint_path = os.path.abspath(CONFIGURATION['checkpoint_dir'] + CONFIGURATION['type'] + '/models/checkpoint.pth')
modle_checkpoint = ModelCheckpoint(filepath=checkpoint_path, verbose=1)

# %%
fit(
    conf=CONFIGURATION,
    start_epoch=0,
    model=model,
    triplet_train_loader=triplet_concat_train_loader, 
    triplet_test_loader=triplet_concat_test_loader, 
    criterion=criterion,
    optimizer=optimizer, 
    scheduler=scheduler, 
    epochs=CONFIGURATION['epochs'], 
    device=device,
    roc_train_loader=roc_concat_train_loader, 
    roc_test_loader=roc_test_loader,
    early_stopping=early_stopping,
    model_checkpoint=modle_checkpoint
)
# Out:
# Epoch 1:
# 	train: loss: 0.0578 | auc_cos: 0.9888 | auc_eu: 0.9940
# 	test: loss: 0.1897 | auc_cos: 0.9399 | auc_eu: 0.9626
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 2:
# 	train: loss: 0.0080 | auc_cos: 0.9877 | auc_eu: 0.9935
# 	test: loss: 0.5490 | auc_cos: 0.9419 | auc_eu: 0.9623
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 3:
# 	train: loss: 0.0000 | auc_cos: 0.9872 | auc_eu: 0.9937
# 	test: loss: 0.4809 | auc_cos: 0.9401 | auc_eu: 0.9631
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 4:
# 	train: loss: 0.0353 | auc_cos: 0.9867 | auc_eu: 0.9941
# 	test: loss: 0.0434 | auc_cos: 0.9409 | auc_eu: 0.9614
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 5:
# 	train: loss: 0.1457 | auc_cos: 0.9899 | auc_eu: 0.9954
# 	test: loss: 0.3207 | auc_cos: 0.9523 | auc_eu: 0.9697
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 6:
# 	train: loss: 0.0000 | auc_cos: 0.9899 | auc_eu: 0.9960
# 	test: loss: 0.3657 | auc_cos: 0.9511 | auc_eu: 0.9691
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 7:
# 	train: loss: 0.0659 | auc_cos: 0.9876 | auc_eu: 0.9947
# 	test: loss: 0.3383 | auc_cos: 0.9526 | auc_eu: 0.9693
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 8:
# 	train: loss: 0.1969 | auc_cos: 0.9912 | auc_eu: 0.9950
# 	test: loss: 0.2331 | auc_cos: 0.9497 | auc_eu: 0.9684
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 9:
# 	train: loss: 0.1246 | auc_cos: 0.9902 | auc_eu: 0.9946
# 	test: loss: 0.1054 | auc_cos: 0.9496 | auc_eu: 0.9665
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 10:
# 	train: loss: 0.0436 | auc_cos: 0.9898 | auc_eu: 0.9955
# 	test: loss: 0.0842 | auc_cos: 0.9507 | auc_eu: 0.9711
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 11:
# 	train: loss: 0.0727 | auc_cos: 0.9901 | auc_eu: 0.9962
# 	test: loss: 0.3518 | auc_cos: 0.9410 | auc_eu: 0.9692
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 12:
# 	train: loss: 0.0040 | auc_cos: 0.9897 | auc_eu: 0.9948
# 	test: loss: 0.1891 | auc_cos: 0.9461 | auc_eu: 0.9676
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 13:
# 	train: loss: 0.0085 | auc_cos: 0.9904 | auc_eu: 0.9949
# 	test: loss: 0.2324 | auc_cos: 0.9408 | auc_eu: 0.9669
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 14:
# 	train: loss: 0.1376 | auc_cos: 0.9908 | auc_eu: 0.9960
# 	test: loss: 0.0814 | auc_cos: 0.9410 | auc_eu: 0.9668
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 15:
# 	train: loss: 0.0276 | auc_cos: 0.9906 | auc_eu: 0.9952
# 	test: loss: 0.0585 | auc_cos: 0.9374 | auc_eu: 0.9654
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 16:
# 	train: loss: 0.0542 | auc_cos: 0.9892 | auc_eu: 0.9945
# 	test: loss: 0.1617 | auc_cos: 0.9306 | auc_eu: 0.9626
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 17:
# 	train: loss: 0.0000 | auc_cos: 0.9888 | auc_eu: 0.9948
# 	test: loss: 0.2846 | auc_cos: 0.9350 | auc_eu: 0.9645
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 18:
# 	train: loss: 0.0000 | auc_cos: 0.9899 | auc_eu: 0.9950
# 	test: loss: 0.3564 | auc_cos: 0.9371 | auc_eu: 0.9656
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 19:
# 	train: loss: 0.0235 | auc_cos: 0.9905 | auc_eu: 0.9955
# 	test: loss: 0.2402 | auc_cos: 0.9349 | auc_eu: 0.9653
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 20:
# 	train: loss: 0.0000 | auc_cos: 0.9881 | auc_eu: 0.9942
# 	test: loss: 0.1728 | auc_cos: 0.9310 | auc_eu: 0.9644
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 21:
# 	train: loss: 0.0000 | auc_cos: 0.9904 | auc_eu: 0.9947
# 	test: loss: 0.3645 | auc_cos: 0.9371 | auc_eu: 0.9650
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 22:
# 	train: loss: 0.1058 | auc_cos: 0.9905 | auc_eu: 0.9952
# 	test: loss: 0.2543 | auc_cos: 0.9376 | auc_eu: 0.9657
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 23:
# 	train: loss: 0.0846 | auc_cos: 0.9908 | auc_eu: 0.9946
# 	test: loss: 0.1706 | auc_cos: 0.9365 | auc_eu: 0.9646
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 24:
# 	train: loss: 0.0853 | auc_cos: 0.9908 | auc_eu: 0.9955
# 	test: loss: 0.1996 | auc_cos: 0.9381 | auc_eu: 0.9654
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 25:
# 	train: loss: 0.0000 | auc_cos: 0.9904 | auc_eu: 0.9953
# 	test: loss: 0.2831 | auc_cos: 0.9354 | auc_eu: 0.9647
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 26:
# 	train: loss: 0.0336 | auc_cos: 0.9904 | auc_eu: 0.9951
# 	test: loss: 0.3002 | auc_cos: 0.9360 | auc_eu: 0.9653
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 27:
# 	train: loss: 0.1713 | auc_cos: 0.9910 | auc_eu: 0.9954
# 	test: loss: 0.2594 | auc_cos: 0.9367 | auc_eu: 0.9658
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 28:
# 	train: loss: 0.0989 | auc_cos: 0.9889 | auc_eu: 0.9948
# 	test: loss: 0.1995 | auc_cos: 0.9288 | auc_eu: 0.9640
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 29:
# 	train: loss: 0.1764 | auc_cos: 0.9917 | auc_eu: 0.9962
# 	test: loss: 0.2770 | auc_cos: 0.9422 | auc_eu: 0.9677
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 30:
# 	train: loss: 0.0810 | auc_cos: 0.9899 | auc_eu: 0.9954
# 	test: loss: 0.2017 | auc_cos: 0.9403 | auc_eu: 0.9604
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 31:
# 	train: loss: 0.0370 | auc_cos: 0.9928 | auc_eu: 0.9957
# 	test: loss: 0.3959 | auc_cos: 0.9485 | auc_eu: 0.9622
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 32:
# 	train: loss: 0.1189 | auc_cos: 0.9932 | auc_eu: 0.9962
# 	test: loss: 0.5442 | auc_cos: 0.9544 | auc_eu: 0.9682
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 33:
# 	train: loss: 0.1137 | auc_cos: 0.9928 | auc_eu: 0.9959
# 	test: loss: 0.3983 | auc_cos: 0.9505 | auc_eu: 0.9678
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 34:
# 	train: loss: 0.0000 | auc_cos: 0.9920 | auc_eu: 0.9959
# 	test: loss: 0.3759 | auc_cos: 0.9351 | auc_eu: 0.9651
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 35:
# 	train: loss: 0.0747 | auc_cos: 0.9932 | auc_eu: 0.9963
# 	test: loss: 0.3181 | auc_cos: 0.9451 | auc_eu: 0.9665
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 36:
# 	train: loss: 0.0000 | auc_cos: 0.9935 | auc_eu: 0.9966
# 	test: loss: 0.2116 | auc_cos: 0.9436 | auc_eu: 0.9654
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 37:
# 	train: loss: 0.1847 | auc_cos: 0.9933 | auc_eu: 0.9969
# 	test: loss: 0.0000 | auc_cos: 0.9516 | auc_eu: 0.9673
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 38:
# 	train: loss: 0.0429 | auc_cos: 0.9930 | auc_eu: 0.9964
# 	test: loss: 0.0478 | auc_cos: 0.9466 | auc_eu: 0.9674
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 39:
# 	train: loss: 0.0229 | auc_cos: 0.9931 | auc_eu: 0.9969
# 	test: loss: 0.0883 | auc_cos: 0.9515 | auc_eu: 0.9695
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 40:
# 	train: loss: 0.1247 | auc_cos: 0.9940 | auc_eu: 0.9968
# 	test: loss: 0.0000 | auc_cos: 0.9496 | auc_eu: 0.9681
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 41:
# 	train: loss: 0.1571 | auc_cos: 0.9940 | auc_eu: 0.9970
# 	test: loss: 0.0000 | auc_cos: 0.9467 | auc_eu: 0.9681
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 42:
# 	train: loss: 0.1279 | auc_cos: 0.9946 | auc_eu: 0.9969
# 	test: loss: 0.0000 | auc_cos: 0.9495 | auc_eu: 0.9692
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 43:
# 	train: loss: 0.1821 | auc_cos: 0.9938 | auc_eu: 0.9967
# 	test: loss: 0.0000 | auc_cos: 0.9534 | auc_eu: 0.9720
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 44:
# 	train: loss: 0.1366 | auc_cos: 0.9939 | auc_eu: 0.9968
# 	test: loss: 0.0000 | auc_cos: 0.9543 | auc_eu: 0.9705
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 45:
# 	train: loss: 0.1159 | auc_cos: 0.9943 | auc_eu: 0.9972
# 	test: loss: 0.0734 | auc_cos: 0.9537 | auc_eu: 0.9707
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 46:
# 	train: loss: 0.3088 | auc_cos: 0.9944 | auc_eu: 0.9966
# 	test: loss: 0.2784 | auc_cos: 0.9530 | auc_eu: 0.9700
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 47:
# 	train: loss: 0.1950 | auc_cos: 0.9942 | auc_eu: 0.9968
# 	test: loss: 0.5343 | auc_cos: 0.9526 | auc_eu: 0.9701
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 48:
# 	train: loss: 0.0000 | auc_cos: 0.9935 | auc_eu: 0.9967
# 	test: loss: 0.2638 | auc_cos: 0.9506 | auc_eu: 0.9702
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 49:
# 	train: loss: 0.1065 | auc_cos: 0.9937 | auc_eu: 0.9968
# 	test: loss: 0.0482 | auc_cos: 0.9549 | auc_eu: 0.9714
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 50:
# 	train: loss: 0.0387 | auc_cos: 0.9938 | auc_eu: 0.9971
# 	test: loss: 0.1049 | auc_cos: 0.9532 | auc_eu: 0.9709
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 51:
# 	train: loss: 0.0705 | auc_cos: 0.9942 | auc_eu: 0.9966
# 	test: loss: 0.3608 | auc_cos: 0.9579 | auc_eu: 0.9717
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 52:
# 	train: loss: 0.2823 | auc_cos: 0.9942 | auc_eu: 0.9975
# 	test: loss: 0.4694 | auc_cos: 0.9524 | auc_eu: 0.9703
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 53:
# 	train: loss: 0.0885 | auc_cos: 0.9941 | auc_eu: 0.9967
# 	test: loss: 0.5343 | auc_cos: 0.9558 | auc_eu: 0.9712
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 54:
# 	train: loss: 0.0000 | auc_cos: 0.9935 | auc_eu: 0.9970
# 	test: loss: 0.2357 | auc_cos: 0.9564 | auc_eu: 0.9716
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 55:
# 	train: loss: 0.0269 | auc_cos: 0.9943 | auc_eu: 0.9971
# 	test: loss: 0.3964 | auc_cos: 0.9544 | auc_eu: 0.9720
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 56:
# 	train: loss: 0.0336 | auc_cos: 0.9943 | auc_eu: 0.9973
# 	test: loss: 0.4127 | auc_cos: 0.9528 | auc_eu: 0.9710
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 57:
# 	train: loss: 0.0083 | auc_cos: 0.9941 | auc_eu: 0.9975
# 	test: loss: 0.3189 | auc_cos: 0.9509 | auc_eu: 0.9707
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 58:
# 	train: loss: 0.0602 | auc_cos: 0.9937 | auc_eu: 0.9967
# 	test: loss: 0.1117 | auc_cos: 0.9536 | auc_eu: 0.9703
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 59:
# 	train: loss: 0.0000 | auc_cos: 0.9942 | auc_eu: 0.9973
# 	test: loss: 0.4174 | auc_cos: 0.9558 | auc_eu: 0.9711
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 60:
# 	train: loss: 0.0391 | auc_cos: 0.9949 | auc_eu: 0.9972
# 	test: loss: 0.0000 | auc_cos: 0.9573 | auc_eu: 0.9780
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 61:
# 	train: loss: 0.0859 | auc_cos: 0.9934 | auc_eu: 0.9968
# 	test: loss: 0.0000 | auc_cos: 0.9596 | auc_eu: 0.9783
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 62:
# 	train: loss: 0.0000 | auc_cos: 0.9946 | auc_eu: 0.9971
# 	test: loss: 0.0000 | auc_cos: 0.9607 | auc_eu: 0.9789
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 63:
# 	train: loss: 0.1016 | auc_cos: 0.9952 | auc_eu: 0.9972
# 	test: loss: 0.0000 | auc_cos: 0.9639 | auc_eu: 0.9769
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 64:
# 	train: loss: 0.0805 | auc_cos: 0.9948 | auc_eu: 0.9971
# 	test: loss: 0.0000 | auc_cos: 0.9557 | auc_eu: 0.9759
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 65:
# 	train: loss: 0.0104 | auc_cos: 0.9932 | auc_eu: 0.9969
# 	test: loss: 0.0000 | auc_cos: 0.9567 | auc_eu: 0.9741
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 66:
# 	train: loss: 0.0668 | auc_cos: 0.9936 | auc_eu: 0.9976
# 	test: loss: 0.0000 | auc_cos: 0.9568 | auc_eu: 0.9726
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 67:
# 	train: loss: 0.5175 | auc_cos: 0.9933 | auc_eu: 0.9970
# 	test: loss: 0.0000 | auc_cos: 0.9570 | auc_eu: 0.9726
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 68:
# 	train: loss: 0.0729 | auc_cos: 0.9937 | auc_eu: 0.9968
# 	test: loss: 0.0000 | auc_cos: 0.9505 | auc_eu: 0.9684
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 69:
# 	train: loss: 0.3424 | auc_cos: 0.9926 | auc_eu: 0.9965
# 	test: loss: 0.0000 | auc_cos: 0.9510 | auc_eu: 0.9686
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 70:
# 	train: loss: 0.1060 | auc_cos: 0.9917 | auc_eu: 0.9965
# 	test: loss: 0.0000 | auc_cos: 0.9436 | auc_eu: 0.9696
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 71:
# 	train: loss: 0.0000 | auc_cos: 0.9924 | auc_eu: 0.9966
# 	test: loss: 0.0000 | auc_cos: 0.9531 | auc_eu: 0.9707
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 72:
# 	train: loss: 0.1362 | auc_cos: 0.9926 | auc_eu: 0.9968
# 	test: loss: 0.0000 | auc_cos: 0.9556 | auc_eu: 0.9706
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 73:
# 	train: loss: 0.1004 | auc_cos: 0.9936 | auc_eu: 0.9969
# 	test: loss: 0.0000 | auc_cos: 0.9608 | auc_eu: 0.9712
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 74:
# 	train: loss: 0.1349 | auc_cos: 0.9944 | auc_eu: 0.9970
# 	test: loss: 0.0000 | auc_cos: 0.9560 | auc_eu: 0.9697
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 75:
# 	train: loss: 0.0000 | auc_cos: 0.9940 | auc_eu: 0.9967
# 	test: loss: 0.0000 | auc_cos: 0.9542 | auc_eu: 0.9690
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 76:
# 	train: loss: 0.1592 | auc_cos: 0.9945 | auc_eu: 0.9972
# 	test: loss: 0.0000 | auc_cos: 0.9525 | auc_eu: 0.9716
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 77:
# 	train: loss: 0.0385 | auc_cos: 0.9944 | auc_eu: 0.9973
# 	test: loss: 0.0000 | auc_cos: 0.9575 | auc_eu: 0.9727
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 78:
# 	train: loss: 0.0380 | auc_cos: 0.9950 | auc_eu: 0.9974
# 	test: loss: 0.0000 | auc_cos: 0.9575 | auc_eu: 0.9728
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 79:
# 	train: loss: 0.0352 | auc_cos: 0.9946 | auc_eu: 0.9972
# 	test: loss: 0.0000 | auc_cos: 0.9586 | auc_eu: 0.9720
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 80:
# 	train: loss: 0.0825 | auc_cos: 0.9951 | auc_eu: 0.9974
# 	test: loss: 0.0000 | auc_cos: 0.9533 | auc_eu: 0.9700
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 81:
# 	train: loss: 0.4416 | auc_cos: 0.9939 | auc_eu: 0.9969
# 	test: loss: 0.0000 | auc_cos: 0.9502 | auc_eu: 0.9705
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 82:
# 	train: loss: 0.1998 | auc_cos: 0.9954 | auc_eu: 0.9975
# 	test: loss: 0.0000 | auc_cos: 0.9548 | auc_eu: 0.9707
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 83:
# 	train: loss: 0.0375 | auc_cos: 0.9948 | auc_eu: 0.9975
# 	test: loss: 0.0000 | auc_cos: 0.9467 | auc_eu: 0.9704
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 84:
# 	train: loss: 0.0000 | auc_cos: 0.9941 | auc_eu: 0.9974
# 	test: loss: 0.0000 | auc_cos: 0.9537 | auc_eu: 0.9718
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 85:
# 	train: loss: 0.0000 | auc_cos: 0.9949 | auc_eu: 0.9974
# 	test: loss: 0.0000 | auc_cos: 0.9531 | auc_eu: 0.9723
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 86:
# 	train: loss: 0.1186 | auc_cos: 0.9945 | auc_eu: 0.9974
# 	test: loss: 0.0000 | auc_cos: 0.9514 | auc_eu: 0.9716
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 87:
# 	train: loss: 0.0000 | auc_cos: 0.9950 | auc_eu: 0.9974
# 	test: loss: 0.0000 | auc_cos: 0.9561 | auc_eu: 0.9729
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 88:
# 	train: loss: 0.0937 | auc_cos: 0.9935 | auc_eu: 0.9973
# 	test: loss: 0.0000 | auc_cos: 0.9491 | auc_eu: 0.9698
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 89:
# 	train: loss: 0.2644 | auc_cos: 0.9946 | auc_eu: 0.9973
# 	test: loss: 0.0000 | auc_cos: 0.9506 | auc_eu: 0.9703
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 90:
# 	train: loss: 0.0502 | auc_cos: 0.9955 | auc_eu: 0.9977
# 	test: loss: 0.0000 | auc_cos: 0.9608 | auc_eu: 0.9731
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 91:
# 	train: loss: 0.1211 | auc_cos: 0.9946 | auc_eu: 0.9977
# 	test: loss: 0.0000 | auc_cos: 0.9618 | auc_eu: 0.9735
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 92:
# 	train: loss: 0.0711 | auc_cos: 0.9942 | auc_eu: 0.9974
# 	test: loss: 0.0000 | auc_cos: 0.9597 | auc_eu: 0.9757
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 93:
# 	train: loss: 0.1775 | auc_cos: 0.9916 | auc_eu: 0.9960
# 	test: loss: 0.0000 | auc_cos: 0.9420 | auc_eu: 0.9693
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 94:
# 	train: loss: 0.3515 | auc_cos: 0.9938 | auc_eu: 0.9970
# 	test: loss: 0.6074 | auc_cos: 0.9518 | auc_eu: 0.9757
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 95:
# 	train: loss: 0.0000 | auc_cos: 0.9938 | auc_eu: 0.9966
# 	test: loss: 0.4245 | auc_cos: 0.9557 | auc_eu: 0.9764
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 96:
# 	train: loss: 0.7273 | auc_cos: 0.9937 | auc_eu: 0.9970
# 	test: loss: 0.0000 | auc_cos: 0.9559 | auc_eu: 0.9775
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 97:
# 	train: loss: 0.5646 | auc_cos: 0.9937 | auc_eu: 0.9968
# 	test: loss: 0.6637 | auc_cos: 0.9599 | auc_eu: 0.9787
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 98:
# 	train: loss: 0.0132 | auc_cos: 0.9945 | auc_eu: 0.9974
# 	test: loss: 0.9009 | auc_cos: 0.9579 | auc_eu: 0.9786
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 99:
# 	train: loss: 0.0212 | auc_cos: 0.9947 | auc_eu: 0.9973
# 	test: loss: 0.0000 | auc_cos: 0.9680 | auc_eu: 0.9801
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 100:
# 	train: loss: 0.2787 | auc_cos: 0.9936 | auc_eu: 0.9971
# 	test: loss: 0.2589 | auc_cos: 0.9605 | auc_eu: 0.9784
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 101:
# 	train: loss: 0.0671 | auc_cos: 0.9929 | auc_eu: 0.9969
# 	test: loss: 0.3224 | auc_cos: 0.9600 | auc_eu: 0.9773
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 102:
# 	train: loss: 0.1758 | auc_cos: 0.9931 | auc_eu: 0.9963
# 	test: loss: 0.0000 | auc_cos: 0.9647 | auc_eu: 0.9795
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 103:
# 	train: loss: 0.0065 | auc_cos: 0.9935 | auc_eu: 0.9968
# 	test: loss: 0.0000 | auc_cos: 0.9659 | auc_eu: 0.9808
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 104:
# 	train: loss: 0.0000 | auc_cos: 0.9926 | auc_eu: 0.9967
# 	test: loss: 0.2662 | auc_cos: 0.9618 | auc_eu: 0.9802
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 105:
# 	train: loss: 0.1257 | auc_cos: 0.9930 | auc_eu: 0.9965
# 	test: loss: 0.1512 | auc_cos: 0.9644 | auc_eu: 0.9802
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 106:
# 	train: loss: 0.0465 | auc_cos: 0.9939 | auc_eu: 0.9966
# 	test: loss: 0.2466 | auc_cos: 0.9634 | auc_eu: 0.9793
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 107:
# 	train: loss: 0.0166 | auc_cos: 0.9934 | auc_eu: 0.9968
# 	test: loss: 0.4860 | auc_cos: 0.9631 | auc_eu: 0.9795
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 108:
# 	train: loss: 0.0585 | auc_cos: 0.9930 | auc_eu: 0.9966
# 	test: loss: 0.7285 | auc_cos: 0.9603 | auc_eu: 0.9786
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 109:
# 	train: loss: 0.1059 | auc_cos: 0.9936 | auc_eu: 0.9969
# 	test: loss: 0.4308 | auc_cos: 0.9631 | auc_eu: 0.9789
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 110:
# 	train: loss: 0.0156 | auc_cos: 0.9946 | auc_eu: 0.9971
# 	test: loss: 0.7365 | auc_cos: 0.9623 | auc_eu: 0.9777
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 111:
# 	train: loss: 0.1142 | auc_cos: 0.9945 | auc_eu: 0.9972
# 	test: loss: 0.6806 | auc_cos: 0.9653 | auc_eu: 0.9791
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 112:
# 	train: loss: 0.0000 | auc_cos: 0.9920 | auc_eu: 0.9969
# 	test: loss: 0.9683 | auc_cos: 0.9633 | auc_eu: 0.9790
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 113:
# 	train: loss: 0.0816 | auc_cos: 0.9937 | auc_eu: 0.9970
# 	test: loss: 0.5317 | auc_cos: 0.9647 | auc_eu: 0.9789
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 114:
# 	train: loss: 0.1792 | auc_cos: 0.9938 | auc_eu: 0.9969
# 	test: loss: 0.7731 | auc_cos: 0.9598 | auc_eu: 0.9784
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 115:
# 	train: loss: 0.2748 | auc_cos: 0.9934 | auc_eu: 0.9967
# 	test: loss: 1.1905 | auc_cos: 0.9614 | auc_eu: 0.9773
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 116:
# 	train: loss: 0.1635 | auc_cos: 0.9940 | auc_eu: 0.9970
# 	test: loss: 0.8206 | auc_cos: 0.9613 | auc_eu: 0.9785
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 117:
# 	train: loss: 0.1300 | auc_cos: 0.9944 | auc_eu: 0.9970
# 	test: loss: 1.0556 | auc_cos: 0.9615 | auc_eu: 0.9786
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth
# Epoch 118:
# 	train: loss: 0.1427 | auc_cos: 0.9943 | auc_eu: 0.9971
# 	test: loss: 0.9999 | auc_cos: 0.9685 | auc_eu: 0.9795
# 	Saving model and optimizer state to /kaggle/working/checkpoint/new/concat/models/checkpoint.pth

# %%
checkpoint = torch.load(CONFIGURATION['checkpoint_dir'] + CONFIGURATION['type'] + '/models/checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
print(epoch)

# %%
fit(
    conf=CONFIGURATION,
    start_epoch=epoch,
    model=model,
    triplet_train_loader=triplet_concat_train_loader, 
    triplet_test_loader=triplet_concat_test_loader, 
    criterion=criterion,
    optimizer=optimizer, 
    scheduler=scheduler, 
    epochs=CONFIGURATION['epochs'], 
    device=device,
    roc_train_loader=roc_concat_train_loader, 
    roc_test_loader=roc_test_loader,
    early_stopping=early_stopping,
    model_checkpoint=modle_checkpoint
)

# %%
# !zip -r output.zip checkpoint/new/concat
# Out:
#   adding: checkpoint/new/concat/ (stored 0%)
#   adding: checkpoint/new/concat/logs/ (stored 0%)
#   adding: checkpoint/new/concat/logs/Cosine_auc_test/ (stored 0%)
#   adding: checkpoint/new/concat/logs/Cosine_auc_test/events.out.tfevents.1734804322.3c7a2fe95029.21.4 (deflated 63%)
#   adding: checkpoint/new/concat/logs/Loss_train/ (stored 0%)
#   adding: checkpoint/new/concat/logs/Loss_train/events.out.tfevents.1734804322.3c7a2fe95029.21.1 (deflated 58%)
#   adding: checkpoint/new/concat/logs/Cosine_auc_train/ (stored 0%)
#   adding: checkpoint/new/concat/logs/Cosine_auc_train/events.out.tfevents.1734804322.3c7a2fe95029.21.3 (deflated 63%)
#   adding: checkpoint/new/concat/logs/events.out.tfevents.1734804214.3c7a2fe95029.21.0 (deflated 9%)
#   adding: checkpoint/new/concat/logs/Euclidean_auc_test/ (stored 0%)
#   adding: checkpoint/new/concat/logs/Euclidean_auc_test/events.out.tfevents.1734804322.3c7a2fe95029.21.6 (deflated 64%)
#   adding: checkpoint/new/concat/logs/Loss_test/ (stored 0%)
#   adding: checkpoint/new/concat/logs/Loss_test/events.out.tfevents.1734804322.3c7a2fe95029.21.2 (deflated 60%)
#   adding: checkpoint/new/concat/logs/Euclidean_auc_train/ (stored 0%)
#   adding: checkpoint/new/concat/logs/Euclidean_auc_train/events.out.tfevents.1734804322.3c7a2fe95029.21.5 (deflated 65%)
#   adding: checkpoint/new/concat/models/ (stored 0%)
#   adding: checkpoint/new/concat/models/best_cosine_auc_118.pth (deflated 7%)
#   adding: checkpoint/new/concat/models/best_euclidean_auc_103.pth (deflated 7%)
#   adding: checkpoint/new/concat/models/checkpoint.pth (deflated 7%)
