# %%
import os

import torch
from torchinfo import summary
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts

from going_modular.dataloader.magface import create_magface_dataloader
from going_modular.model.MagFaceRecognition import MagFaceRecognition
from going_modular.train_eval.train import fit
from going_modular.loss.MagLoss import MagLoss
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint

device = "cuda" if torch.cuda.is_available() else "cpu"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
CONFIGURATION = {
    # Thư mục
    'type': 'albedo',
    'train_dir': './Dataset/Albedo/train',
    'test_dir': './Dataset/Albedo/test',
    
    # Cấu hình train
    'backbone': 'iresnet50',
    'epochs': 2000,
    'num_workers': 4,
    'batch_size': 16,
    'image_size': 224,
    'num_class': len(os.listdir('./Dataset/Albedo/train')),
    'embedding_size': 512,
    
    'learning_rate': 0.1,
    'weight_decay': 5e-4,
    'momentum': 0.9,
    'alpha': 0.9,
    
    # Hàm m(ai) giúp thay đổi ai từ 0.25 đến 1.6
    'scale': 64,
    'lambda_g': 20,
    'l_margin': 0.45, 
    'u_margin': 0.8,
    'l_a': 10, 
    'u_a': 110,
}

# %%
# Đặt seed toàn cục
seed = 42
torch.manual_seed(seed)

# %%
train_dataloader, val_dataloader = create_magface_dataloader(CONFIGURATION, None, None)

# %%
dataiter = iter(train_dataloader)
images, labels = next(dataiter)
print(f"Labels: {images.shape}")
# Out:
# Labels: torch.Size([16, 3, 224, 224])

# %%
# summary(
#     model=MagFaceRecognition(CONFIGURATION), 
#     verbose=0, 
#     col_width=20, 
#     row_settings=["var_names"],
#     col_names=["input_size", 'output_size', "num_params", "trainable"],
#     input_size=(1,3,224,224)
# )

# %%
model = MagFaceRecognition(CONFIGURATION).to(device)
criterion = MagLoss(conf = CONFIGURATION)

# optimizer = torch.optim.SGD(
#         filter(lambda p: p.requires_grad, model.parameters()),
#         CONFIGURATION['learning_rate'],
#         momentum=CONFIGURATION['momentum'],
#         weight_decay=CONFIGURATION['weight_decay']
# )
optimizer = torch.optim.Adam(model.parameters(), lr=CONFIGURATION['learning_rate'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=40, T_mult=1, eta_min=1e-6)
checkpoint_path = os.path.abspath('checkpoint/magface/albedo/' + CONFIGURATION['backbone'] + '/models/checkpoint.pth')
modle_checkpoint = ModelCheckpoint(filepath=checkpoint_path, verbose=1)
earlystop_dir = os.path.abspath('checkpoint/magface/albedo/' + CONFIGURATION['backbone'] + '/models')
early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['val_euclidean_accuracy', 'val_cosine_accuracy', 'val_auc_euclidean', 'val_auc_cosine'],
    patience=40,
    mode='max',
    verbose=1,
    save_dir=earlystop_dir,
    start_from_epoch=60
)

# %%
fit(CONFIGURATION, 0, model, device, train_dataloader, val_dataloader, criterion, optimizer, scheduler, early_stopping, modle_checkpoint)
# Out:
# Epoch 1:
# 	train: loss 3.342 | loss id   3.32 | top_1_acc   0.00 | top_5_acc   0.03 | acc_eu: 0.491 | acc_cos: 0.208 | auc_eu: 0.578 | auc_cos: 0.531
# 	val: acc_eu: 0.824 | acc_cos: 0.177 | auc_eu: 0.597 | auc_cos: 0.504
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 2:
# 	train: loss 1.156 | loss id   1.13 | top_1_acc   0.01 | top_5_acc   0.02 | acc_eu: 0.504 | acc_cos: 0.489 | auc_eu: 0.572 | auc_cos: 0.555
# 	val: acc_eu: 0.687 | acc_cos: 0.500 | auc_eu: 0.585 | auc_cos: 0.556
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 3:
# 	train: loss 0.621 | loss id   0.60 | top_1_acc   0.00 | top_5_acc   0.04 | acc_eu: 0.533 | acc_cos: 0.335 | auc_eu: 0.583 | auc_cos: 0.606
# 	val: acc_eu: 0.593 | acc_cos: 0.457 | auc_eu: 0.606 | auc_cos: 0.637
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 4:
# 	train: loss 0.545 | loss id   0.52 | top_1_acc   0.01 | top_5_acc   0.04 | acc_eu: 0.400 | acc_cos: 0.389 | auc_eu: 0.620 | auc_cos: 0.632
# 	val: acc_eu: 0.617 | acc_cos: 0.628 | auc_eu: 0.655 | auc_cos: 0.672
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 5:
# 	train: loss 0.497 | loss id   0.47 | top_1_acc   0.01 | top_5_acc   0.05 | acc_eu: 0.400 | acc_cos: 0.400 | auc_eu: 0.602 | auc_cos: 0.598
# 	val: acc_eu: 0.522 | acc_cos: 0.521 | auc_eu: 0.616 | auc_cos: 0.612
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 6:
# 	train: loss 0.464 | loss id   0.44 | top_1_acc   0.01 | top_5_acc   0.05 | acc_eu: 0.484 | acc_cos: 0.503 | auc_eu: 0.649 | auc_cos: 0.657
# 	val: acc_eu: 0.620 | acc_cos: 0.647 | auc_eu: 0.692 | auc_cos: 0.707
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 7:
# 	train: loss 0.436 | loss id   0.41 | top_1_acc   0.01 | top_5_acc   0.05 | acc_eu: 0.511 | acc_cos: 0.410 | auc_eu: 0.617 | auc_cos: 0.637
# 	val: acc_eu: 0.726 | acc_cos: 0.738 | auc_eu: 0.666 | auc_cos: 0.685
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 8:
# 	train: loss 0.417 | loss id   0.39 | top_1_acc   0.02 | top_5_acc   0.06 | acc_eu: 0.512 | acc_cos: 0.475 | auc_eu: 0.613 | auc_cos: 0.636
# 	val: acc_eu: 0.683 | acc_cos: 0.473 | auc_eu: 0.669 | auc_cos: 0.694
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 9:
# 	train: loss 0.417 | loss id   0.39 | top_1_acc   0.01 | top_5_acc   0.05 | acc_eu: 0.517 | acc_cos: 0.433 | auc_eu: 0.607 | auc_cos: 0.649
# 	val: acc_eu: 0.746 | acc_cos: 0.595 | auc_eu: 0.665 | auc_cos: 0.706
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 10:
# 	train: loss 0.479 | loss id   0.46 | top_1_acc   0.01 | top_5_acc   0.06 | acc_eu: 0.441 | acc_cos: 0.421 | auc_eu: 0.614 | auc_cos: 0.651
# 	val: acc_eu: 0.695 | acc_cos: 0.498 | auc_eu: 0.663 | auc_cos: 0.696
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 11:
# 	train: loss 0.478 | loss id   0.46 | top_1_acc   0.01 | top_5_acc   0.06 | acc_eu: 0.422 | acc_cos: 0.532 | auc_eu: 0.610 | auc_cos: 0.662
# 	val: acc_eu: 0.679 | acc_cos: 0.552 | auc_eu: 0.636 | auc_cos: 0.715
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 12:
# 	train: loss 0.457 | loss id   0.43 | top_1_acc   0.00 | top_5_acc   0.06 | acc_eu: 0.543 | acc_cos: 0.727 | auc_eu: 0.618 | auc_cos: 0.674
# 	val: acc_eu: 0.638 | acc_cos: 0.681 | auc_eu: 0.647 | auc_cos: 0.751
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 13:
# 	train: loss 0.447 | loss id   0.42 | top_1_acc   0.02 | top_5_acc   0.06 | acc_eu: 0.597 | acc_cos: 0.606 | auc_eu: 0.640 | auc_cos: 0.693
# 	val: acc_eu: 0.601 | acc_cos: 0.662 | auc_eu: 0.679 | auc_cos: 0.737
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 14:
# 	train: loss 0.486 | loss id   0.46 | top_1_acc   0.02 | top_5_acc   0.07 | acc_eu: 0.450 | acc_cos: 0.590 | auc_eu: 0.632 | auc_cos: 0.682
# 	val: acc_eu: 0.681 | acc_cos: 0.566 | auc_eu: 0.664 | auc_cos: 0.740
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 15:
# 	train: loss 0.466 | loss id   0.44 | top_1_acc   0.01 | top_5_acc   0.08 | acc_eu: 0.549 | acc_cos: 0.548 | auc_eu: 0.653 | auc_cos: 0.659
# 	val: acc_eu: 0.738 | acc_cos: 0.810 | auc_eu: 0.706 | auc_cos: 0.708
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 16:
# 	train: loss 0.468 | loss id   0.44 | top_1_acc   0.02 | top_5_acc   0.09 | acc_eu: 0.586 | acc_cos: 0.580 | auc_eu: 0.652 | auc_cos: 0.678
# 	val: acc_eu: 0.698 | acc_cos: 0.642 | auc_eu: 0.690 | auc_cos: 0.717
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 17:
# 	train: loss 0.466 | loss id   0.44 | top_1_acc   0.02 | top_5_acc   0.08 | acc_eu: 0.604 | acc_cos: 0.595 | auc_eu: 0.684 | auc_cos: 0.709
# 	val: acc_eu: 0.816 | acc_cos: 0.749 | auc_eu: 0.743 | auc_cos: 0.769
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 18:
# 	train: loss 0.442 | loss id   0.42 | top_1_acc   0.02 | top_5_acc   0.09 | acc_eu: 0.648 | acc_cos: 0.627 | auc_eu: 0.664 | auc_cos: 0.713
# 	val: acc_eu: 0.727 | acc_cos: 0.753 | auc_eu: 0.699 | auc_cos: 0.756
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 19:
# 	train: loss 0.488 | loss id   0.47 | top_1_acc   0.02 | top_5_acc   0.09 | acc_eu: 0.652 | acc_cos: 0.579 | auc_eu: 0.671 | auc_cos: 0.731
# 	val: acc_eu: 0.703 | acc_cos: 0.765 | auc_eu: 0.719 | auc_cos: 0.785
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 20:
# 	train: loss 0.478 | loss id   0.45 | top_1_acc   0.02 | top_5_acc   0.09 | acc_eu: 0.660 | acc_cos: 0.581 | auc_eu: 0.690 | auc_cos: 0.732
# 	val: acc_eu: 0.748 | acc_cos: 0.721 | auc_eu: 0.731 | auc_cos: 0.768
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 21:
# 	train: loss 0.491 | loss id   0.47 | top_1_acc   0.02 | top_5_acc   0.10 | acc_eu: 0.683 | acc_cos: 0.634 | auc_eu: 0.702 | auc_cos: 0.726
# 	val: acc_eu: 0.790 | acc_cos: 0.603 | auc_eu: 0.743 | auc_cos: 0.764
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 22:
# 	train: loss 0.500 | loss id   0.48 | top_1_acc   0.02 | top_5_acc   0.11 | acc_eu: 0.647 | acc_cos: 0.630 | auc_eu: 0.693 | auc_cos: 0.729
# 	val: acc_eu: 0.603 | acc_cos: 0.657 | auc_eu: 0.740 | auc_cos: 0.760
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 23:
# 	train: loss 0.501 | loss id   0.48 | top_1_acc   0.03 | top_5_acc   0.12 | acc_eu: 0.635 | acc_cos: 0.586 | auc_eu: 0.666 | auc_cos: 0.699
# 	val: acc_eu: 0.746 | acc_cos: 0.678 | auc_eu: 0.697 | auc_cos: 0.739
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 24:
# 	train: loss 0.524 | loss id   0.50 | top_1_acc   0.03 | top_5_acc   0.13 | acc_eu: 0.723 | acc_cos: 0.680 | auc_eu: 0.712 | auc_cos: 0.756
# 	val: acc_eu: 0.639 | acc_cos: 0.714 | auc_eu: 0.774 | auc_cos: 0.821
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 25:
# 	train: loss 0.538 | loss id   0.52 | top_1_acc   0.04 | top_5_acc   0.14 | acc_eu: 0.730 | acc_cos: 0.690 | auc_eu: 0.709 | auc_cos: 0.745
# 	val: acc_eu: 0.731 | acc_cos: 0.765 | auc_eu: 0.767 | auc_cos: 0.821
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 26:
# 	train: loss 0.486 | loss id   0.46 | top_1_acc   0.04 | top_5_acc   0.16 | acc_eu: 0.713 | acc_cos: 0.695 | auc_eu: 0.711 | auc_cos: 0.783
# 	val: acc_eu: 0.758 | acc_cos: 0.851 | auc_eu: 0.767 | auc_cos: 0.846
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 27:
# 	train: loss 0.538 | loss id   0.51 | top_1_acc   0.05 | top_5_acc   0.20 | acc_eu: 0.658 | acc_cos: 0.682 | auc_eu: 0.731 | auc_cos: 0.769
# 	val: acc_eu: 0.684 | acc_cos: 0.774 | auc_eu: 0.765 | auc_cos: 0.800
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 28:
# 	train: loss 0.529 | loss id   0.51 | top_1_acc   0.06 | top_5_acc   0.19 | acc_eu: 0.719 | acc_cos: 0.699 | auc_eu: 0.759 | auc_cos: 0.824
# 	val: acc_eu: 0.684 | acc_cos: 0.612 | auc_eu: 0.784 | auc_cos: 0.829
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 29:
# 	train: loss 0.506 | loss id   0.48 | top_1_acc   0.05 | top_5_acc   0.20 | acc_eu: 0.676 | acc_cos: 0.704 | auc_eu: 0.755 | auc_cos: 0.817
# 	val: acc_eu: 0.765 | acc_cos: 0.785 | auc_eu: 0.784 | auc_cos: 0.825
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 30:
# 	train: loss 0.519 | loss id   0.50 | top_1_acc   0.07 | top_5_acc   0.24 | acc_eu: 0.712 | acc_cos: 0.732 | auc_eu: 0.782 | auc_cos: 0.837
# 	val: acc_eu: 0.670 | acc_cos: 0.764 | auc_eu: 0.799 | auc_cos: 0.828
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 31:
# 	train: loss 0.561 | loss id   0.54 | top_1_acc   0.08 | top_5_acc   0.26 | acc_eu: 0.733 | acc_cos: 0.739 | auc_eu: 0.767 | auc_cos: 0.841
# 	val: acc_eu: 0.731 | acc_cos: 0.786 | auc_eu: 0.795 | auc_cos: 0.863
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 32:
# 	train: loss 0.569 | loss id   0.55 | top_1_acc   0.09 | top_5_acc   0.30 | acc_eu: 0.711 | acc_cos: 0.668 | auc_eu: 0.748 | auc_cos: 0.776
# 	val: acc_eu: 0.724 | acc_cos: 0.771 | auc_eu: 0.770 | auc_cos: 0.798
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 33:
# 	train: loss 0.567 | loss id   0.54 | top_1_acc   0.10 | top_5_acc   0.30 | acc_eu: 0.771 | acc_cos: 0.745 | auc_eu: 0.768 | auc_cos: 0.810
# 	val: acc_eu: 0.877 | acc_cos: 0.819 | auc_eu: 0.814 | auc_cos: 0.851
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 34:
# 	train: loss 0.546 | loss id   0.52 | top_1_acc   0.11 | top_5_acc   0.34 | acc_eu: 0.790 | acc_cos: 0.753 | auc_eu: 0.819 | auc_cos: 0.856
# 	val: acc_eu: 0.851 | acc_cos: 0.810 | auc_eu: 0.832 | auc_cos: 0.862
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 35:
# 	train: loss 0.591 | loss id   0.57 | top_1_acc   0.12 | top_5_acc   0.35 | acc_eu: 0.776 | acc_cos: 0.764 | auc_eu: 0.811 | auc_cos: 0.856
# 	val: acc_eu: 0.832 | acc_cos: 0.904 | auc_eu: 0.827 | auc_cos: 0.861
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 36:
# 	train: loss 0.572 | loss id   0.55 | top_1_acc   0.14 | top_5_acc   0.38 | acc_eu: 0.761 | acc_cos: 0.775 | auc_eu: 0.839 | auc_cos: 0.863
# 	val: acc_eu: 0.850 | acc_cos: 0.852 | auc_eu: 0.851 | auc_cos: 0.887
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 37:
# 	train: loss 0.556 | loss id   0.53 | top_1_acc   0.17 | top_5_acc   0.44 | acc_eu: 0.757 | acc_cos: 0.785 | auc_eu: 0.843 | auc_cos: 0.881
# 	val: acc_eu: 0.898 | acc_cos: 0.899 | auc_eu: 0.842 | auc_cos: 0.891
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 38:
# 	train: loss 0.552 | loss id   0.53 | top_1_acc   0.16 | top_5_acc   0.43 | acc_eu: 0.756 | acc_cos: 0.740 | auc_eu: 0.824 | auc_cos: 0.856
# 	val: acc_eu: 0.877 | acc_cos: 0.813 | auc_eu: 0.842 | auc_cos: 0.888
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 39:
# 	train: loss 0.541 | loss id   0.52 | top_1_acc   0.17 | top_5_acc   0.43 | acc_eu: 0.782 | acc_cos: 0.793 | auc_eu: 0.842 | auc_cos: 0.883
# 	val: acc_eu: 0.815 | acc_cos: 0.790 | auc_eu: 0.841 | auc_cos: 0.893
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 40:
# 	train: loss 0.561 | loss id   0.54 | top_1_acc   0.20 | top_5_acc   0.47 | acc_eu: 0.802 | acc_cos: 0.785 | auc_eu: 0.841 | auc_cos: 0.894
# 	val: acc_eu: 0.903 | acc_cos: 0.866 | auc_eu: 0.825 | auc_cos: 0.891
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 41:
# 	train: loss 0.514 | loss id   0.49 | top_1_acc   0.21 | top_5_acc   0.50 | acc_eu: 0.792 | acc_cos: 0.747 | auc_eu: 0.764 | auc_cos: 0.804
# 	val: acc_eu: 0.876 | acc_cos: 0.797 | auc_eu: 0.774 | auc_cos: 0.807
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 42:
# 	train: loss 0.587 | loss id   0.56 | top_1_acc   0.22 | top_5_acc   0.55 | acc_eu: 0.801 | acc_cos: 0.767 | auc_eu: 0.859 | auc_cos: 0.862
# 	val: acc_eu: 0.854 | acc_cos: 0.841 | auc_eu: 0.850 | auc_cos: 0.855
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 43:
# 	train: loss 0.559 | loss id   0.54 | top_1_acc   0.21 | top_5_acc   0.53 | acc_eu: 0.807 | acc_cos: 0.795 | auc_eu: 0.843 | auc_cos: 0.868
# 	val: acc_eu: 0.819 | acc_cos: 0.896 | auc_eu: 0.847 | auc_cos: 0.877
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 44:
# 	train: loss 0.518 | loss id   0.49 | top_1_acc   0.22 | top_5_acc   0.56 | acc_eu: 0.774 | acc_cos: 0.782 | auc_eu: 0.802 | auc_cos: 0.828
# 	val: acc_eu: 0.811 | acc_cos: 0.894 | auc_eu: 0.836 | auc_cos: 0.856
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 45:
# 	train: loss 0.544 | loss id   0.52 | top_1_acc   0.23 | top_5_acc   0.55 | acc_eu: 0.771 | acc_cos: 0.791 | auc_eu: 0.843 | auc_cos: 0.870
# 	val: acc_eu: 0.882 | acc_cos: 0.826 | auc_eu: 0.841 | auc_cos: 0.871
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 46:
# 	train: loss 0.516 | loss id   0.49 | top_1_acc   0.29 | top_5_acc   0.60 | acc_eu: 0.812 | acc_cos: 0.795 | auc_eu: 0.854 | auc_cos: 0.900
# 	val: acc_eu: 0.869 | acc_cos: 0.864 | auc_eu: 0.845 | auc_cos: 0.889
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 47:
# 	train: loss 0.519 | loss id   0.50 | top_1_acc   0.28 | top_5_acc   0.61 | acc_eu: 0.816 | acc_cos: 0.800 | auc_eu: 0.890 | auc_cos: 0.915
# 	val: acc_eu: 0.881 | acc_cos: 0.879 | auc_eu: 0.867 | auc_cos: 0.903
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 48:
# 	train: loss 0.512 | loss id   0.49 | top_1_acc   0.27 | top_5_acc   0.60 | acc_eu: 0.826 | acc_cos: 0.834 | auc_eu: 0.863 | auc_cos: 0.917
# 	val: acc_eu: 0.827 | acc_cos: 0.825 | auc_eu: 0.840 | auc_cos: 0.893
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 49:
# 	train: loss 0.560 | loss id   0.54 | top_1_acc   0.29 | top_5_acc   0.65 | acc_eu: 0.820 | acc_cos: 0.855 | auc_eu: 0.890 | auc_cos: 0.925
# 	val: acc_eu: 0.886 | acc_cos: 0.823 | auc_eu: 0.852 | auc_cos: 0.899
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 50:
# 	train: loss 0.481 | loss id   0.46 | top_1_acc   0.31 | top_5_acc   0.65 | acc_eu: 0.847 | acc_cos: 0.810 | auc_eu: 0.877 | auc_cos: 0.919
# 	val: acc_eu: 0.875 | acc_cos: 0.806 | auc_eu: 0.848 | auc_cos: 0.902
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 51:
# 	train: loss 0.465 | loss id   0.44 | top_1_acc   0.32 | top_5_acc   0.67 | acc_eu: 0.780 | acc_cos: 0.804 | auc_eu: 0.841 | auc_cos: 0.877
# 	val: acc_eu: 0.776 | acc_cos: 0.802 | auc_eu: 0.813 | auc_cos: 0.866
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 52:
# 	train: loss 0.459 | loss id   0.44 | top_1_acc   0.31 | top_5_acc   0.68 | acc_eu: 0.801 | acc_cos: 0.822 | auc_eu: 0.878 | auc_cos: 0.913
# 	val: acc_eu: 0.855 | acc_cos: 0.764 | auc_eu: 0.846 | auc_cos: 0.885
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 53:
# 	train: loss 0.454 | loss id   0.43 | top_1_acc   0.32 | top_5_acc   0.68 | acc_eu: 0.757 | acc_cos: 0.805 | auc_eu: 0.849 | auc_cos: 0.879
# 	val: acc_eu: 0.898 | acc_cos: 0.822 | auc_eu: 0.842 | auc_cos: 0.871
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 54:
# 	train: loss 0.431 | loss id   0.41 | top_1_acc   0.34 | top_5_acc   0.70 | acc_eu: 0.807 | acc_cos: 0.798 | auc_eu: 0.873 | auc_cos: 0.905
# 	val: acc_eu: 0.819 | acc_cos: 0.902 | auc_eu: 0.842 | auc_cos: 0.885
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 55:
# 	train: loss 0.442 | loss id   0.42 | top_1_acc   0.41 | top_5_acc   0.75 | acc_eu: 0.835 | acc_cos: 0.844 | auc_eu: 0.876 | auc_cos: 0.918
# 	val: acc_eu: 0.890 | acc_cos: 0.835 | auc_eu: 0.834 | auc_cos: 0.885
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 56:
# 	train: loss 0.432 | loss id   0.41 | top_1_acc   0.39 | top_5_acc   0.73 | acc_eu: 0.843 | acc_cos: 0.826 | auc_eu: 0.880 | auc_cos: 0.909
# 	val: acc_eu: 0.844 | acc_cos: 0.860 | auc_eu: 0.849 | auc_cos: 0.888
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 57:
# 	train: loss 0.445 | loss id   0.42 | top_1_acc   0.38 | top_5_acc   0.75 | acc_eu: 0.822 | acc_cos: 0.842 | auc_eu: 0.891 | auc_cos: 0.928
# 	val: acc_eu: 0.890 | acc_cos: 0.893 | auc_eu: 0.851 | auc_cos: 0.908
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 58:
# 	train: loss 0.398 | loss id   0.37 | top_1_acc   0.44 | top_5_acc   0.77 | acc_eu: 0.860 | acc_cos: 0.845 | auc_eu: 0.894 | auc_cos: 0.925
# 	val: acc_eu: 0.825 | acc_cos: 0.874 | auc_eu: 0.842 | auc_cos: 0.899
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 59:
# 	train: loss 0.410 | loss id   0.39 | top_1_acc   0.41 | top_5_acc   0.76 | acc_eu: 0.850 | acc_cos: 0.841 | auc_eu: 0.910 | auc_cos: 0.940
# 	val: acc_eu: 0.915 | acc_cos: 0.855 | auc_eu: 0.863 | auc_cos: 0.907
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# Epoch 60:
# 	train: loss 0.407 | loss id   0.38 | top_1_acc   0.46 | top_5_acc   0.81 | acc_eu: 0.831 | acc_cos: 0.864 | auc_eu: 0.917 | auc_cos: 0.942
# 	val: acc_eu: 0.811 | acc_cos: 0.878 | auc_eu: 0.856 | auc_cos: 0.909
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 60 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_euclidean_accuracy.pth'
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 60 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_cosine_accuracy.pth'
# 	Saved best model weights for 'val_auc_euclidean' at epoch 60 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_auc_euclidean.pth'
# 	Saved best model weights for 'val_auc_cosine' at epoch 60 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_auc_cosine.pth'
# Epoch 61:
# 	train: loss 0.411 | loss id   0.39 | top_1_acc   0.48 | top_5_acc   0.81 | acc_eu: 0.828 | acc_cos: 0.845 | auc_eu: 0.896 | auc_cos: 0.924
# 	val: acc_eu: 0.892 | acc_cos: 0.885 | auc_eu: 0.845 | auc_cos: 0.893
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 61 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_euclidean_accuracy.pth'
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 61 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_cosine_accuracy.pth'
# 	Epoch 61: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 61: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 62:
# 	train: loss 0.394 | loss id   0.37 | top_1_acc   0.50 | top_5_acc   0.82 | acc_eu: 0.860 | acc_cos: 0.856 | auc_eu: 0.889 | auc_cos: 0.921
# 	val: acc_eu: 0.871 | acc_cos: 0.846 | auc_eu: 0.838 | auc_cos: 0.875
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 62: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 62: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 62: EarlyStopping counter for 'val_auc_euclidean': 2/40
# 	Epoch 62: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 63:
# 	train: loss 0.406 | loss id   0.38 | top_1_acc   0.50 | top_5_acc   0.83 | acc_eu: 0.801 | acc_cos: 0.812 | auc_eu: 0.873 | auc_cos: 0.896
# 	val: acc_eu: 0.850 | acc_cos: 0.858 | auc_eu: 0.875 | auc_cos: 0.905
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 63: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Epoch 63: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Saved best model weights for 'val_auc_euclidean' at epoch 63 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_auc_euclidean.pth'
# 	Epoch 63: EarlyStopping counter for 'val_auc_cosine': 3/40
# Epoch 64:
# 	train: loss 0.382 | loss id   0.36 | top_1_acc   0.55 | top_5_acc   0.85 | acc_eu: 0.834 | acc_cos: 0.830 | auc_eu: 0.907 | auc_cos: 0.921
# 	val: acc_eu: 0.924 | acc_cos: 0.940 | auc_eu: 0.880 | auc_cos: 0.904
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 64 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_euclidean_accuracy.pth'
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 64 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_cosine_accuracy.pth'
# 	Saved best model weights for 'val_auc_euclidean' at epoch 64 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_auc_euclidean.pth'
# 	Epoch 64: EarlyStopping counter for 'val_auc_cosine': 4/40
# Epoch 65:
# 	train: loss 0.417 | loss id   0.39 | top_1_acc   0.53 | top_5_acc   0.86 | acc_eu: 0.847 | acc_cos: 0.837 | auc_eu: 0.901 | auc_cos: 0.928
# 	val: acc_eu: 0.929 | acc_cos: 0.941 | auc_eu: 0.860 | auc_cos: 0.904
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 65 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_euclidean_accuracy.pth'
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 65 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_cosine_accuracy.pth'
# 	Epoch 65: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 65: EarlyStopping counter for 'val_auc_cosine': 5/40
# Epoch 66:
# 	train: loss 0.358 | loss id   0.33 | top_1_acc   0.56 | top_5_acc   0.88 | acc_eu: 0.857 | acc_cos: 0.846 | auc_eu: 0.914 | auc_cos: 0.930
# 	val: acc_eu: 0.908 | acc_cos: 0.903 | auc_eu: 0.853 | auc_cos: 0.894
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 66: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 66: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 66: EarlyStopping counter for 'val_auc_euclidean': 2/40
# 	Epoch 66: EarlyStopping counter for 'val_auc_cosine': 6/40
# Epoch 67:
# 	train: loss 0.372 | loss id   0.35 | top_1_acc   0.62 | top_5_acc   0.89 | acc_eu: 0.840 | acc_cos: 0.855 | auc_eu: 0.910 | auc_cos: 0.946
# 	val: acc_eu: 0.814 | acc_cos: 0.880 | auc_eu: 0.847 | auc_cos: 0.911
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 67: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Epoch 67: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 67: EarlyStopping counter for 'val_auc_euclidean': 3/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 67 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_auc_cosine.pth'
# Epoch 68:
# 	train: loss 0.414 | loss id   0.39 | top_1_acc   0.55 | top_5_acc   0.88 | acc_eu: 0.861 | acc_cos: 0.870 | auc_eu: 0.897 | auc_cos: 0.942
# 	val: acc_eu: 0.884 | acc_cos: 0.869 | auc_eu: 0.837 | auc_cos: 0.917
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 68: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Epoch 68: EarlyStopping counter for 'val_cosine_accuracy': 3/40
# 	Epoch 68: EarlyStopping counter for 'val_auc_euclidean': 4/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 68 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_auc_cosine.pth'
# Epoch 69:
# 	train: loss 0.433 | loss id   0.41 | top_1_acc   0.58 | top_5_acc   0.87 | acc_eu: 0.875 | acc_cos: 0.864 | auc_eu: 0.910 | auc_cos: 0.941
# 	val: acc_eu: 0.825 | acc_cos: 0.848 | auc_eu: 0.862 | auc_cos: 0.914
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 69: EarlyStopping counter for 'val_euclidean_accuracy': 4/40
# 	Epoch 69: EarlyStopping counter for 'val_cosine_accuracy': 4/40
# 	Epoch 69: EarlyStopping counter for 'val_auc_euclidean': 5/40
# 	Epoch 69: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 70:
# 	train: loss 0.454 | loss id   0.43 | top_1_acc   0.60 | top_5_acc   0.89 | acc_eu: 0.850 | acc_cos: 0.861 | auc_eu: 0.915 | auc_cos: 0.947
# 	val: acc_eu: 0.900 | acc_cos: 0.930 | auc_eu: 0.863 | auc_cos: 0.924
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 70: EarlyStopping counter for 'val_euclidean_accuracy': 5/40
# 	Epoch 70: EarlyStopping counter for 'val_cosine_accuracy': 5/40
# 	Epoch 70: EarlyStopping counter for 'val_auc_euclidean': 6/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 70 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_auc_cosine.pth'
# Epoch 71:
# 	train: loss 0.500 | loss id   0.48 | top_1_acc   0.59 | top_5_acc   0.88 | acc_eu: 0.831 | acc_cos: 0.828 | auc_eu: 0.892 | auc_cos: 0.913
# 	val: acc_eu: 0.858 | acc_cos: 0.827 | auc_eu: 0.844 | auc_cos: 0.884
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 71: EarlyStopping counter for 'val_euclidean_accuracy': 6/40
# 	Epoch 71: EarlyStopping counter for 'val_cosine_accuracy': 6/40
# 	Epoch 71: EarlyStopping counter for 'val_auc_euclidean': 7/40
# 	Epoch 71: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 72:
# 	train: loss 0.482 | loss id   0.46 | top_1_acc   0.59 | top_5_acc   0.88 | acc_eu: 0.846 | acc_cos: 0.845 | auc_eu: 0.873 | auc_cos: 0.915
# 	val: acc_eu: 0.925 | acc_cos: 0.913 | auc_eu: 0.840 | auc_cos: 0.890
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 72: EarlyStopping counter for 'val_euclidean_accuracy': 7/40
# 	Epoch 72: EarlyStopping counter for 'val_cosine_accuracy': 7/40
# 	Epoch 72: EarlyStopping counter for 'val_auc_euclidean': 8/40
# 	Epoch 72: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 73:
# 	train: loss 0.557 | loss id   0.53 | top_1_acc   0.60 | top_5_acc   0.89 | acc_eu: 0.847 | acc_cos: 0.842 | auc_eu: 0.873 | auc_cos: 0.919
# 	val: acc_eu: 0.828 | acc_cos: 0.799 | auc_eu: 0.838 | auc_cos: 0.896
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 73: EarlyStopping counter for 'val_euclidean_accuracy': 8/40
# 	Epoch 73: EarlyStopping counter for 'val_cosine_accuracy': 8/40
# 	Epoch 73: EarlyStopping counter for 'val_auc_euclidean': 9/40
# 	Epoch 73: EarlyStopping counter for 'val_auc_cosine': 3/40
# Epoch 74:
# 	train: loss 0.500 | loss id   0.48 | top_1_acc   0.61 | top_5_acc   0.91 | acc_eu: 0.856 | acc_cos: 0.812 | auc_eu: 0.836 | auc_cos: 0.896
# 	val: acc_eu: 0.867 | acc_cos: 0.881 | auc_eu: 0.812 | auc_cos: 0.883
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 74: EarlyStopping counter for 'val_euclidean_accuracy': 9/40
# 	Epoch 74: EarlyStopping counter for 'val_cosine_accuracy': 9/40
# 	Epoch 74: EarlyStopping counter for 'val_auc_euclidean': 10/40
# 	Epoch 74: EarlyStopping counter for 'val_auc_cosine': 4/40
# Epoch 75:
# 	train: loss 0.620 | loss id   0.60 | top_1_acc   0.60 | top_5_acc   0.90 | acc_eu: 0.859 | acc_cos: 0.846 | auc_eu: 0.910 | auc_cos: 0.939
# 	val: acc_eu: 0.849 | acc_cos: 0.863 | auc_eu: 0.870 | auc_cos: 0.907
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 75: EarlyStopping counter for 'val_euclidean_accuracy': 10/40
# 	Epoch 75: EarlyStopping counter for 'val_cosine_accuracy': 10/40
# 	Epoch 75: EarlyStopping counter for 'val_auc_euclidean': 11/40
# 	Epoch 75: EarlyStopping counter for 'val_auc_cosine': 5/40
# Epoch 76:
# 	train: loss 0.582 | loss id   0.56 | top_1_acc   0.64 | top_5_acc   0.91 | acc_eu: 0.858 | acc_cos: 0.852 | auc_eu: 0.896 | auc_cos: 0.914
# 	val: acc_eu: 0.943 | acc_cos: 0.902 | auc_eu: 0.855 | auc_cos: 0.896
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 76 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_euclidean_accuracy.pth'
# 	Epoch 76: EarlyStopping counter for 'val_cosine_accuracy': 11/40
# 	Epoch 76: EarlyStopping counter for 'val_auc_euclidean': 12/40
# 	Epoch 76: EarlyStopping counter for 'val_auc_cosine': 6/40
# Epoch 77:
# 	train: loss 0.556 | loss id   0.53 | top_1_acc   0.68 | top_5_acc   0.93 | acc_eu: 0.884 | acc_cos: 0.870 | auc_eu: 0.906 | auc_cos: 0.944
# 	val: acc_eu: 0.850 | acc_cos: 0.906 | auc_eu: 0.837 | auc_cos: 0.906
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 77: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 77: EarlyStopping counter for 'val_cosine_accuracy': 12/40
# 	Epoch 77: EarlyStopping counter for 'val_auc_euclidean': 13/40
# 	Epoch 77: EarlyStopping counter for 'val_auc_cosine': 7/40
# Epoch 78:
# 	train: loss 0.554 | loss id   0.53 | top_1_acc   0.63 | top_5_acc   0.89 | acc_eu: 0.875 | acc_cos: 0.837 | auc_eu: 0.887 | auc_cos: 0.935
# 	val: acc_eu: 0.939 | acc_cos: 0.920 | auc_eu: 0.836 | auc_cos: 0.911
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 78: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Epoch 78: EarlyStopping counter for 'val_cosine_accuracy': 13/40
# 	Epoch 78: EarlyStopping counter for 'val_auc_euclidean': 14/40
# 	Epoch 78: EarlyStopping counter for 'val_auc_cosine': 8/40
# Epoch 79:
# 	train: loss 0.587 | loss id   0.56 | top_1_acc   0.71 | top_5_acc   0.93 | acc_eu: 0.864 | acc_cos: 0.854 | auc_eu: 0.920 | auc_cos: 0.948
# 	val: acc_eu: 0.805 | acc_cos: 0.804 | auc_eu: 0.851 | auc_cos: 0.903
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 79: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Epoch 79: EarlyStopping counter for 'val_cosine_accuracy': 14/40
# 	Epoch 79: EarlyStopping counter for 'val_auc_euclidean': 15/40
# 	Epoch 79: EarlyStopping counter for 'val_auc_cosine': 9/40
# Epoch 80:
# 	train: loss 0.726 | loss id   0.70 | top_1_acc   0.70 | top_5_acc   0.95 | acc_eu: 0.894 | acc_cos: 0.851 | auc_eu: 0.925 | auc_cos: 0.943
# 	val: acc_eu: 0.860 | acc_cos: 0.885 | auc_eu: 0.844 | auc_cos: 0.893
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 80: EarlyStopping counter for 'val_euclidean_accuracy': 4/40
# 	Epoch 80: EarlyStopping counter for 'val_cosine_accuracy': 15/40
# 	Epoch 80: EarlyStopping counter for 'val_auc_euclidean': 16/40
# 	Epoch 80: EarlyStopping counter for 'val_auc_cosine': 10/40
# Epoch 81:
# 	train: loss 0.806 | loss id   0.78 | top_1_acc   0.68 | top_5_acc   0.93 | acc_eu: 0.873 | acc_cos: 0.845 | auc_eu: 0.906 | auc_cos: 0.926
# 	val: acc_eu: 0.878 | acc_cos: 0.900 | auc_eu: 0.834 | auc_cos: 0.881
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 81: EarlyStopping counter for 'val_euclidean_accuracy': 5/40
# 	Epoch 81: EarlyStopping counter for 'val_cosine_accuracy': 16/40
# 	Epoch 81: EarlyStopping counter for 'val_auc_euclidean': 17/40
# 	Epoch 81: EarlyStopping counter for 'val_auc_cosine': 11/40
# Epoch 82:
# 	train: loss 0.917 | loss id   0.89 | top_1_acc   0.67 | top_5_acc   0.92 | acc_eu: 0.841 | acc_cos: 0.829 | auc_eu: 0.870 | auc_cos: 0.897
# 	val: acc_eu: 0.881 | acc_cos: 0.819 | auc_eu: 0.821 | auc_cos: 0.868
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 82: EarlyStopping counter for 'val_euclidean_accuracy': 6/40
# 	Epoch 82: EarlyStopping counter for 'val_cosine_accuracy': 17/40
# 	Epoch 82: EarlyStopping counter for 'val_auc_euclidean': 18/40
# 	Epoch 82: EarlyStopping counter for 'val_auc_cosine': 12/40
# Epoch 83:
# 	train: loss 1.015 | loss id   0.99 | top_1_acc   0.66 | top_5_acc   0.92 | acc_eu: 0.840 | acc_cos: 0.847 | auc_eu: 0.888 | auc_cos: 0.890
# 	val: acc_eu: 0.823 | acc_cos: 0.805 | auc_eu: 0.854 | auc_cos: 0.858
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 83: EarlyStopping counter for 'val_euclidean_accuracy': 7/40
# 	Epoch 83: EarlyStopping counter for 'val_cosine_accuracy': 18/40
# 	Epoch 83: EarlyStopping counter for 'val_auc_euclidean': 19/40
# 	Epoch 83: EarlyStopping counter for 'val_auc_cosine': 13/40
# Epoch 84:
# 	train: loss 1.164 | loss id   1.14 | top_1_acc   0.66 | top_5_acc   0.92 | acc_eu: 0.851 | acc_cos: 0.831 | auc_eu: 0.884 | auc_cos: 0.888
# 	val: acc_eu: 0.859 | acc_cos: 0.901 | auc_eu: 0.853 | auc_cos: 0.874
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 84: EarlyStopping counter for 'val_euclidean_accuracy': 8/40
# 	Epoch 84: EarlyStopping counter for 'val_cosine_accuracy': 19/40
# 	Epoch 84: EarlyStopping counter for 'val_auc_euclidean': 20/40
# 	Epoch 84: EarlyStopping counter for 'val_auc_cosine': 14/40
# Epoch 85:
# 	train: loss 1.201 | loss id   1.18 | top_1_acc   0.69 | top_5_acc   0.93 | acc_eu: 0.853 | acc_cos: 0.833 | auc_eu: 0.891 | auc_cos: 0.882
# 	val: acc_eu: 0.935 | acc_cos: 0.859 | auc_eu: 0.828 | auc_cos: 0.834
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 85: EarlyStopping counter for 'val_euclidean_accuracy': 9/40
# 	Epoch 85: EarlyStopping counter for 'val_cosine_accuracy': 20/40
# 	Epoch 85: EarlyStopping counter for 'val_auc_euclidean': 21/40
# 	Epoch 85: EarlyStopping counter for 'val_auc_cosine': 15/40
# Epoch 86:
# 	train: loss 1.167 | loss id   1.14 | top_1_acc   0.70 | top_5_acc   0.91 | acc_eu: 0.846 | acc_cos: 0.828 | auc_eu: 0.911 | auc_cos: 0.901
# 	val: acc_eu: 0.946 | acc_cos: 0.910 | auc_eu: 0.842 | auc_cos: 0.849
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 86 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/best_val_euclidean_accuracy.pth'
# 	Epoch 86: EarlyStopping counter for 'val_cosine_accuracy': 21/40
# 	Epoch 86: EarlyStopping counter for 'val_auc_euclidean': 22/40
# 	Epoch 86: EarlyStopping counter for 'val_auc_cosine': 16/40
# Epoch 87:
# 	train: loss 1.318 | loss id   1.30 | top_1_acc   0.73 | top_5_acc   0.94 | acc_eu: 0.878 | acc_cos: 0.834 | auc_eu: 0.921 | auc_cos: 0.897
# 	val: acc_eu: 0.858 | acc_cos: 0.935 | auc_eu: 0.861 | auc_cos: 0.835
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 87: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 87: EarlyStopping counter for 'val_cosine_accuracy': 22/40
# 	Epoch 87: EarlyStopping counter for 'val_auc_euclidean': 23/40
# 	Epoch 87: EarlyStopping counter for 'val_auc_cosine': 17/40
# Epoch 88:
# 	train: loss 1.386 | loss id   1.36 | top_1_acc   0.75 | top_5_acc   0.95 | acc_eu: 0.863 | acc_cos: 0.852 | auc_eu: 0.928 | auc_cos: 0.926
# 	val: acc_eu: 0.895 | acc_cos: 0.767 | auc_eu: 0.849 | auc_cos: 0.837
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 88: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Epoch 88: EarlyStopping counter for 'val_cosine_accuracy': 23/40
# 	Epoch 88: EarlyStopping counter for 'val_auc_euclidean': 24/40
# 	Epoch 88: EarlyStopping counter for 'val_auc_cosine': 18/40
# Epoch 89:
# 	train: loss 1.551 | loss id   1.53 | top_1_acc   0.74 | top_5_acc   0.95 | acc_eu: 0.866 | acc_cos: 0.870 | auc_eu: 0.929 | auc_cos: 0.923
# 	val: acc_eu: 0.850 | acc_cos: 0.843 | auc_eu: 0.837 | auc_cos: 0.837
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 89: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Epoch 89: EarlyStopping counter for 'val_cosine_accuracy': 24/40
# 	Epoch 89: EarlyStopping counter for 'val_auc_euclidean': 25/40
# 	Epoch 89: EarlyStopping counter for 'val_auc_cosine': 19/40
# Epoch 90:
# 	train: loss 1.556 | loss id   1.53 | top_1_acc   0.80 | top_5_acc   0.95 | acc_eu: 0.888 | acc_cos: 0.880 | auc_eu: 0.932 | auc_cos: 0.937
# 	val: acc_eu: 0.790 | acc_cos: 0.836 | auc_eu: 0.844 | auc_cos: 0.849
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 90: EarlyStopping counter for 'val_euclidean_accuracy': 4/40
# 	Epoch 90: EarlyStopping counter for 'val_cosine_accuracy': 25/40
# 	Epoch 90: EarlyStopping counter for 'val_auc_euclidean': 26/40
# 	Epoch 90: EarlyStopping counter for 'val_auc_cosine': 20/40
# Epoch 91:
# 	train: loss 1.893 | loss id   1.87 | top_1_acc   0.77 | top_5_acc   0.94 | acc_eu: 0.899 | acc_cos: 0.837 | auc_eu: 0.942 | auc_cos: 0.925
# 	val: acc_eu: 0.852 | acc_cos: 0.902 | auc_eu: 0.844 | auc_cos: 0.842
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 91: EarlyStopping counter for 'val_euclidean_accuracy': 5/40
# 	Epoch 91: EarlyStopping counter for 'val_cosine_accuracy': 26/40
# 	Epoch 91: EarlyStopping counter for 'val_auc_euclidean': 27/40
# 	Epoch 91: EarlyStopping counter for 'val_auc_cosine': 21/40
# Epoch 92:
# 	train: loss 2.029 | loss id   2.01 | top_1_acc   0.78 | top_5_acc   0.96 | acc_eu: 0.874 | acc_cos: 0.846 | auc_eu: 0.936 | auc_cos: 0.940
# 	val: acc_eu: 0.893 | acc_cos: 0.874 | auc_eu: 0.849 | auc_cos: 0.873
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 92: EarlyStopping counter for 'val_euclidean_accuracy': 6/40
# 	Epoch 92: EarlyStopping counter for 'val_cosine_accuracy': 27/40
# 	Epoch 92: EarlyStopping counter for 'val_auc_euclidean': 28/40
# 	Epoch 92: EarlyStopping counter for 'val_auc_cosine': 22/40
# Epoch 93:
# 	train: loss 2.114 | loss id   2.09 | top_1_acc   0.82 | top_5_acc   0.96 | acc_eu: 0.896 | acc_cos: 0.907 | auc_eu: 0.957 | auc_cos: 0.972
# 	val: acc_eu: 0.906 | acc_cos: 0.847 | auc_eu: 0.843 | auc_cos: 0.892
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 93: EarlyStopping counter for 'val_euclidean_accuracy': 7/40
# 	Epoch 93: EarlyStopping counter for 'val_cosine_accuracy': 28/40
# 	Epoch 93: EarlyStopping counter for 'val_auc_euclidean': 29/40
# 	Epoch 93: EarlyStopping counter for 'val_auc_cosine': 23/40
# Epoch 94:
# 	train: loss 2.184 | loss id   2.16 | top_1_acc   0.84 | top_5_acc   0.96 | acc_eu: 0.895 | acc_cos: 0.925 | auc_eu: 0.958 | auc_cos: 0.971
# 	val: acc_eu: 0.837 | acc_cos: 0.860 | auc_eu: 0.844 | auc_cos: 0.896
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 94: EarlyStopping counter for 'val_euclidean_accuracy': 8/40
# 	Epoch 94: EarlyStopping counter for 'val_cosine_accuracy': 29/40
# 	Epoch 94: EarlyStopping counter for 'val_auc_euclidean': 30/40
# 	Epoch 94: EarlyStopping counter for 'val_auc_cosine': 24/40
# Epoch 95:
# 	train: loss 1.979 | loss id   1.96 | top_1_acc   0.89 | top_5_acc   0.97 | acc_eu: 0.887 | acc_cos: 0.907 | auc_eu: 0.946 | auc_cos: 0.955
# 	val: acc_eu: 0.866 | acc_cos: 0.879 | auc_eu: 0.830 | auc_cos: 0.886
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 95: EarlyStopping counter for 'val_euclidean_accuracy': 9/40
# 	Epoch 95: EarlyStopping counter for 'val_cosine_accuracy': 30/40
# 	Epoch 95: EarlyStopping counter for 'val_auc_euclidean': 31/40
# 	Epoch 95: EarlyStopping counter for 'val_auc_cosine': 25/40
# Epoch 96:
# 	train: loss 1.931 | loss id   1.91 | top_1_acc   0.90 | top_5_acc   0.97 | acc_eu: 0.917 | acc_cos: 0.930 | auc_eu: 0.964 | auc_cos: 0.980
# 	val: acc_eu: 0.836 | acc_cos: 0.815 | auc_eu: 0.838 | auc_cos: 0.892
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 96: EarlyStopping counter for 'val_euclidean_accuracy': 10/40
# 	Epoch 96: EarlyStopping counter for 'val_cosine_accuracy': 31/40
# 	Epoch 96: EarlyStopping counter for 'val_auc_euclidean': 32/40
# 	Epoch 96: EarlyStopping counter for 'val_auc_cosine': 26/40
# Epoch 97:
# 	train: loss 1.792 | loss id   1.77 | top_1_acc   0.92 | top_5_acc   0.98 | acc_eu: 0.939 | acc_cos: 0.960 | auc_eu: 0.981 | auc_cos: 0.993
# 	val: acc_eu: 0.912 | acc_cos: 0.891 | auc_eu: 0.852 | auc_cos: 0.919
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 97: EarlyStopping counter for 'val_euclidean_accuracy': 11/40
# 	Epoch 97: EarlyStopping counter for 'val_cosine_accuracy': 32/40
# 	Epoch 97: EarlyStopping counter for 'val_auc_euclidean': 33/40
# 	Epoch 97: EarlyStopping counter for 'val_auc_cosine': 27/40
# Epoch 98:
# 	train: loss 1.675 | loss id   1.65 | top_1_acc   0.94 | top_5_acc   0.99 | acc_eu: 0.948 | acc_cos: 0.956 | auc_eu: 0.987 | auc_cos: 0.994
# 	val: acc_eu: 0.939 | acc_cos: 0.849 | auc_eu: 0.861 | auc_cos: 0.892
# ...
# 	val: acc_eu: 0.788 | acc_cos: 0.878 | auc_eu: 0.821 | auc_cos: 0.905
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 191: EarlyStopping counter for 'val_euclidean_accuracy': 84/40
# 	Epoch 191: EarlyStopping counter for 'val_cosine_accuracy': 126/40
# 	Epoch 191: EarlyStopping counter for 'val_auc_euclidean': 127/40
# 	Epoch 191: EarlyStopping counter for 'val_auc_cosine': 17/40
# Epoch 192:
# 	train: loss 0.053 | loss id   0.03 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.782 | acc_cos: 0.936 | auc_eu: 0.836 | auc_cos: 0.898
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 192: EarlyStopping counter for 'val_euclidean_accuracy': 85/40
# 	Epoch 192: EarlyStopping counter for 'val_cosine_accuracy': 127/40
# 	Epoch 192: EarlyStopping counter for 'val_auc_euclidean': 128/40
# 	Epoch 192: EarlyStopping counter for 'val_auc_cosine': 18/40
# Epoch 193:
# 	train: loss 0.053 | loss id   0.03 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.996 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.785 | acc_cos: 0.904 | auc_eu: 0.815 | auc_cos: 0.910
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 193: EarlyStopping counter for 'val_euclidean_accuracy': 86/40
# 	Epoch 193: EarlyStopping counter for 'val_cosine_accuracy': 128/40
# 	Epoch 193: EarlyStopping counter for 'val_auc_euclidean': 129/40
# 	Epoch 193: EarlyStopping counter for 'val_auc_cosine': 19/40
# Epoch 194:
# 	train: loss 0.042 | loss id   0.02 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.803 | acc_cos: 0.834 | auc_eu: 0.793 | auc_cos: 0.896
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 194: EarlyStopping counter for 'val_euclidean_accuracy': 87/40
# 	Epoch 194: EarlyStopping counter for 'val_cosine_accuracy': 129/40
# 	Epoch 194: EarlyStopping counter for 'val_auc_euclidean': 130/40
# 	Epoch 194: EarlyStopping counter for 'val_auc_cosine': 20/40
# Epoch 195:
# 	train: loss 0.052 | loss id   0.03 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.873 | acc_cos: 0.870 | auc_eu: 0.818 | auc_cos: 0.913
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 195: EarlyStopping counter for 'val_euclidean_accuracy': 88/40
# 	Epoch 195: EarlyStopping counter for 'val_cosine_accuracy': 130/40
# 	Epoch 195: EarlyStopping counter for 'val_auc_euclidean': 131/40
# 	Epoch 195: EarlyStopping counter for 'val_auc_cosine': 21/40
# Epoch 196:
# 	train: loss 0.057 | loss id   0.03 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.995 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.713 | acc_cos: 0.909 | auc_eu: 0.812 | auc_cos: 0.909
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 196: EarlyStopping counter for 'val_euclidean_accuracy': 89/40
# 	Epoch 196: EarlyStopping counter for 'val_cosine_accuracy': 131/40
# 	Epoch 196: EarlyStopping counter for 'val_auc_euclidean': 132/40
# 	Epoch 196: EarlyStopping counter for 'val_auc_cosine': 22/40
# Epoch 197:
# 	train: loss 0.053 | loss id   0.03 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.836 | acc_cos: 0.937 | auc_eu: 0.813 | auc_cos: 0.903
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 197: EarlyStopping counter for 'val_euclidean_accuracy': 90/40
# 	Epoch 197: EarlyStopping counter for 'val_cosine_accuracy': 132/40
# 	Epoch 197: EarlyStopping counter for 'val_auc_euclidean': 133/40
# 	Epoch 197: EarlyStopping counter for 'val_auc_cosine': 23/40
# Epoch 198:
# 	train: loss 0.039 | loss id   0.02 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.855 | acc_cos: 0.870 | auc_eu: 0.820 | auc_cos: 0.917
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 198: EarlyStopping counter for 'val_euclidean_accuracy': 91/40
# 	Epoch 198: EarlyStopping counter for 'val_cosine_accuracy': 133/40
# 	Epoch 198: EarlyStopping counter for 'val_auc_euclidean': 134/40
# 	Epoch 198: EarlyStopping counter for 'val_auc_cosine': 24/40
# Epoch 199:
# 	train: loss 0.038 | loss id   0.02 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.791 | acc_cos: 0.921 | auc_eu: 0.802 | auc_cos: 0.903
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 199: EarlyStopping counter for 'val_euclidean_accuracy': 92/40
# 	Epoch 199: EarlyStopping counter for 'val_cosine_accuracy': 134/40
# 	Epoch 199: EarlyStopping counter for 'val_auc_euclidean': 135/40
# 	Epoch 199: EarlyStopping counter for 'val_auc_cosine': 25/40
# Epoch 200:
# 	train: loss 0.064 | loss id   0.04 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.997 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.826 | acc_cos: 0.891 | auc_eu: 0.802 | auc_cos: 0.905
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 200: EarlyStopping counter for 'val_euclidean_accuracy': 93/40
# 	Epoch 200: EarlyStopping counter for 'val_cosine_accuracy': 135/40
# 	Epoch 200: EarlyStopping counter for 'val_auc_euclidean': 136/40
# 	Epoch 200: EarlyStopping counter for 'val_auc_cosine': 26/40
# Epoch 201:
# 	train: loss 0.118 | loss id   0.09 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.973 | acc_cos: 0.992 | auc_eu: 0.996 | auc_cos: 1.000
# 	val: acc_eu: 0.860 | acc_cos: 0.773 | auc_eu: 0.819 | auc_cos: 0.863
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 201: EarlyStopping counter for 'val_euclidean_accuracy': 94/40
# 	Epoch 201: EarlyStopping counter for 'val_cosine_accuracy': 136/40
# 	Epoch 201: EarlyStopping counter for 'val_auc_euclidean': 137/40
# 	Epoch 201: EarlyStopping counter for 'val_auc_cosine': 27/40
# Epoch 202:
# 	train: loss 0.139 | loss id   0.12 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.857 | acc_cos: 0.920 | auc_eu: 0.814 | auc_cos: 0.908
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 202: EarlyStopping counter for 'val_euclidean_accuracy': 95/40
# 	Epoch 202: EarlyStopping counter for 'val_cosine_accuracy': 137/40
# 	Epoch 202: EarlyStopping counter for 'val_auc_euclidean': 138/40
# 	Epoch 202: EarlyStopping counter for 'val_auc_cosine': 28/40
# Epoch 203:
# 	train: loss 0.090 | loss id   0.07 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.996 | acc_cos: 1.000 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.918 | acc_cos: 0.892 | auc_eu: 0.819 | auc_cos: 0.904
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 203: EarlyStopping counter for 'val_euclidean_accuracy': 96/40
# 	Epoch 203: EarlyStopping counter for 'val_cosine_accuracy': 138/40
# 	Epoch 203: EarlyStopping counter for 'val_auc_euclidean': 139/40
# 	Epoch 203: EarlyStopping counter for 'val_auc_cosine': 29/40
# Epoch 204:
# 	train: loss 0.063 | loss id   0.04 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.733 | acc_cos: 0.930 | auc_eu: 0.810 | auc_cos: 0.913
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 204: EarlyStopping counter for 'val_euclidean_accuracy': 97/40
# 	Epoch 204: EarlyStopping counter for 'val_cosine_accuracy': 139/40
# 	Epoch 204: EarlyStopping counter for 'val_auc_euclidean': 140/40
# 	Epoch 204: EarlyStopping counter for 'val_auc_cosine': 30/40
# Epoch 205:
# 	train: loss 0.047 | loss id   0.02 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.862 | acc_cos: 0.934 | auc_eu: 0.825 | auc_cos: 0.897
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 205: EarlyStopping counter for 'val_euclidean_accuracy': 98/40
# 	Epoch 205: EarlyStopping counter for 'val_cosine_accuracy': 140/40
# 	Epoch 205: EarlyStopping counter for 'val_auc_euclidean': 141/40
# 	Epoch 205: EarlyStopping counter for 'val_auc_cosine': 31/40
# Epoch 206:
# 	train: loss 0.052 | loss id   0.03 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.837 | acc_cos: 0.885 | auc_eu: 0.823 | auc_cos: 0.914
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 206: EarlyStopping counter for 'val_euclidean_accuracy': 99/40
# 	Epoch 206: EarlyStopping counter for 'val_cosine_accuracy': 141/40
# 	Epoch 206: EarlyStopping counter for 'val_auc_euclidean': 142/40
# 	Epoch 206: EarlyStopping counter for 'val_auc_cosine': 32/40
# Epoch 207:
# 	train: loss 0.039 | loss id   0.02 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.869 | acc_cos: 0.829 | auc_eu: 0.822 | auc_cos: 0.911
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 207: EarlyStopping counter for 'val_euclidean_accuracy': 100/40
# 	Epoch 207: EarlyStopping counter for 'val_cosine_accuracy': 142/40
# 	Epoch 207: EarlyStopping counter for 'val_auc_euclidean': 143/40
# 	Epoch 207: EarlyStopping counter for 'val_auc_cosine': 33/40
# Epoch 208:
# 	train: loss 0.037 | loss id   0.01 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.854 | acc_cos: 0.933 | auc_eu: 0.816 | auc_cos: 0.909
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 208: EarlyStopping counter for 'val_euclidean_accuracy': 101/40
# 	Epoch 208: EarlyStopping counter for 'val_cosine_accuracy': 143/40
# 	Epoch 208: EarlyStopping counter for 'val_auc_euclidean': 144/40
# 	Epoch 208: EarlyStopping counter for 'val_auc_cosine': 34/40
# Epoch 209:
# 	train: loss 0.035 | loss id   0.01 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.920 | acc_cos: 0.888 | auc_eu: 0.825 | auc_cos: 0.909
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 209: EarlyStopping counter for 'val_euclidean_accuracy': 102/40
# 	Epoch 209: EarlyStopping counter for 'val_cosine_accuracy': 144/40
# 	Epoch 209: EarlyStopping counter for 'val_auc_euclidean': 145/40
# 	Epoch 209: EarlyStopping counter for 'val_auc_cosine': 35/40
# Epoch 210:
# 	train: loss 0.035 | loss id   0.01 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.742 | acc_cos: 0.841 | auc_eu: 0.818 | auc_cos: 0.913
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 210: EarlyStopping counter for 'val_euclidean_accuracy': 103/40
# 	Epoch 210: EarlyStopping counter for 'val_cosine_accuracy': 145/40
# 	Epoch 210: EarlyStopping counter for 'val_auc_euclidean': 146/40
# 	Epoch 210: EarlyStopping counter for 'val_auc_cosine': 36/40
# Epoch 211:
# 	train: loss 0.046 | loss id   0.02 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.887 | acc_cos: 0.872 | auc_eu: 0.815 | auc_cos: 0.901
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 211: EarlyStopping counter for 'val_euclidean_accuracy': 104/40
# 	Epoch 211: EarlyStopping counter for 'val_cosine_accuracy': 146/40
# 	Epoch 211: EarlyStopping counter for 'val_auc_euclidean': 147/40
# 	Epoch 211: EarlyStopping counter for 'val_auc_cosine': 37/40
# Epoch 212:
# 	train: loss 0.058 | loss id   0.04 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.796 | acc_cos: 0.844 | auc_eu: 0.822 | auc_cos: 0.899
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 212: EarlyStopping counter for 'val_euclidean_accuracy': 105/40
# 	Epoch 212: EarlyStopping counter for 'val_cosine_accuracy': 147/40
# 	Epoch 212: EarlyStopping counter for 'val_auc_euclidean': 148/40
# 	Epoch 212: EarlyStopping counter for 'val_auc_cosine': 38/40
# Epoch 213:
# 	train: loss 0.067 | loss id   0.04 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.813 | acc_cos: 0.829 | auc_eu: 0.823 | auc_cos: 0.921
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 213: EarlyStopping counter for 'val_euclidean_accuracy': 106/40
# 	Epoch 213: EarlyStopping counter for 'val_cosine_accuracy': 148/40
# 	Epoch 213: EarlyStopping counter for 'val_auc_euclidean': 149/40
# 	Epoch 213: EarlyStopping counter for 'val_auc_cosine': 39/40
# Epoch 214:
# 	train: loss 0.043 | loss id   0.02 | top_1_acc   1.00 | top_5_acc   1.00 | acc_eu: 0.998 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.841 | acc_cos: 0.890 | auc_eu: 0.819 | auc_cos: 0.905
# 	Saving model to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet50/models/checkpoint.pth
# 	Epoch 214: EarlyStopping counter for 'val_euclidean_accuracy': 107/40
# 	Epoch 214: EarlyStopping counter for 'val_cosine_accuracy': 149/40
# 	Epoch 214: EarlyStopping counter for 'val_auc_euclidean': 150/40
# 	Epoch 214: EarlyStopping counter for 'val_auc_cosine': 40/40
# 	Early stopping triggered at epoch 214 as all metrics exceeded patience.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 fit(CONFIGURATION, 0, model, device, train_dataloader, val_dataloader, criterion, optimizer, scheduler, early_stopping, modle_checkpoint)
#
# File /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/going_modular/train_eval/train.py:49, in fit(conf, start_epoch, model, device, train_dataloader, val_dataloader, criterion, optimizer, scheduler, early_stopping, model_checkpoint)
#      46 model.train()
#      48 for input, target in train_dataloader:
# ---> 49     input = input.to(device)
#      50     target = target.to(device)
#      51     logits, x_norm = model(input)
#
# KeyboardInterrupt:

# %%
# %load_ext tensorboard
# %tensorboard --logdir checkpoint/magface/albedo/iresnet50/logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 126216), started 0:00:04 ago. (Use '!kill 126216' to kill it.)
#       <iframe id="tensorboard-frame-f5c1fbb6646140a4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f5c1fbb6646140a4");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
print('TB: 1.15211267606p/epoch')
# Out:
# TB: 1.15211267606p/epoch
