# %%
import os

import torch
from torchinfo import summary
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts

from going_modular.dataloader.magface import create_magface_dataloader
from going_modular.model.MagFaceRecognition import MagFaceRecognition
from going_modular.train_eval.train import fit
from going_modular.loss.MagLoss import MagLoss
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint

device = "cuda" if torch.cuda.is_available() else "cpu"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
CONFIGURATION = {
    # Thư mục
    'type': 'albedo',
    'train_dir': './Dataset/Albedo/train',
    'test_dir': './Dataset/Albedo/test',
    
    # Cấu hình train
    'backbone': 'iresnet18',
    'epochs': 2000,
    'num_workers': 4,
    'batch_size': 16,
    'image_size': 224,
    'num_class': len(os.listdir('./Dataset/Albedo/train')),
    'embedding_size': 512,
    
    'learning_rate': 0.2,
    'weight_decay': 5e-4,
    'momentum': 0.9,
    'alpha': 0.9,
    
    # Hàm m(ai) giúp thay đổi ai từ 0.25 đến 1.6
    'scale': 64,
    'lambda_g': 20,
    'l_margin': 0.45, 
    'u_margin': 0.8,
    'l_a': 10, 
    'u_a': 110,
}

# %%
# Đặt seed toàn cục
seed = 42
torch.manual_seed(seed)

# %%
train_dataloader, val_dataloader = create_magface_dataloader(CONFIGURATION, None, None)

# %%
model = MagFaceRecognition(CONFIGURATION).to(device)
criterion = MagLoss(conf = CONFIGURATION)

optimizer = torch.optim.Adam(model.parameters(), lr=CONFIGURATION['learning_rate'])
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=40, T_mult=1, eta_min=1e-6)
checkpoint_path = os.path.abspath('checkpoint/magface/albedo/' + CONFIGURATION['backbone'] + '/models/checkpoint.pth')
modle_checkpoint = ModelCheckpoint(filepath=checkpoint_path, verbose=1)
earlystop_dir = os.path.abspath('checkpoint/magface/albedo/' + CONFIGURATION['backbone'] + '/models')
early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['val_euclidean_accuracy', 'val_cosine_accuracy', 'val_auc_euclidean', 'val_auc_cosine'],
    patience=40,
    mode='max',
    verbose=1,
    save_dir=earlystop_dir,
    start_from_epoch=40
)

# %%
fit(CONFIGURATION, 0, model, device, train_dataloader, val_dataloader, criterion, optimizer, scheduler, early_stopping, modle_checkpoint)
# Out:
# Epoch 1:
# 	train: loss 3.721 | loss id   3.70 | top_1_acc 0.0067 | top_5_acc 0.0209 | acc_eu: 0.730 | acc_cos: 0.572 | auc_eu: 0.620 | auc_cos: 0.681
# 	val: acc_eu: 0.665 | acc_cos: 0.671 | auc_eu: 0.646 | auc_cos: 0.702
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 2:
# 	train: loss 2.081 | loss id   2.06 | top_1_acc 0.0105 | top_5_acc 0.0351 | acc_eu: 0.707 | acc_cos: 0.578 | auc_eu: 0.642 | auc_cos: 0.656
# 	val: acc_eu: 0.569 | acc_cos: 0.611 | auc_eu: 0.705 | auc_cos: 0.708
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 3:
# 	train: loss 0.677 | loss id   0.65 | top_1_acc 0.0097 | top_5_acc 0.0538 | acc_eu: 0.579 | acc_cos: 0.550 | auc_eu: 0.662 | auc_cos: 0.671
# 	val: acc_eu: 0.578 | acc_cos: 0.520 | auc_eu: 0.719 | auc_cos: 0.722
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 4:
# 	train: loss 0.576 | loss id   0.55 | top_1_acc 0.0127 | top_5_acc 0.0471 | acc_eu: 0.510 | acc_cos: 0.518 | auc_eu: 0.677 | auc_cos: 0.677
# 	val: acc_eu: 0.635 | acc_cos: 0.680 | auc_eu: 0.732 | auc_cos: 0.716
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 5:
# 	train: loss 0.489 | loss id   0.47 | top_1_acc 0.0075 | top_5_acc 0.0456 | acc_eu: 0.548 | acc_cos: 0.561 | auc_eu: 0.675 | auc_cos: 0.687
# 	val: acc_eu: 0.587 | acc_cos: 0.517 | auc_eu: 0.735 | auc_cos: 0.737
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 6:
# 	train: loss 0.494 | loss id   0.47 | top_1_acc 0.0105 | top_5_acc 0.0553 | acc_eu: 0.618 | acc_cos: 0.539 | auc_eu: 0.676 | auc_cos: 0.685
# 	val: acc_eu: 0.613 | acc_cos: 0.493 | auc_eu: 0.743 | auc_cos: 0.737
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 7:
# 	train: loss 0.467 | loss id   0.44 | top_1_acc 0.0120 | top_5_acc 0.0478 | acc_eu: 0.566 | acc_cos: 0.462 | auc_eu: 0.691 | auc_cos: 0.690
# 	val: acc_eu: 0.557 | acc_cos: 0.596 | auc_eu: 0.730 | auc_cos: 0.721
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 8:
# 	train: loss 0.442 | loss id   0.42 | top_1_acc 0.0090 | top_5_acc 0.0523 | acc_eu: 0.615 | acc_cos: 0.510 | auc_eu: 0.685 | auc_cos: 0.689
# 	val: acc_eu: 0.701 | acc_cos: 0.571 | auc_eu: 0.751 | auc_cos: 0.750
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 9:
# 	train: loss 0.449 | loss id   0.43 | top_1_acc 0.0135 | top_5_acc 0.0568 | acc_eu: 0.588 | acc_cos: 0.509 | auc_eu: 0.692 | auc_cos: 0.697
# 	val: acc_eu: 0.650 | acc_cos: 0.600 | auc_eu: 0.730 | auc_cos: 0.727
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 10:
# 	train: loss 0.451 | loss id   0.43 | top_1_acc 0.0120 | top_5_acc 0.0568 | acc_eu: 0.612 | acc_cos: 0.567 | auc_eu: 0.700 | auc_cos: 0.707
# 	val: acc_eu: 0.643 | acc_cos: 0.523 | auc_eu: 0.751 | auc_cos: 0.739
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 11:
# 	train: loss 0.436 | loss id   0.41 | top_1_acc 0.0142 | top_5_acc 0.0852 | acc_eu: 0.653 | acc_cos: 0.578 | auc_eu: 0.699 | auc_cos: 0.711
# 	val: acc_eu: 0.626 | acc_cos: 0.666 | auc_eu: 0.715 | auc_cos: 0.733
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 12:
# 	train: loss 0.450 | loss id   0.43 | top_1_acc 0.0164 | top_5_acc 0.0867 | acc_eu: 0.564 | acc_cos: 0.643 | auc_eu: 0.691 | auc_cos: 0.713
# 	val: acc_eu: 0.757 | acc_cos: 0.676 | auc_eu: 0.735 | auc_cos: 0.760
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 13:
# 	train: loss 0.482 | loss id   0.46 | top_1_acc 0.0247 | top_5_acc 0.1024 | acc_eu: 0.637 | acc_cos: 0.647 | auc_eu: 0.725 | auc_cos: 0.734
# 	val: acc_eu: 0.667 | acc_cos: 0.644 | auc_eu: 0.754 | auc_cos: 0.773
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 14:
# 	train: loss 0.493 | loss id   0.47 | top_1_acc 0.0179 | top_5_acc 0.1016 | acc_eu: 0.537 | acc_cos: 0.639 | auc_eu: 0.699 | auc_cos: 0.720
# 	val: acc_eu: 0.882 | acc_cos: 0.667 | auc_eu: 0.729 | auc_cos: 0.760
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 15:
# 	train: loss 0.450 | loss id   0.43 | top_1_acc 0.0306 | top_5_acc 0.1084 | acc_eu: 0.582 | acc_cos: 0.600 | auc_eu: 0.670 | auc_cos: 0.676
# 	val: acc_eu: 0.654 | acc_cos: 0.838 | auc_eu: 0.720 | auc_cos: 0.706
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 16:
# 	train: loss 0.435 | loss id   0.41 | top_1_acc 0.0232 | top_5_acc 0.1009 | acc_eu: 0.632 | acc_cos: 0.659 | auc_eu: 0.653 | auc_cos: 0.680
# 	val: acc_eu: 0.802 | acc_cos: 0.735 | auc_eu: 0.725 | auc_cos: 0.771
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 17:
# 	train: loss 0.454 | loss id   0.43 | top_1_acc 0.0239 | top_5_acc 0.1211 | acc_eu: 0.686 | acc_cos: 0.648 | auc_eu: 0.738 | auc_cos: 0.751
# 	val: acc_eu: 0.667 | acc_cos: 0.756 | auc_eu: 0.764 | auc_cos: 0.799
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 18:
# 	train: loss 0.430 | loss id   0.41 | top_1_acc 0.0359 | top_5_acc 0.1383 | acc_eu: 0.683 | acc_cos: 0.676 | auc_eu: 0.729 | auc_cos: 0.752
# 	val: acc_eu: 0.810 | acc_cos: 0.765 | auc_eu: 0.743 | auc_cos: 0.790
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 19:
# 	train: loss 0.424 | loss id   0.40 | top_1_acc 0.0336 | top_5_acc 0.1278 | acc_eu: 0.667 | acc_cos: 0.620 | auc_eu: 0.750 | auc_cos: 0.768
# 	val: acc_eu: 0.667 | acc_cos: 0.711 | auc_eu: 0.773 | auc_cos: 0.815
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 20:
# 	train: loss 0.450 | loss id   0.43 | top_1_acc 0.0433 | top_5_acc 0.1555 | acc_eu: 0.674 | acc_cos: 0.647 | auc_eu: 0.735 | auc_cos: 0.771
# 	val: acc_eu: 0.713 | acc_cos: 0.816 | auc_eu: 0.730 | auc_cos: 0.808
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 21:
# 	train: loss 0.452 | loss id   0.43 | top_1_acc 0.0404 | top_5_acc 0.1659 | acc_eu: 0.711 | acc_cos: 0.595 | auc_eu: 0.718 | auc_cos: 0.741
# 	val: acc_eu: 0.853 | acc_cos: 0.751 | auc_eu: 0.748 | auc_cos: 0.786
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 22:
# 	train: loss 0.469 | loss id   0.45 | top_1_acc 0.0516 | top_5_acc 0.1883 | acc_eu: 0.708 | acc_cos: 0.651 | auc_eu: 0.718 | auc_cos: 0.759
# 	val: acc_eu: 0.794 | acc_cos: 0.656 | auc_eu: 0.744 | auc_cos: 0.800
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 23:
# 	train: loss 0.457 | loss id   0.43 | top_1_acc 0.0620 | top_5_acc 0.1928 | acc_eu: 0.700 | acc_cos: 0.619 | auc_eu: 0.750 | auc_cos: 0.777
# 	val: acc_eu: 0.700 | acc_cos: 0.718 | auc_eu: 0.788 | auc_cos: 0.821
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 24:
# 	train: loss 0.465 | loss id   0.44 | top_1_acc 0.0590 | top_5_acc 0.2018 | acc_eu: 0.676 | acc_cos: 0.634 | auc_eu: 0.751 | auc_cos: 0.779
# 	val: acc_eu: 0.661 | acc_cos: 0.667 | auc_eu: 0.795 | auc_cos: 0.823
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 25:
# 	train: loss 0.471 | loss id   0.45 | top_1_acc 0.0710 | top_5_acc 0.2205 | acc_eu: 0.742 | acc_cos: 0.675 | auc_eu: 0.759 | auc_cos: 0.791
# 	val: acc_eu: 0.822 | acc_cos: 0.757 | auc_eu: 0.750 | auc_cos: 0.827
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 26:
# 	train: loss 0.515 | loss id   0.49 | top_1_acc 0.0964 | top_5_acc 0.2698 | acc_eu: 0.812 | acc_cos: 0.768 | auc_eu: 0.759 | auc_cos: 0.793
# 	val: acc_eu: 0.794 | acc_cos: 0.839 | auc_eu: 0.770 | auc_cos: 0.840
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 27:
# 	train: loss 0.442 | loss id   0.42 | top_1_acc 0.0934 | top_5_acc 0.2735 | acc_eu: 0.702 | acc_cos: 0.747 | auc_eu: 0.796 | auc_cos: 0.838
# 	val: acc_eu: 0.700 | acc_cos: 0.828 | auc_eu: 0.813 | auc_cos: 0.863
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 28:
# 	train: loss 0.551 | loss id   0.53 | top_1_acc 0.1121 | top_5_acc 0.3027 | acc_eu: 0.760 | acc_cos: 0.757 | auc_eu: 0.804 | auc_cos: 0.855
# 	val: acc_eu: 0.744 | acc_cos: 0.770 | auc_eu: 0.821 | auc_cos: 0.866
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 29:
# 	train: loss 0.461 | loss id   0.44 | top_1_acc 0.1024 | top_5_acc 0.3303 | acc_eu: 0.757 | acc_cos: 0.763 | auc_eu: 0.834 | auc_cos: 0.865
# 	val: acc_eu: 0.869 | acc_cos: 0.846 | auc_eu: 0.859 | auc_cos: 0.877
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 30:
# 	train: loss 0.494 | loss id   0.47 | top_1_acc 0.1173 | top_5_acc 0.3520 | acc_eu: 0.773 | acc_cos: 0.747 | auc_eu: 0.834 | auc_cos: 0.868
# 	val: acc_eu: 0.774 | acc_cos: 0.792 | auc_eu: 0.853 | auc_cos: 0.877
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 31:
# 	train: loss 0.494 | loss id   0.47 | top_1_acc 0.1525 | top_5_acc 0.3886 | acc_eu: 0.767 | acc_cos: 0.741 | auc_eu: 0.814 | auc_cos: 0.846
# 	val: acc_eu: 0.864 | acc_cos: 0.748 | auc_eu: 0.830 | auc_cos: 0.878
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 32:
# 	train: loss 0.499 | loss id   0.48 | top_1_acc 0.1809 | top_5_acc 0.4297 | acc_eu: 0.729 | acc_cos: 0.681 | auc_eu: 0.747 | auc_cos: 0.744
# 	val: acc_eu: 0.747 | acc_cos: 0.790 | auc_eu: 0.813 | auc_cos: 0.805
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 33:
# 	train: loss 0.553 | loss id   0.53 | top_1_acc 0.1861 | top_5_acc 0.4439 | acc_eu: 0.762 | acc_cos: 0.693 | auc_eu: 0.786 | auc_cos: 0.802
# 	val: acc_eu: 0.879 | acc_cos: 0.780 | auc_eu: 0.799 | auc_cos: 0.831
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 34:
# 	train: loss 0.538 | loss id   0.52 | top_1_acc 0.2160 | top_5_acc 0.4933 | acc_eu: 0.755 | acc_cos: 0.763 | auc_eu: 0.786 | auc_cos: 0.819
# 	val: acc_eu: 0.816 | acc_cos: 0.802 | auc_eu: 0.815 | auc_cos: 0.844
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 35:
# 	train: loss 0.510 | loss id   0.49 | top_1_acc 0.2070 | top_5_acc 0.4933 | acc_eu: 0.760 | acc_cos: 0.780 | auc_eu: 0.860 | auc_cos: 0.885
# 	val: acc_eu: 0.894 | acc_cos: 0.842 | auc_eu: 0.880 | auc_cos: 0.900
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 36:
# 	train: loss 0.566 | loss id   0.54 | top_1_acc 0.2220 | top_5_acc 0.5277 | acc_eu: 0.810 | acc_cos: 0.780 | auc_eu: 0.831 | auc_cos: 0.854
# 	val: acc_eu: 0.815 | acc_cos: 0.862 | auc_eu: 0.851 | auc_cos: 0.866
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 37:
# 	train: loss 0.496 | loss id   0.47 | top_1_acc 0.2698 | top_5_acc 0.5575 | acc_eu: 0.810 | acc_cos: 0.774 | auc_eu: 0.861 | auc_cos: 0.872
# 	val: acc_eu: 0.913 | acc_cos: 0.828 | auc_eu: 0.865 | auc_cos: 0.884
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 38:
# 	train: loss 0.566 | loss id   0.54 | top_1_acc 0.2668 | top_5_acc 0.5605 | acc_eu: 0.810 | acc_cos: 0.816 | auc_eu: 0.872 | auc_cos: 0.910
# 	val: acc_eu: 0.805 | acc_cos: 0.882 | auc_eu: 0.863 | auc_cos: 0.897
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 39:
# 	train: loss 0.536 | loss id   0.51 | top_1_acc 0.2915 | top_5_acc 0.5979 | acc_eu: 0.854 | acc_cos: 0.840 | auc_eu: 0.884 | auc_cos: 0.916
# 	val: acc_eu: 0.815 | acc_cos: 0.916 | auc_eu: 0.868 | auc_cos: 0.914
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# Epoch 40:
# 	train: loss 0.534 | loss id   0.51 | top_1_acc 0.2848 | top_5_acc 0.5845 | acc_eu: 0.830 | acc_cos: 0.832 | auc_eu: 0.876 | auc_cos: 0.904
# 	val: acc_eu: 0.857 | acc_cos: 0.837 | auc_eu: 0.859 | auc_cos: 0.887
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 40 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_euclidean_accuracy_40.pth'
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 40 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_cosine_accuracy_40.pth'
# 	Saved best model weights for 'val_auc_euclidean' at epoch 40 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_euclidean_40.pth'
# 	Saved best model weights for 'val_auc_cosine' at epoch 40 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_cosine_40.pth'
# Epoch 41:
# 	train: loss 0.538 | loss id   0.51 | top_1_acc 0.2653 | top_5_acc 0.5837 | acc_eu: 0.811 | acc_cos: 0.788 | auc_eu: 0.877 | auc_cos: 0.907
# 	val: acc_eu: 0.873 | acc_cos: 0.869 | auc_eu: 0.861 | auc_cos: 0.878
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 41 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_euclidean_accuracy_41.pth'
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 41 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_cosine_accuracy_41.pth'
# 	Saved best model weights for 'val_auc_euclidean' at epoch 41 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_euclidean_41.pth'
# 	Epoch 41: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 42:
# 	train: loss 0.579 | loss id   0.56 | top_1_acc 0.2960 | top_5_acc 0.6114 | acc_eu: 0.796 | acc_cos: 0.791 | auc_eu: 0.851 | auc_cos: 0.853
# 	val: acc_eu: 0.850 | acc_cos: 0.856 | auc_eu: 0.841 | auc_cos: 0.877
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 42: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 42: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 42: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 42: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 43:
# 	train: loss 0.533 | loss id   0.51 | top_1_acc 0.3572 | top_5_acc 0.6786 | acc_eu: 0.803 | acc_cos: 0.736 | auc_eu: 0.838 | auc_cos: 0.864
# 	val: acc_eu: 0.898 | acc_cos: 0.816 | auc_eu: 0.860 | auc_cos: 0.879
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 43 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_euclidean_accuracy_43.pth'
# 	Epoch 43: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 43: EarlyStopping counter for 'val_auc_euclidean': 2/40
# 	Epoch 43: EarlyStopping counter for 'val_auc_cosine': 3/40
# Epoch 44:
# 	train: loss 0.566 | loss id   0.54 | top_1_acc 0.3655 | top_5_acc 0.6786 | acc_eu: 0.798 | acc_cos: 0.833 | auc_eu: 0.809 | auc_cos: 0.853
# 	val: acc_eu: 0.791 | acc_cos: 0.852 | auc_eu: 0.855 | auc_cos: 0.885
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 44: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 44: EarlyStopping counter for 'val_cosine_accuracy': 3/40
# 	Epoch 44: EarlyStopping counter for 'val_auc_euclidean': 3/40
# 	Epoch 44: EarlyStopping counter for 'val_auc_cosine': 4/40
# Epoch 45:
# 	train: loss 0.606 | loss id   0.58 | top_1_acc 0.4013 | top_5_acc 0.7212 | acc_eu: 0.825 | acc_cos: 0.813 | auc_eu: 0.894 | auc_cos: 0.920
# 	val: acc_eu: 0.814 | acc_cos: 0.858 | auc_eu: 0.864 | auc_cos: 0.891
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 45: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Epoch 45: EarlyStopping counter for 'val_cosine_accuracy': 4/40
# 	Saved best model weights for 'val_auc_euclidean' at epoch 45 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_euclidean_45.pth'
# 	Saved best model weights for 'val_auc_cosine' at epoch 45 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_cosine_45.pth'
# Epoch 46:
# 	train: loss 0.559 | loss id   0.54 | top_1_acc 0.4425 | top_5_acc 0.7735 | acc_eu: 0.822 | acc_cos: 0.843 | auc_eu: 0.897 | auc_cos: 0.918
# 	val: acc_eu: 0.911 | acc_cos: 0.889 | auc_eu: 0.852 | auc_cos: 0.889
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 46 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_euclidean_accuracy_46.pth'
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 46 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_cosine_accuracy_46.pth'
# 	Epoch 46: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 46: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 47:
# 	train: loss 0.567 | loss id   0.54 | top_1_acc 0.4552 | top_5_acc 0.7676 | acc_eu: 0.813 | acc_cos: 0.848 | auc_eu: 0.911 | auc_cos: 0.929
# 	val: acc_eu: 0.865 | acc_cos: 0.800 | auc_eu: 0.873 | auc_cos: 0.892
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 47: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Epoch 47: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Saved best model weights for 'val_auc_euclidean' at epoch 47 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_euclidean_47.pth'
# 	Saved best model weights for 'val_auc_cosine' at epoch 47 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_cosine_47.pth'
# Epoch 48:
# 	train: loss 0.521 | loss id   0.50 | top_1_acc 0.4425 | top_5_acc 0.7511 | acc_eu: 0.863 | acc_cos: 0.829 | auc_eu: 0.895 | auc_cos: 0.921
# 	val: acc_eu: 0.864 | acc_cos: 0.827 | auc_eu: 0.859 | auc_cos: 0.886
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 48: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Epoch 48: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 48: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 48: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 49:
# 	train: loss 0.586 | loss id   0.56 | top_1_acc 0.4425 | top_5_acc 0.7855 | acc_eu: 0.846 | acc_cos: 0.853 | auc_eu: 0.906 | auc_cos: 0.930
# 	val: acc_eu: 0.875 | acc_cos: 0.824 | auc_eu: 0.852 | auc_cos: 0.887
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 49: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Epoch 49: EarlyStopping counter for 'val_cosine_accuracy': 3/40
# 	Epoch 49: EarlyStopping counter for 'val_auc_euclidean': 2/40
# 	Epoch 49: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 50:
# 	train: loss 0.624 | loss id   0.60 | top_1_acc 0.5015 | top_5_acc 0.8169 | acc_eu: 0.846 | acc_cos: 0.849 | auc_eu: 0.910 | auc_cos: 0.935
# 	val: acc_eu: 0.871 | acc_cos: 0.852 | auc_eu: 0.886 | auc_cos: 0.893
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 50: EarlyStopping counter for 'val_euclidean_accuracy': 4/40
# 	Epoch 50: EarlyStopping counter for 'val_cosine_accuracy': 4/40
# 	Saved best model weights for 'val_auc_euclidean' at epoch 50 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_euclidean_50.pth'
# 	Saved best model weights for 'val_auc_cosine' at epoch 50 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_cosine_50.pth'
# Epoch 51:
# 	train: loss 0.683 | loss id   0.66 | top_1_acc 0.5045 | top_5_acc 0.8236 | acc_eu: 0.831 | acc_cos: 0.826 | auc_eu: 0.845 | auc_cos: 0.885
# 	val: acc_eu: 0.835 | acc_cos: 0.833 | auc_eu: 0.839 | auc_cos: 0.877
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 51: EarlyStopping counter for 'val_euclidean_accuracy': 5/40
# 	Epoch 51: EarlyStopping counter for 'val_cosine_accuracy': 5/40
# 	Epoch 51: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 51: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 52:
# 	train: loss 0.703 | loss id   0.68 | top_1_acc 0.4776 | top_5_acc 0.7870 | acc_eu: 0.809 | acc_cos: 0.801 | auc_eu: 0.871 | auc_cos: 0.861
# 	val: acc_eu: 0.867 | acc_cos: 0.681 | auc_eu: 0.846 | auc_cos: 0.867
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 52: EarlyStopping counter for 'val_euclidean_accuracy': 6/40
# 	Epoch 52: EarlyStopping counter for 'val_cosine_accuracy': 6/40
# 	Epoch 52: EarlyStopping counter for 'val_auc_euclidean': 2/40
# 	Epoch 52: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 53:
# 	train: loss 0.696 | loss id   0.67 | top_1_acc 0.5254 | top_5_acc 0.8288 | acc_eu: 0.824 | acc_cos: 0.809 | auc_eu: 0.862 | auc_cos: 0.887
# 	val: acc_eu: 0.924 | acc_cos: 0.850 | auc_eu: 0.810 | auc_cos: 0.875
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Saved best model weights for 'val_euclidean_accuracy' at epoch 53 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_euclidean_accuracy_53.pth'
# 	Epoch 53: EarlyStopping counter for 'val_cosine_accuracy': 7/40
# 	Epoch 53: EarlyStopping counter for 'val_auc_euclidean': 3/40
# 	Epoch 53: EarlyStopping counter for 'val_auc_cosine': 3/40
# Epoch 54:
# 	train: loss 0.748 | loss id   0.73 | top_1_acc 0.5239 | top_5_acc 0.8498 | acc_eu: 0.849 | acc_cos: 0.849 | auc_eu: 0.914 | auc_cos: 0.920
# 	val: acc_eu: 0.844 | acc_cos: 0.902 | auc_eu: 0.890 | auc_cos: 0.885
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 54: EarlyStopping counter for 'val_euclidean_accuracy': 1/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 54 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_cosine_accuracy_54.pth'
# 	Saved best model weights for 'val_auc_euclidean' at epoch 54 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_euclidean_54.pth'
# 	Epoch 54: EarlyStopping counter for 'val_auc_cosine': 4/40
# Epoch 55:
# 	train: loss 0.720 | loss id   0.70 | top_1_acc 0.6143 | top_5_acc 0.8894 | acc_eu: 0.875 | acc_cos: 0.868 | auc_eu: 0.915 | auc_cos: 0.920
# 	val: acc_eu: 0.916 | acc_cos: 0.908 | auc_eu: 0.880 | auc_cos: 0.873
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 55: EarlyStopping counter for 'val_euclidean_accuracy': 2/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 55 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_cosine_accuracy_55.pth'
# 	Epoch 55: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 55: EarlyStopping counter for 'val_auc_cosine': 5/40
# Epoch 56:
# 	train: loss 0.767 | loss id   0.74 | top_1_acc 0.5957 | top_5_acc 0.8767 | acc_eu: 0.871 | acc_cos: 0.852 | auc_eu: 0.921 | auc_cos: 0.917
# 	val: acc_eu: 0.816 | acc_cos: 0.825 | auc_eu: 0.864 | auc_cos: 0.879
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 56: EarlyStopping counter for 'val_euclidean_accuracy': 3/40
# 	Epoch 56: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 56: EarlyStopping counter for 'val_auc_euclidean': 2/40
# 	Epoch 56: EarlyStopping counter for 'val_auc_cosine': 6/40
# Epoch 57:
# 	train: loss 0.840 | loss id   0.82 | top_1_acc 0.6129 | top_5_acc 0.9013 | acc_eu: 0.860 | acc_cos: 0.857 | auc_eu: 0.910 | auc_cos: 0.936
# 	val: acc_eu: 0.841 | acc_cos: 0.918 | auc_eu: 0.841 | auc_cos: 0.862
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 57: EarlyStopping counter for 'val_euclidean_accuracy': 4/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 57 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_cosine_accuracy_57.pth'
# 	Epoch 57: EarlyStopping counter for 'val_auc_euclidean': 3/40
# 	Epoch 57: EarlyStopping counter for 'val_auc_cosine': 7/40
# Epoch 58:
# 	train: loss 0.961 | loss id   0.94 | top_1_acc 0.5859 | top_5_acc 0.8617 | acc_eu: 0.860 | acc_cos: 0.845 | auc_eu: 0.885 | auc_cos: 0.913
# 	val: acc_eu: 0.837 | acc_cos: 0.831 | auc_eu: 0.860 | auc_cos: 0.867
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 58: EarlyStopping counter for 'val_euclidean_accuracy': 5/40
# 	Epoch 58: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 58: EarlyStopping counter for 'val_auc_euclidean': 4/40
# 	Epoch 58: EarlyStopping counter for 'val_auc_cosine': 8/40
# Epoch 59:
# 	train: loss 1.027 | loss id   1.00 | top_1_acc 0.5830 | top_5_acc 0.8700 | acc_eu: 0.861 | acc_cos: 0.854 | auc_eu: 0.917 | auc_cos: 0.919
# 	val: acc_eu: 0.893 | acc_cos: 0.917 | auc_eu: 0.866 | auc_cos: 0.866
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 59: EarlyStopping counter for 'val_euclidean_accuracy': 6/40
# 	Epoch 59: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 59: EarlyStopping counter for 'val_auc_euclidean': 5/40
# 	Epoch 59: EarlyStopping counter for 'val_auc_cosine': 9/40
# Epoch 60:
# 	train: loss 1.038 | loss id   1.02 | top_1_acc 0.6016 | top_5_acc 0.8647 | acc_eu: 0.868 | acc_cos: 0.847 | auc_eu: 0.917 | auc_cos: 0.921
# 	val: acc_eu: 0.844 | acc_cos: 0.871 | auc_eu: 0.844 | auc_cos: 0.838
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 60: EarlyStopping counter for 'val_euclidean_accuracy': 7/40
# 	Epoch 60: EarlyStopping counter for 'val_cosine_accuracy': 3/40
# 	Epoch 60: EarlyStopping counter for 'val_auc_euclidean': 6/40
# 	Epoch 60: EarlyStopping counter for 'val_auc_cosine': 10/40
# Epoch 61:
# 	train: loss 1.098 | loss id   1.08 | top_1_acc 0.6226 | top_5_acc 0.8864 | acc_eu: 0.886 | acc_cos: 0.848 | auc_eu: 0.908 | auc_cos: 0.913
# 	val: acc_eu: 0.826 | acc_cos: 0.877 | auc_eu: 0.843 | auc_cos: 0.857
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 61: EarlyStopping counter for 'val_euclidean_accuracy': 8/40
# 	Epoch 61: EarlyStopping counter for 'val_cosine_accuracy': 4/40
# 	Epoch 61: EarlyStopping counter for 'val_auc_euclidean': 7/40
# 	Epoch 61: EarlyStopping counter for 'val_auc_cosine': 11/40
# Epoch 62:
# 	train: loss 1.183 | loss id   1.16 | top_1_acc 0.6570 | top_5_acc 0.8857 | acc_eu: 0.849 | acc_cos: 0.798 | auc_eu: 0.857 | auc_cos: 0.845
# 	val: acc_eu: 0.903 | acc_cos: 0.843 | auc_eu: 0.829 | auc_cos: 0.840
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 62: EarlyStopping counter for 'val_euclidean_accuracy': 9/40
# 	Epoch 62: EarlyStopping counter for 'val_cosine_accuracy': 5/40
# 	Epoch 62: EarlyStopping counter for 'val_auc_euclidean': 8/40
# 	Epoch 62: EarlyStopping counter for 'val_auc_cosine': 12/40
# Epoch 63:
# 	train: loss 1.354 | loss id   1.33 | top_1_acc 0.6704 | top_5_acc 0.9013 | acc_eu: 0.811 | acc_cos: 0.782 | auc_eu: 0.791 | auc_cos: 0.779
# 	val: acc_eu: 0.888 | acc_cos: 0.734 | auc_eu: 0.757 | auc_cos: 0.779
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 63: EarlyStopping counter for 'val_euclidean_accuracy': 10/40
# 	Epoch 63: EarlyStopping counter for 'val_cosine_accuracy': 6/40
# 	Epoch 63: EarlyStopping counter for 'val_auc_euclidean': 9/40
# 	Epoch 63: EarlyStopping counter for 'val_auc_cosine': 13/40
# Epoch 64:
# 	train: loss 1.361 | loss id   1.34 | top_1_acc 0.6659 | top_5_acc 0.9163 | acc_eu: 0.850 | acc_cos: 0.830 | auc_eu: 0.894 | auc_cos: 0.894
# 	val: acc_eu: 0.839 | acc_cos: 0.838 | auc_eu: 0.827 | auc_cos: 0.824
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 64: EarlyStopping counter for 'val_euclidean_accuracy': 11/40
# 	Epoch 64: EarlyStopping counter for 'val_cosine_accuracy': 7/40
# 	Epoch 64: EarlyStopping counter for 'val_auc_euclidean': 10/40
# 	Epoch 64: EarlyStopping counter for 'val_auc_cosine': 14/40
# Epoch 65:
# 	train: loss 1.510 | loss id   1.49 | top_1_acc 0.7033 | top_5_acc 0.9238 | acc_eu: 0.887 | acc_cos: 0.820 | auc_eu: 0.897 | auc_cos: 0.889
# 	val: acc_eu: 0.871 | acc_cos: 0.814 | auc_eu: 0.849 | auc_cos: 0.819
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 65: EarlyStopping counter for 'val_euclidean_accuracy': 12/40
# 	Epoch 65: EarlyStopping counter for 'val_cosine_accuracy': 8/40
# 	Epoch 65: EarlyStopping counter for 'val_auc_euclidean': 11/40
# 	Epoch 65: EarlyStopping counter for 'val_auc_cosine': 15/40
# Epoch 66:
# 	train: loss 1.681 | loss id   1.66 | top_1_acc 0.7354 | top_5_acc 0.9253 | acc_eu: 0.908 | acc_cos: 0.848 | auc_eu: 0.912 | auc_cos: 0.918
# 	val: acc_eu: 0.856 | acc_cos: 0.827 | auc_eu: 0.826 | auc_cos: 0.823
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 66: EarlyStopping counter for 'val_euclidean_accuracy': 13/40
# 	Epoch 66: EarlyStopping counter for 'val_cosine_accuracy': 9/40
# 	Epoch 66: EarlyStopping counter for 'val_auc_euclidean': 12/40
# 	Epoch 66: EarlyStopping counter for 'val_auc_cosine': 16/40
# Epoch 67:
# 	train: loss 1.746 | loss id   1.72 | top_1_acc 0.7332 | top_5_acc 0.9230 | acc_eu: 0.895 | acc_cos: 0.854 | auc_eu: 0.925 | auc_cos: 0.928
# 	val: acc_eu: 0.885 | acc_cos: 0.755 | auc_eu: 0.836 | auc_cos: 0.846
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 67: EarlyStopping counter for 'val_euclidean_accuracy': 14/40
# 	Epoch 67: EarlyStopping counter for 'val_cosine_accuracy': 10/40
# 	Epoch 67: EarlyStopping counter for 'val_auc_euclidean': 13/40
# 	Epoch 67: EarlyStopping counter for 'val_auc_cosine': 17/40
# Epoch 68:
# 	train: loss 2.067 | loss id   2.04 | top_1_acc 0.7795 | top_5_acc 0.9439 | acc_eu: 0.926 | acc_cos: 0.878 | auc_eu: 0.923 | auc_cos: 0.957
# 	val: acc_eu: 0.782 | acc_cos: 0.764 | auc_eu: 0.827 | auc_cos: 0.874
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 68: EarlyStopping counter for 'val_euclidean_accuracy': 15/40
# 	Epoch 68: EarlyStopping counter for 'val_cosine_accuracy': 11/40
# 	Epoch 68: EarlyStopping counter for 'val_auc_euclidean': 14/40
# 	Epoch 68: EarlyStopping counter for 'val_auc_cosine': 18/40
# Epoch 69:
# 	train: loss 2.190 | loss id   2.17 | top_1_acc 0.8206 | top_5_acc 0.9544 | acc_eu: 0.927 | acc_cos: 0.933 | auc_eu: 0.974 | auc_cos: 0.986
# 	val: acc_eu: 0.785 | acc_cos: 0.914 | auc_eu: 0.893 | auc_cos: 0.935
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 69: EarlyStopping counter for 'val_euclidean_accuracy': 16/40
# 	Epoch 69: EarlyStopping counter for 'val_cosine_accuracy': 12/40
# 	Saved best model weights for 'val_auc_euclidean' at epoch 69 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_euclidean_69.pth'
# 	Saved best model weights for 'val_auc_cosine' at epoch 69 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_cosine_69.pth'
# Epoch 70:
# 	train: loss 1.964 | loss id   1.94 | top_1_acc 0.8535 | top_5_acc 0.9611 | acc_eu: 0.935 | acc_cos: 0.951 | auc_eu: 0.977 | auc_cos: 0.992
# 	val: acc_eu: 0.848 | acc_cos: 0.864 | auc_eu: 0.885 | auc_cos: 0.938
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 70: EarlyStopping counter for 'val_euclidean_accuracy': 17/40
# 	Epoch 70: EarlyStopping counter for 'val_cosine_accuracy': 13/40
# 	Epoch 70: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 70 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_cosine_70.pth'
# Epoch 71:
# 	train: loss 1.813 | loss id   1.79 | top_1_acc 0.8961 | top_5_acc 0.9798 | acc_eu: 0.952 | acc_cos: 0.960 | auc_eu: 0.986 | auc_cos: 0.992
# 	val: acc_eu: 0.869 | acc_cos: 0.830 | auc_eu: 0.907 | auc_cos: 0.937
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 71: EarlyStopping counter for 'val_euclidean_accuracy': 18/40
# 	Epoch 71: EarlyStopping counter for 'val_cosine_accuracy': 14/40
# 	Saved best model weights for 'val_auc_euclidean' at epoch 71 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_euclidean_71.pth'
# 	Epoch 71: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 72:
# 	train: loss 1.683 | loss id   1.66 | top_1_acc 0.9253 | top_5_acc 0.9895 | acc_eu: 0.887 | acc_cos: 0.886 | auc_eu: 0.943 | auc_cos: 0.961
# 	val: acc_eu: 0.637 | acc_cos: 0.809 | auc_eu: 0.826 | auc_cos: 0.841
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 72: EarlyStopping counter for 'val_euclidean_accuracy': 19/40
# 	Epoch 72: EarlyStopping counter for 'val_cosine_accuracy': 15/40
# 	Epoch 72: EarlyStopping counter for 'val_auc_euclidean': 1/40
# 	Epoch 72: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 73:
# 	train: loss 1.591 | loss id   1.57 | top_1_acc 0.9327 | top_5_acc 0.9880 | acc_eu: 0.939 | acc_cos: 0.970 | auc_eu: 0.980 | auc_cos: 0.995
# 	val: acc_eu: 0.823 | acc_cos: 0.886 | auc_eu: 0.866 | auc_cos: 0.922
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 73: EarlyStopping counter for 'val_euclidean_accuracy': 20/40
# 	Epoch 73: EarlyStopping counter for 'val_cosine_accuracy': 16/40
# 	Epoch 73: EarlyStopping counter for 'val_auc_euclidean': 2/40
# 	Epoch 73: EarlyStopping counter for 'val_auc_cosine': 3/40
# Epoch 74:
# 	train: loss 1.457 | loss id   1.43 | top_1_acc 0.9462 | top_5_acc 0.9910 | acc_eu: 0.947 | acc_cos: 0.973 | auc_eu: 0.987 | auc_cos: 0.997
# 	val: acc_eu: 0.832 | acc_cos: 0.901 | auc_eu: 0.865 | auc_cos: 0.921
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 74: EarlyStopping counter for 'val_euclidean_accuracy': 21/40
# 	Epoch 74: EarlyStopping counter for 'val_cosine_accuracy': 17/40
# 	Epoch 74: EarlyStopping counter for 'val_auc_euclidean': 3/40
# 	Epoch 74: EarlyStopping counter for 'val_auc_cosine': 4/40
# Epoch 75:
# 	train: loss 1.352 | loss id   1.33 | top_1_acc 0.9679 | top_5_acc 0.9970 | acc_eu: 0.947 | acc_cos: 0.923 | auc_eu: 0.984 | auc_cos: 0.983
# 	val: acc_eu: 0.844 | acc_cos: 0.887 | auc_eu: 0.891 | auc_cos: 0.878
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 75: EarlyStopping counter for 'val_euclidean_accuracy': 22/40
# 	Epoch 75: EarlyStopping counter for 'val_cosine_accuracy': 18/40
# 	Epoch 75: EarlyStopping counter for 'val_auc_euclidean': 4/40
# 	Epoch 75: EarlyStopping counter for 'val_auc_cosine': 5/40
# Epoch 76:
# 	train: loss 1.269 | loss id   1.25 | top_1_acc 0.9776 | top_5_acc 0.9985 | acc_eu: 0.978 | acc_cos: 0.988 | auc_eu: 0.997 | auc_cos: 0.999
# 	val: acc_eu: 0.842 | acc_cos: 0.883 | auc_eu: 0.885 | auc_cos: 0.923
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 76: EarlyStopping counter for 'val_euclidean_accuracy': 23/40
# 	Epoch 76: EarlyStopping counter for 'val_cosine_accuracy': 19/40
# 	Epoch 76: EarlyStopping counter for 'val_auc_euclidean': 5/40
# 	Epoch 76: EarlyStopping counter for 'val_auc_cosine': 6/40
# Epoch 77:
# 	train: loss 1.176 | loss id   1.15 | top_1_acc 0.9851 | top_5_acc 1.0000 | acc_eu: 0.980 | acc_cos: 0.993 | auc_eu: 0.998 | auc_cos: 1.000
# 	val: acc_eu: 0.855 | acc_cos: 0.894 | auc_eu: 0.892 | auc_cos: 0.935
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 77: EarlyStopping counter for 'val_euclidean_accuracy': 24/40
# 	Epoch 77: EarlyStopping counter for 'val_cosine_accuracy': 20/40
# 	Epoch 77: EarlyStopping counter for 'val_auc_euclidean': 6/40
# 	Epoch 77: EarlyStopping counter for 'val_auc_cosine': 7/40
# Epoch 78:
# 	train: loss 1.033 | loss id   1.01 | top_1_acc 0.9925 | top_5_acc 1.0000 | acc_eu: 0.991 | acc_cos: 0.997 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.871 | acc_cos: 0.857 | auc_eu: 0.892 | auc_cos: 0.941
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 78: EarlyStopping counter for 'val_euclidean_accuracy': 25/40
# 	Epoch 78: EarlyStopping counter for 'val_cosine_accuracy': 21/40
# 	Epoch 78: EarlyStopping counter for 'val_auc_euclidean': 7/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 78 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_cosine_78.pth'
# Epoch 79:
# 	train: loss 0.933 | loss id   0.91 | top_1_acc 0.9955 | top_5_acc 1.0000 | acc_eu: 0.992 | acc_cos: 0.999 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.847 | acc_cos: 0.870 | auc_eu: 0.884 | auc_cos: 0.942
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 79: EarlyStopping counter for 'val_euclidean_accuracy': 26/40
# 	Epoch 79: EarlyStopping counter for 'val_cosine_accuracy': 22/40
# 	Epoch 79: EarlyStopping counter for 'val_auc_euclidean': 8/40
# 	Saved best model weights for 'val_auc_cosine' at epoch 79 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_auc_cosine_79.pth'
# Epoch 80:
# 	train: loss 0.914 | loss id   0.89 | top_1_acc 0.9955 | top_5_acc 0.9993 | acc_eu: 0.994 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.900 | acc_cos: 0.895 | auc_eu: 0.895 | auc_cos: 0.932
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 80: EarlyStopping counter for 'val_euclidean_accuracy': 27/40
# 	Epoch 80: EarlyStopping counter for 'val_cosine_accuracy': 23/40
# 	Epoch 80: EarlyStopping counter for 'val_auc_euclidean': 9/40
# 	Epoch 80: EarlyStopping counter for 'val_auc_cosine': 1/40
# Epoch 81:
# 	train: loss 0.870 | loss id   0.85 | top_1_acc 0.9955 | top_5_acc 1.0000 | acc_eu: 0.981 | acc_cos: 0.992 | auc_eu: 0.998 | auc_cos: 1.000
# 	val: acc_eu: 0.815 | acc_cos: 0.947 | auc_eu: 0.867 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 81: EarlyStopping counter for 'val_euclidean_accuracy': 28/40
# 	Saved best model weights for 'val_cosine_accuracy' at epoch 81 to '/media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/best_val_cosine_accuracy_81.pth'
# 	Epoch 81: EarlyStopping counter for 'val_auc_euclidean': 10/40
# 	Epoch 81: EarlyStopping counter for 'val_auc_cosine': 2/40
# Epoch 82:
# 	train: loss 0.787 | loss id   0.76 | top_1_acc 0.9978 | top_5_acc 1.0000 | acc_eu: 0.990 | acc_cos: 0.997 | auc_eu: 0.999 | auc_cos: 1.000
# 	val: acc_eu: 0.789 | acc_cos: 0.845 | auc_eu: 0.852 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 82: EarlyStopping counter for 'val_euclidean_accuracy': 29/40
# 	Epoch 82: EarlyStopping counter for 'val_cosine_accuracy': 1/40
# 	Epoch 82: EarlyStopping counter for 'val_auc_euclidean': 11/40
# 	Epoch 82: EarlyStopping counter for 'val_auc_cosine': 3/40
# Epoch 83:
# 	train: loss 0.713 | loss id   0.69 | top_1_acc 0.9993 | top_5_acc 1.0000 | acc_eu: 0.982 | acc_cos: 0.994 | auc_eu: 0.997 | auc_cos: 1.000
# 	val: acc_eu: 0.890 | acc_cos: 0.895 | auc_eu: 0.832 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 83: EarlyStopping counter for 'val_euclidean_accuracy': 30/40
# 	Epoch 83: EarlyStopping counter for 'val_cosine_accuracy': 2/40
# 	Epoch 83: EarlyStopping counter for 'val_auc_euclidean': 12/40
# 	Epoch 83: EarlyStopping counter for 'val_auc_cosine': 4/40
# Epoch 84:
# 	train: loss 0.650 | loss id   0.63 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.993 | acc_cos: 0.998 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.765 | acc_cos: 0.900 | auc_eu: 0.860 | auc_cos: 0.900
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 84: EarlyStopping counter for 'val_euclidean_accuracy': 31/40
# ...
# 	Epoch 97: EarlyStopping counter for 'val_euclidean_accuracy': 44/40
# 	Epoch 97: EarlyStopping counter for 'val_cosine_accuracy': 16/40
# 	Epoch 97: EarlyStopping counter for 'val_auc_euclidean': 26/40
# 	Epoch 97: EarlyStopping counter for 'val_auc_cosine': 18/40
# Epoch 98:
# 	train: loss 0.184 | loss id   0.16 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.840 | acc_cos: 0.841 | auc_eu: 0.857 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 98: EarlyStopping counter for 'val_euclidean_accuracy': 45/40
# 	Epoch 98: EarlyStopping counter for 'val_cosine_accuracy': 17/40
# 	Epoch 98: EarlyStopping counter for 'val_auc_euclidean': 27/40
# 	Epoch 98: EarlyStopping counter for 'val_auc_cosine': 19/40
# Epoch 99:
# 	train: loss 0.202 | loss id   0.18 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.766 | acc_cos: 0.913 | auc_eu: 0.860 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 99: EarlyStopping counter for 'val_euclidean_accuracy': 46/40
# 	Epoch 99: EarlyStopping counter for 'val_cosine_accuracy': 18/40
# 	Epoch 99: EarlyStopping counter for 'val_auc_euclidean': 28/40
# 	Epoch 99: EarlyStopping counter for 'val_auc_cosine': 20/40
# Epoch 100:
# 	train: loss 0.178 | loss id   0.16 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.832 | acc_cos: 0.935 | auc_eu: 0.860 | auc_cos: 0.898
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 100: EarlyStopping counter for 'val_euclidean_accuracy': 47/40
# 	Epoch 100: EarlyStopping counter for 'val_cosine_accuracy': 19/40
# 	Epoch 100: EarlyStopping counter for 'val_auc_euclidean': 29/40
# 	Epoch 100: EarlyStopping counter for 'val_auc_cosine': 21/40
# Epoch 101:
# 	train: loss 0.164 | loss id   0.14 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.874 | acc_cos: 0.906 | auc_eu: 0.863 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 101: EarlyStopping counter for 'val_euclidean_accuracy': 48/40
# 	Epoch 101: EarlyStopping counter for 'val_cosine_accuracy': 20/40
# 	Epoch 101: EarlyStopping counter for 'val_auc_euclidean': 30/40
# 	Epoch 101: EarlyStopping counter for 'val_auc_cosine': 22/40
# Epoch 102:
# 	train: loss 0.145 | loss id   0.12 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.763 | acc_cos: 0.911 | auc_eu: 0.865 | auc_cos: 0.898
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 102: EarlyStopping counter for 'val_euclidean_accuracy': 49/40
# 	Epoch 102: EarlyStopping counter for 'val_cosine_accuracy': 21/40
# 	Epoch 102: EarlyStopping counter for 'val_auc_euclidean': 31/40
# 	Epoch 102: EarlyStopping counter for 'val_auc_cosine': 23/40
# Epoch 103:
# 	train: loss 0.137 | loss id   0.11 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.846 | acc_cos: 0.870 | auc_eu: 0.857 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 103: EarlyStopping counter for 'val_euclidean_accuracy': 50/40
# 	Epoch 103: EarlyStopping counter for 'val_cosine_accuracy': 22/40
# 	Epoch 103: EarlyStopping counter for 'val_auc_euclidean': 32/40
# 	Epoch 103: EarlyStopping counter for 'val_auc_cosine': 24/40
# Epoch 104:
# 	train: loss 0.111 | loss id   0.09 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.871 | acc_cos: 0.905 | auc_eu: 0.861 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 104: EarlyStopping counter for 'val_euclidean_accuracy': 51/40
# 	Epoch 104: EarlyStopping counter for 'val_cosine_accuracy': 23/40
# 	Epoch 104: EarlyStopping counter for 'val_auc_euclidean': 33/40
# 	Epoch 104: EarlyStopping counter for 'val_auc_cosine': 25/40
# Epoch 105:
# 	train: loss 0.127 | loss id   0.10 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.790 | acc_cos: 0.891 | auc_eu: 0.847 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 105: EarlyStopping counter for 'val_euclidean_accuracy': 52/40
# 	Epoch 105: EarlyStopping counter for 'val_cosine_accuracy': 24/40
# 	Epoch 105: EarlyStopping counter for 'val_auc_euclidean': 34/40
# 	Epoch 105: EarlyStopping counter for 'val_auc_cosine': 26/40
# Epoch 106:
# 	train: loss 0.110 | loss id   0.09 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.774 | acc_cos: 0.879 | auc_eu: 0.861 | auc_cos: 0.900
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 106: EarlyStopping counter for 'val_euclidean_accuracy': 53/40
# 	Epoch 106: EarlyStopping counter for 'val_cosine_accuracy': 25/40
# 	Epoch 106: EarlyStopping counter for 'val_auc_euclidean': 35/40
# 	Epoch 106: EarlyStopping counter for 'val_auc_cosine': 27/40
# Epoch 107:
# 	train: loss 0.084 | loss id   0.06 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.878 | acc_cos: 0.921 | auc_eu: 0.861 | auc_cos: 0.896
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 107: EarlyStopping counter for 'val_euclidean_accuracy': 54/40
# 	Epoch 107: EarlyStopping counter for 'val_cosine_accuracy': 26/40
# 	Epoch 107: EarlyStopping counter for 'val_auc_euclidean': 36/40
# 	Epoch 107: EarlyStopping counter for 'val_auc_cosine': 28/40
# Epoch 108:
# 	train: loss 0.107 | loss id   0.08 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.817 | acc_cos: 0.868 | auc_eu: 0.863 | auc_cos: 0.909
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 108: EarlyStopping counter for 'val_euclidean_accuracy': 55/40
# 	Epoch 108: EarlyStopping counter for 'val_cosine_accuracy': 27/40
# 	Epoch 108: EarlyStopping counter for 'val_auc_euclidean': 37/40
# 	Epoch 108: EarlyStopping counter for 'val_auc_cosine': 29/40
# Epoch 109:
# 	train: loss 0.096 | loss id   0.07 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.781 | acc_cos: 0.909 | auc_eu: 0.849 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 109: EarlyStopping counter for 'val_euclidean_accuracy': 56/40
# 	Epoch 109: EarlyStopping counter for 'val_cosine_accuracy': 28/40
# 	Epoch 109: EarlyStopping counter for 'val_auc_euclidean': 38/40
# 	Epoch 109: EarlyStopping counter for 'val_auc_cosine': 30/40
# Epoch 110:
# 	train: loss 0.106 | loss id   0.08 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.736 | acc_cos: 0.911 | auc_eu: 0.847 | auc_cos: 0.902
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 110: EarlyStopping counter for 'val_euclidean_accuracy': 57/40
# 	Epoch 110: EarlyStopping counter for 'val_cosine_accuracy': 29/40
# 	Epoch 110: EarlyStopping counter for 'val_auc_euclidean': 39/40
# 	Epoch 110: EarlyStopping counter for 'val_auc_cosine': 31/40
# Epoch 111:
# 	train: loss 0.103 | loss id   0.08 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 0.999 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.808 | acc_cos: 0.862 | auc_eu: 0.855 | auc_cos: 0.893
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 111: EarlyStopping counter for 'val_euclidean_accuracy': 58/40
# 	Epoch 111: EarlyStopping counter for 'val_cosine_accuracy': 30/40
# 	Epoch 111: EarlyStopping counter for 'val_auc_euclidean': 40/40
# 	Epoch 111: EarlyStopping counter for 'val_auc_cosine': 32/40
# Epoch 112:
# 	train: loss 0.112 | loss id   0.09 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.785 | acc_cos: 0.920 | auc_eu: 0.858 | auc_cos: 0.892
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 112: EarlyStopping counter for 'val_euclidean_accuracy': 59/40
# 	Epoch 112: EarlyStopping counter for 'val_cosine_accuracy': 31/40
# 	Epoch 112: EarlyStopping counter for 'val_auc_euclidean': 41/40
# 	Epoch 112: EarlyStopping counter for 'val_auc_cosine': 33/40
# Epoch 113:
# 	train: loss 0.089 | loss id   0.07 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.820 | acc_cos: 0.901 | auc_eu: 0.860 | auc_cos: 0.905
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 113: EarlyStopping counter for 'val_euclidean_accuracy': 60/40
# 	Epoch 113: EarlyStopping counter for 'val_cosine_accuracy': 32/40
# 	Epoch 113: EarlyStopping counter for 'val_auc_euclidean': 42/40
# 	Epoch 113: EarlyStopping counter for 'val_auc_cosine': 34/40
# Epoch 114:
# 	train: loss 0.074 | loss id   0.05 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.795 | acc_cos: 0.863 | auc_eu: 0.852 | auc_cos: 0.908
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 114: EarlyStopping counter for 'val_euclidean_accuracy': 61/40
# 	Epoch 114: EarlyStopping counter for 'val_cosine_accuracy': 33/40
# 	Epoch 114: EarlyStopping counter for 'val_auc_euclidean': 43/40
# 	Epoch 114: EarlyStopping counter for 'val_auc_cosine': 35/40
# Epoch 115:
# 	train: loss 0.075 | loss id   0.05 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.753 | acc_cos: 0.808 | auc_eu: 0.854 | auc_cos: 0.901
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 115: EarlyStopping counter for 'val_euclidean_accuracy': 62/40
# 	Epoch 115: EarlyStopping counter for 'val_cosine_accuracy': 34/40
# 	Epoch 115: EarlyStopping counter for 'val_auc_euclidean': 44/40
# 	Epoch 115: EarlyStopping counter for 'val_auc_cosine': 36/40
# Epoch 116:
# 	train: loss 0.093 | loss id   0.07 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.867 | acc_cos: 0.904 | auc_eu: 0.870 | auc_cos: 0.907
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 116: EarlyStopping counter for 'val_euclidean_accuracy': 63/40
# 	Epoch 116: EarlyStopping counter for 'val_cosine_accuracy': 35/40
# 	Epoch 116: EarlyStopping counter for 'val_auc_euclidean': 45/40
# 	Epoch 116: EarlyStopping counter for 'val_auc_cosine': 37/40
# Epoch 117:
# 	train: loss 0.083 | loss id   0.06 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.797 | acc_cos: 0.868 | auc_eu: 0.854 | auc_cos: 0.908
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 117: EarlyStopping counter for 'val_euclidean_accuracy': 64/40
# 	Epoch 117: EarlyStopping counter for 'val_cosine_accuracy': 36/40
# 	Epoch 117: EarlyStopping counter for 'val_auc_euclidean': 46/40
# 	Epoch 117: EarlyStopping counter for 'val_auc_cosine': 38/40
# Epoch 118:
# 	train: loss 0.080 | loss id   0.06 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.862 | acc_cos: 0.906 | auc_eu: 0.856 | auc_cos: 0.917
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 118: EarlyStopping counter for 'val_euclidean_accuracy': 65/40
# 	Epoch 118: EarlyStopping counter for 'val_cosine_accuracy': 37/40
# 	Epoch 118: EarlyStopping counter for 'val_auc_euclidean': 47/40
# 	Epoch 118: EarlyStopping counter for 'val_auc_cosine': 39/40
# Epoch 119:
# 	train: loss 0.080 | loss id   0.06 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.904 | acc_cos: 0.907 | auc_eu: 0.872 | auc_cos: 0.913
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 119: EarlyStopping counter for 'val_euclidean_accuracy': 66/40
# 	Epoch 119: EarlyStopping counter for 'val_cosine_accuracy': 38/40
# 	Epoch 119: EarlyStopping counter for 'val_auc_euclidean': 48/40
# 	Epoch 119: EarlyStopping counter for 'val_auc_cosine': 40/40
# Epoch 120:
# 	train: loss 0.070 | loss id   0.05 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.874 | acc_cos: 0.888 | auc_eu: 0.864 | auc_cos: 0.910
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 120: EarlyStopping counter for 'val_euclidean_accuracy': 67/40
# 	Epoch 120: EarlyStopping counter for 'val_cosine_accuracy': 39/40
# 	Epoch 120: EarlyStopping counter for 'val_auc_euclidean': 49/40
# 	Epoch 120: EarlyStopping counter for 'val_auc_cosine': 41/40
# Epoch 121:
# 	train: loss 0.091 | loss id   0.07 | top_1_acc 1.0000 | top_5_acc 1.0000 | acc_eu: 1.000 | acc_cos: 1.000 | auc_eu: 1.000 | auc_cos: 1.000
# 	val: acc_eu: 0.840 | acc_cos: 0.931 | auc_eu: 0.863 | auc_cos: 0.904
# 	Saving model and optimizer state to /media/vohoang/WorkSpace/ubuntu/projects/in-process/Bachelor-s-Project/checkpoint/magface/albedo/iresnet18/models/checkpoint.pth
# 	Epoch 121: EarlyStopping counter for 'val_euclidean_accuracy': 68/40
# 	Epoch 121: EarlyStopping counter for 'val_cosine_accuracy': 40/40
# 	Epoch 121: EarlyStopping counter for 'val_auc_euclidean': 50/40
# 	Epoch 121: EarlyStopping counter for 'val_auc_cosine': 42/40
# 	Early stopping triggered at epoch 121 as all metrics exceeded patience.

# %%
# %load_ext tensorboard
# %tensorboard --logdir checkpoint/magface/albedo/iresnet18/logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 171244), started 0:00:04 ago. (Use '!kill 171244' to kill it.)
#       <iframe id="tensorboard-frame-78e798b5e6067726" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-78e798b5e6067726");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
